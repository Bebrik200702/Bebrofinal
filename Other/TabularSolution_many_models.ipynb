# %%
import numpy as np
import pandas as pd
import polars as pl
from catboost import CatBoostClassifier, Pool, cv
import lightgbm as lgb
import xgboost as xgb
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import roc_auc_score, roc_curve, auc
from functools import partial 
from sklearn.base import BaseEstimator
from tqdm.auto import trange
from sklearn.model_selection import train_test_split, StratifiedKFold, StratifiedGroupKFold

# %%
train_data = pl.read_csv('./isic-2024-challenge/train-metadata.csv')

# %%
def process_data(data):
    return (
        data
        .with_columns(
                pl.col('age_approx').cast(pl.String).replace('NA', np.nan).cast(pl.Float64),
            )
        .with_columns(
                lesion_size_ratio              = pl.col('tbp_lv_minorAxisMM') / pl.col('clin_size_long_diam_mm'),
                lesion_shape_index             = pl.col('tbp_lv_areaMM2') / (pl.col('tbp_lv_perimeterMM') ** 2),
                hue_contrast                   = (pl.col('tbp_lv_H') - pl.col('tbp_lv_Hext')).abs(),
                luminance_contrast             = (pl.col('tbp_lv_L') - pl.col('tbp_lv_Lext')).abs(),
                lesion_color_difference        = (pl.col('tbp_lv_deltaA') ** 2 + pl.col('tbp_lv_deltaB') ** 2 + pl.col('tbp_lv_deltaL') ** 2).sqrt(),
                border_complexity              = pl.col('tbp_lv_norm_border') + pl.col('tbp_lv_symm_2axis'),
                color_uniformity               = pl.col('tbp_lv_color_std_mean') / (pl.col('tbp_lv_radial_color_std_max') + 1e-6),
            )
        .with_columns(
                position_distance_3d           = (pl.col('tbp_lv_x') ** 2 + pl.col('tbp_lv_y') ** 2 + pl.col('tbp_lv_z') ** 2).sqrt(),
                perimeter_to_area_ratio        = pl.col('tbp_lv_perimeterMM') / pl.col('tbp_lv_areaMM2'),
                area_to_perimeter_ratio        = pl.col('tbp_lv_areaMM2') / pl.col('tbp_lv_perimeterMM'),
                lesion_visibility_score        = pl.col('tbp_lv_deltaLBnorm') + pl.col('tbp_lv_norm_color'),
                combined_anatomical_site       = pl.col('anatom_site_general') + '_' + pl.col('tbp_lv_location'),
                symmetry_border_consistency    = pl.col('tbp_lv_symm_2axis') * pl.col('tbp_lv_norm_border'),
                consistency_symmetry_border    = pl.col('tbp_lv_symm_2axis') * pl.col('tbp_lv_norm_border') / (pl.col('tbp_lv_symm_2axis') + pl.col('tbp_lv_norm_border')),
            )
        .with_columns(
                color_consistency              = pl.col('tbp_lv_stdL') / pl.col('tbp_lv_Lext'),
                consistency_color              = pl.col('tbp_lv_stdL') * pl.col('tbp_lv_Lext') / (pl.col('tbp_lv_stdL') + pl.col('tbp_lv_Lext')),
                size_age_interaction           = pl.col('clin_size_long_diam_mm') * pl.col('age_approx'),
                hue_color_std_interaction      = pl.col('tbp_lv_H') * pl.col('tbp_lv_color_std_mean'),
                lesion_severity_index          = (pl.col('tbp_lv_norm_border') + pl.col('tbp_lv_norm_color') + pl.col('tbp_lv_eccentricity')) / 3,
                shape_complexity_index         = pl.col('border_complexity') + pl.col('lesion_shape_index'),
                color_contrast_index           = pl.col('tbp_lv_deltaA') + pl.col('tbp_lv_deltaB') + pl.col('tbp_lv_deltaL') + pl.col('tbp_lv_deltaLBnorm'),
            )
        .with_columns(
                log_lesion_area                = (pl.col('tbp_lv_areaMM2') + 1).log(),
                normalized_lesion_size         = pl.col('clin_size_long_diam_mm') / pl.col('age_approx'),
                mean_hue_difference            = (pl.col('tbp_lv_H') + pl.col('tbp_lv_Hext')) / 2,
                std_dev_contrast               = ((pl.col('tbp_lv_deltaA') ** 2 + pl.col('tbp_lv_deltaB') ** 2 + pl.col('tbp_lv_deltaL') ** 2) / 3).sqrt(),
                color_shape_composite_index    = (pl.col('tbp_lv_color_std_mean') + pl.col('tbp_lv_area_perim_ratio') + pl.col('tbp_lv_symm_2axis')) / 3,
                lesion_orientation_3d          = pl.arctan2(pl.col('tbp_lv_y'), pl.col('tbp_lv_x')),
                overall_color_difference       = (pl.col('tbp_lv_deltaA') + pl.col('tbp_lv_deltaB') + pl.col('tbp_lv_deltaL')) / 3,
            )
        .with_columns(
                symmetry_perimeter_interaction = pl.col('tbp_lv_symm_2axis') * pl.col('tbp_lv_perimeterMM'),
                comprehensive_lesion_index     = (pl.col('tbp_lv_area_perim_ratio') + pl.col('tbp_lv_eccentricity') + pl.col('tbp_lv_norm_color') + pl.col('tbp_lv_symm_2axis')) / 4,
                color_variance_ratio           = pl.col('tbp_lv_color_std_mean') / pl.col('tbp_lv_stdLExt'),
                border_color_interaction       = pl.col('tbp_lv_norm_border') * pl.col('tbp_lv_norm_color'),
                border_color_interaction_2     = pl.col('tbp_lv_norm_border') * pl.col('tbp_lv_norm_color') / (pl.col('tbp_lv_norm_border') + pl.col('tbp_lv_norm_color')),
                size_color_contrast_ratio      = pl.col('clin_size_long_diam_mm') / pl.col('tbp_lv_deltaLBnorm'),
                age_normalized_nevi_confidence = pl.col('tbp_lv_nevi_confidence') / pl.col('age_approx'),
                age_normalized_nevi_confidence_2 = (pl.col('clin_size_long_diam_mm')**2 + pl.col('age_approx')**2).sqrt(),
                color_asymmetry_index          = pl.col('tbp_lv_radial_color_std_max') * pl.col('tbp_lv_symm_2axis'),
            )
        .with_columns(
                volume_approximation_3d        = pl.col('tbp_lv_areaMM2') * (pl.col('tbp_lv_x')**2 + pl.col('tbp_lv_y')**2 + pl.col('tbp_lv_z')**2).sqrt(),
                color_range                    = (pl.col('tbp_lv_L') - pl.col('tbp_lv_Lext')).abs() + (pl.col('tbp_lv_A') - pl.col('tbp_lv_Aext')).abs() + (pl.col('tbp_lv_B') - pl.col('tbp_lv_Bext')).abs(),
                shape_color_consistency        = pl.col('tbp_lv_eccentricity') * pl.col('tbp_lv_color_std_mean'),
                border_length_ratio            = pl.col('tbp_lv_perimeterMM') / (2 * np.pi * (pl.col('tbp_lv_areaMM2') / np.pi).sqrt()),
                age_size_symmetry_index        = pl.col('age_approx') * pl.col('clin_size_long_diam_mm') * pl.col('tbp_lv_symm_2axis'),
                index_age_size_symmetry        = pl.col('age_approx') * pl.col('tbp_lv_areaMM2') * pl.col('tbp_lv_symm_2axis'),
            )
        .with_columns(
            ((pl.col(col) - pl.col(col).mean().over('patient_id')) / (pl.col(col).std().over('patient_id') + 1e-5)).alias(f'{col}_patient_norm') for col in (num_cols + new_cols)
        )

        .with_columns(
                count_per_patient = pl.col('isic_id').count().over('patient_id'),
                age_difference = (pl.col('age_approx').max().over('patient_id') - pl.col('age_approx').min().over('patient_id')),
                is_tbp_tile_type = pl.col('tbp_tile_type').map_elements(lambda x: 1 if x == '3D: white' else 0)
        )
        .with_columns(
                tbp_tile_type_mean = pl.col('is_tbp_tile_type').mean().over('patient_id'),
                tbp_tile_type_sum = pl.col('is_tbp_tile_type').sum().over('patient_id'),
                tbp_tile_type_inv = pl.col('count_per_patient') - pl.col('is_tbp_tile_type').sum().over('patient_id'),
        )
        .to_pandas()
    )

# %%
def p_auc_tpr(v_gt, v_pred, min_tpr=None, sample_weight=None):
    """Computes the area under the AUC above a minumum TPR.

    Args:
        v_gt: ground truth vector (1s and 0s)
        v_p: predictions vector of scores ranging [0, 1]
        min_tpr: minimum true positive threshold (sensitivity)

    Returns:
        Float value range [0, 1]
    """
    if len(np.unique(v_gt)) != 2:
        raise ValueError(
            "Only one class present in y_true. ROC AUC score "
            "is not defined in that case."
        )
    
    # redefine the target. set 0s to 1s and 1s to 0s
    v_gt = abs(np.asarray(v_gt)-1)
    v_pred = abs(np.asarray(v_pred)-1)
    max_fpr = abs(1-min_tpr)
    
    # using sklearn.metric functions: (1) roc_curve and (2) auc
    fpr, tpr, _ = roc_curve(v_gt, v_pred, sample_weight=sample_weight)
    if max_fpr is None or max_fpr == 1:
        return auc(fpr, tpr)
    if max_fpr <= 0 or max_fpr > 1:
        raise ValueError("Expected min_tpr in range [0, 1), got: %r" % min_tpr)

    # Add a single point at max_fpr by linear interpolation
    stop = np.searchsorted(fpr, max_fpr, "right")
    x_interp = [fpr[stop - 1], fpr[stop]]
    y_interp = [tpr[stop - 1], tpr[stop]]
    tpr = np.append(tpr[:stop], np.interp(max_fpr, x_interp, y_interp))
    fpr = np.append(fpr[:stop], max_fpr)
    partial_auc = auc(fpr, tpr)
    return(partial_auc)

# %%
class PRAUCMetric:
    def is_max_optimal(self):
        return True # greater is better

    def evaluate(self, approxes, target, weight):
        assert len(approxes) == 1
        assert len(target) == len(approxes[0])

        approx = approxes[0]

        y_pred = approx #np.rint(approx)
        y_true = np.array(target).astype(int)

        output_weight = 1 # weight is not used

        score = p_auc_tpr(y_true, y_pred,min_tpr=0.80)
 
        return score, output_weight

    def get_final_error(self, error, weight):
        return error

def lgb_custom_metric(preds, dataset):
    y_true = dataset#.get_label()
    try:
        return 'prauc', -p_auc_tpr(y_true, preds,min_tpr=0.80), True
    except:
        return 'prauc', -100, True

def xgb_custom_metric(y_true, y_pred,*args, **kwargs):
    return -p_auc_tpr(y_true, y_pred, min_tpr=0.80)

# %%
num_cols = [
    'age_approx',                        # Approximate age of patient at time of imaging.
    'clin_size_long_diam_mm',            # Maximum diameter of the lesion (mm).+
    'tbp_lv_A',                          # A inside  lesion.+
    'tbp_lv_Aext',                       # A outside lesion.+
    'tbp_lv_B',                          # B inside  lesion.+
    'tbp_lv_Bext',                       # B outside lesion.+ 
    'tbp_lv_C',                          # Chroma inside  lesion.+
    'tbp_lv_Cext',                       # Chroma outside lesion.+
    'tbp_lv_H',                          # Hue inside the lesion; calculated as the angle of A* and B* in LAB* color space. Typical values range from 25 (red) to 75 (brown).+
    'tbp_lv_Hext',                       # Hue outside lesion.+
    'tbp_lv_L',                          # L inside lesion.+
    'tbp_lv_Lext',                       # L outside lesion.+
    'tbp_lv_areaMM2',                    # Area of lesion (mm^2).+
    'tbp_lv_area_perim_ratio',           # Border jaggedness, the ratio between lesions perimeter and area. Circular lesions will have low values; irregular shaped lesions will have higher values. Values range 0-10.+
    'tbp_lv_color_std_mean',             # Color irregularity, calculated as the variance of colors within the lesion's boundary.
    'tbp_lv_deltaA',                     # Average A contrast (inside vs. outside lesion).+
    'tbp_lv_deltaB',                     # Average B contrast (inside vs. outside lesion).+
    'tbp_lv_deltaL',                     # Average L contrast (inside vs. outside lesion).+
    'tbp_lv_deltaLB',                    #
    'tbp_lv_deltaLBnorm',                # Contrast between the lesion and its immediate surrounding skin. Low contrast lesions tend to be faintly visible such as freckles; high contrast lesions tend to be those with darker pigment. Calculated as the average delta LB of the lesion relative to its immediate background in LAB* color space. Typical values range from 5.5 to 25.+
    'tbp_lv_eccentricity',               # Eccentricity.+
    'tbp_lv_minorAxisMM',                # Smallest lesion diameter (mm).+
    'tbp_lv_nevi_confidence',            # Nevus confidence score (0-100 scale) is a convolutional neural network classifier estimated probability that the lesion is a nevus. The neural network was trained on approximately 57,000 lesions that were classified and labeled by a dermatologist.+,++
    'tbp_lv_norm_border',                # Border irregularity (0-10 scale); the normalized average of border jaggedness and asymmetry.+
    'tbp_lv_norm_color',                 # Color variation (0-10 scale); the normalized average of color asymmetry and color irregularity.+
    'tbp_lv_perimeterMM',                # Perimeter of lesion (mm).+
    'tbp_lv_radial_color_std_max',       # Color asymmetry, a measure of asymmetry of the spatial distribution of color within the lesion. This score is calculated by looking at the average standard deviation in LAB* color space within concentric rings originating from the lesion center. Values range 0-10.+
    'tbp_lv_stdL',                       # Standard deviation of L inside  lesion.+
    'tbp_lv_stdLExt',                    # Standard deviation of L outside lesion.+
    'tbp_lv_symm_2axis',                 # Border asymmetry; a measure of asymmetry of the lesion's contour about an axis perpendicular to the lesion's most symmetric axis. Lesions with two axes of symmetry will therefore have low scores (more symmetric), while lesions with only one or zero axes of symmetry will have higher scores (less symmetric). This score is calculated by comparing opposite halves of the lesion contour over many degrees of rotation. The angle where the halves are most similar identifies the principal axis of symmetry, while the second axis of symmetry is perpendicular to the principal axis. Border asymmetry is reported as the asymmetry value about this second axis. Values range 0-10.+
    'tbp_lv_symm_2axis_angle',           # Lesion border asymmetry angle.+
    'tbp_lv_x',                          # X-coordinate of the lesion on 3D TBP.+
    'tbp_lv_y',                          # Y-coordinate of the lesion on 3D TBP.+
    'tbp_lv_z',                          # Z-coordinate of the lesion on 3D TBP.+
]

new_cols = [
    'lesion_size_ratio',             # tbp_lv_minorAxisMM      / clin_size_long_diam_mm
    'lesion_shape_index',            # tbp_lv_areaMM2          / tbp_lv_perimeterMM **2
    'hue_contrast',                  # tbp_lv_H                - tbp_lv_Hext              abs
    'luminance_contrast',            # tbp_lv_L                - tbp_lv_Lext              abs
    'lesion_color_difference',       # tbp_lv_deltaA **2       + tbp_lv_deltaB **2 + tbp_lv_deltaL **2  sqrt  
    'border_complexity',             # tbp_lv_norm_border      + tbp_lv_symm_2axis
    'color_uniformity',              # tbp_lv_color_std_mean   / tbp_lv_radial_color_std_max

    'position_distance_3d',          # tbp_lv_x **2 + tbp_lv_y **2 + tbp_lv_z **2  sqrt
    'perimeter_to_area_ratio',       # tbp_lv_perimeterMM      / tbp_lv_areaMM2
    'area_to_perimeter_ratio',       # tbp_lv_areaMM2          / tbp_lv_perimeterMM
    'lesion_visibility_score',       # tbp_lv_deltaLBnorm      + tbp_lv_norm_color
    'symmetry_border_consistency',   # tbp_lv_symm_2axis       * tbp_lv_norm_border
    'consistency_symmetry_border',   # tbp_lv_symm_2axis       * tbp_lv_norm_border / (tbp_lv_symm_2axis + tbp_lv_norm_border)

    'color_consistency',             # tbp_lv_stdL             / tbp_lv_Lext
    'consistency_color',             # tbp_lv_stdL*tbp_lv_Lext / tbp_lv_stdL + tbp_lv_Lext
    'size_age_interaction',          # clin_size_long_diam_mm  * age_approx
    'hue_color_std_interaction',     # tbp_lv_H                * tbp_lv_color_std_mean
    'lesion_severity_index',         # tbp_lv_norm_border      + tbp_lv_norm_color + tbp_lv_eccentricity / 3
    'shape_complexity_index',        # border_complexity       + lesion_shape_index
    'color_contrast_index',          # tbp_lv_deltaA + tbp_lv_deltaB + tbp_lv_deltaL + tbp_lv_deltaLBnorm

    'log_lesion_area',               # tbp_lv_areaMM2          + 1  np.log
    'normalized_lesion_size',        # clin_size_long_diam_mm  / age_approx
    'mean_hue_difference',           # tbp_lv_H                + tbp_lv_Hext    / 2
    'std_dev_contrast',              # tbp_lv_deltaA **2 + tbp_lv_deltaB **2 + tbp_lv_deltaL **2   / 3  np.sqrt
    'color_shape_composite_index',   # tbp_lv_color_std_mean   + bp_lv_area_perim_ratio + tbp_lv_symm_2axis   / 3
    'lesion_orientation_3d',         # tbp_lv_y                , tbp_lv_x  np.arctan2
    'overall_color_difference',      # tbp_lv_deltaA           + tbp_lv_deltaB + tbp_lv_deltaL   / 3

    'symmetry_perimeter_interaction',# tbp_lv_symm_2axis       * tbp_lv_perimeterMM
    'comprehensive_lesion_index',    # tbp_lv_area_perim_ratio + tbp_lv_eccentricity + bp_lv_norm_color + tbp_lv_symm_2axis   / 4
    'color_variance_ratio',          # tbp_lv_color_std_mean   / tbp_lv_stdLExt
    'border_color_interaction',      # tbp_lv_norm_border      * tbp_lv_norm_color
    'border_color_interaction_2',
    'size_color_contrast_ratio',     # clin_size_long_diam_mm  / tbp_lv_deltaLBnorm
    'age_normalized_nevi_confidence',# tbp_lv_nevi_confidence  / age_approx
    'age_normalized_nevi_confidence_2',
    'color_asymmetry_index',         # tbp_lv_symm_2axis       * tbp_lv_radial_color_std_max

    'volume_approximation_3d',       # tbp_lv_areaMM2          * sqrt(tbp_lv_x**2 + tbp_lv_y**2 + tbp_lv_z**2)
    'color_range',                   # abs(tbp_lv_L - tbp_lv_Lext) + abs(tbp_lv_A - tbp_lv_Aext) + abs(tbp_lv_B - tbp_lv_Bext)
    'shape_color_consistency',       # tbp_lv_eccentricity     * tbp_lv_color_std_mean
    'border_length_ratio',           # tbp_lv_perimeterMM      / pi * sqrt(tbp_lv_areaMM2 / pi)
    'age_size_symmetry_index',       # age_approx              * clin_size_long_diam_mm * tbp_lv_symm_2axis
    'index_age_size_symmetry',       # age_approx              * tbp_lv_areaMM2 * tbp_lv_symm_2axis
]

aggr_cols = ['combined_anatomical_site'] + [f'{col}_patient_norm' for col in (num_cols + new_cols)]
cat_cols = ['sex', 'anatom_site_general', 'tbp_tile_type', 'tbp_lv_location', 'tbp_lv_location_simple', 'attribution', 'copyright_license','combined_anatomical_site',]
drop_cols = [
    'isic_id',
    'patient_id',
    'image_type',
    'lesion_id',
    'iddx_full',
    'iddx_1',
    'iddx_2',
    'iddx_3',
    'iddx_4',
    'iddx_5',
    'mel_mitotic_index',
    'mel_thick_mm', 
    'tbp_lv_dnn_lesion_confidence',
    'is_tbp_tile_type',
]

cb_params = {
    'iterations': 1000,
    'learning_rate': 0.05,
    'loss_function': 'CrossEntropy',
    'max_depth': 6,
    'eval_metric': PRAUCMetric(),
    'l2_leaf_reg': 6.216113851699493, 
    #'subsample': 0.6249261779711819, 
    'min_data_in_leaf': 24,
    'task_type': 'GPU',
    'random_seed': 56,
}


lgb_params = {
    'objective':        'binary',
    'verbosity':        -1,
    'n_iter':           300,
    'boosting_type':    'gbdt',
    'random_state':     56,
    'lambda_l1':        0.08758718919397321, 
    'lambda_l2':        0.0039689175176025465, 
    'learning_rate':    0.03231007103195577, 
    'max_depth':        5, 
    'num_leaves':       103, 
    'colsample_bytree': 0.8329551585827726, 
    'colsample_bynode': 0.4025961355653304, 
    'bagging_fraction': 0.7738954452473223, 
    'extra_trees':      True,
    'bagging_freq':     4, 
    'min_data_in_leaf': 85, 
    'scale_pos_weight': 2.7984184778875543,
}


xgb_params = {
    'enable_categorical': True,
    #'verbose':50,
    'objective':'binary:logistic',
    'tree_method': 'hist',
    #'num_iterations': 400,
    'random_state': 56,
    'learning_rate': 0.08501257473292347, 
    'lambda': 8.879624125465703, 
    'early_stopping_rounds': 30,
    'alpha': 0.6779926606782505, 
    'eval_metric': xgb_custom_metric,
    'max_depth': 6,
    'subsample': 0.6012681388711075, 
    'colsample_bytree': 0.8437772277074493, 
    'colsample_bylevel': 0.5476090898823716, 
    'colsample_bynode': 0.9928601203635129, 
    'scale_pos_weight': 3.29440313334688,
    'random_state': 56
}

params = {
    'cb_params': cb_params,
    'lgb_params': lgb_params,
    'xgb_params': xgb_params
}

label_col = 'target'
n_folds = 5
n_repits = 1

# %%
class EnsembleClassifier(BaseEstimator):
    def __init__(self,cb_params,lgb_params,xgb_params):
        self.cbm = CatBoostClassifier(**cb_params)
        self.lgbm = lgb.LGBMClassifier(**lgb_params)
        self.xgbm = xgb.XGBClassifier(**xgb_params)
    
    def fit(self,X,y,X_val,y_val,cat_features=None,verbose=False):
        train_pool = Pool(X,label=y,cat_features=cat_features)
        eval_pool = Pool(X_val,label=y_val,cat_features=cat_features)
        self.cbm.fit(train_pool,eval_set=eval_pool,verbose=verbose)
        self.lgbm.fit(X,y,eval_set=[(X_val,y_val)],eval_metric=lgb_custom_metric,categorical_feature=cat_features)
        self.xgbm.fit(X,y,eval_set=[(X_val,y_val)])
    
    def predict_proba(self,X_test,cat_features):
        test_pool = Pool(X_test,cat_features=cat_features)
        cb_preds = self.cbm.predict_proba(test_pool)[:,1]
        lgb_preds = self.lgbm.predict_proba(X_test)[:,1]
        xgb_preds = self.xgbm.predict_proba(X_test)[:,1]
        return cb_preds, lgb_preds, xgb_preds

# %%
class CustomBoostKfoldWraper(BaseEstimator):
    def __init__(self,num_folds,num_repits,params,random_state=56,score_func=p_auc_tpr):
        self.models = []
        self.params = params
        self.random_state = random_state
        self.num_folds = num_folds
        self.num_repits = num_repits
        self.score_func = score_func
        
    def fit(self,train_data,cat_features=None,drop_cols=None,label_col=None,verbose=False):
        self.scores = []
        
        for i in trange(self.num_repits):
            kfold = StratifiedGroupKFold(self.num_folds,random_state=self.random_state+i,shuffle=True)
            for train_index, test_index in (kfold.split(train_data,train_data[label_col],train_data['patient_id'])):
                train_df = train_data.iloc[train_index]
                test_df = train_data.iloc[test_index]
                
                model = EnsembleClassifier(**self.params)
                model.fit(
                    X = train_df.drop([label_col]+drop_cols,axis=1),
                    y = train_df[label_col],
                    X_val = test_df.drop([label_col]+drop_cols,axis=1),
                    y_val = test_df[label_col],
                    cat_features = cat_features,
                    verbose = verbose
                )
                cb_preds, lgb_preds, xgb_preds = model.predict_proba(test_df.drop([label_col]+drop_cols,axis=1),cat_features)
                avg_preds = (cb_preds + lgb_preds + xgb_preds) / 3
                self.scores += [[
                    self.score_func(test_df[label_col],cb_preds),
                    self.score_func(test_df[label_col],lgb_preds),
                    self.score_func(test_df[label_col],xgb_preds),
                    self.score_func(test_df[label_col],avg_preds)
                ]]
                print(self.scores[-1])
                self.models += [model]
                
        print(f"Total Score {np.mean([x[3] for x in self.scores])}")
            
    def predict(self,test_data,drop_cols=None,cat_features=None):
        preds = np.mean([
            np.mean(model.predict_proba(test_data.drop(drop_cols,axis=1),cat_features=cat_features)[:,1],axis=0)
            for model in self.models
        ],axis=0)
        return preds
    
    def get_feature_importance(self,type='FeatureImportance'):
        imp_0 = self.models[0].cbm.get_feature_importance(prettified=True,type=type).set_index('Feature Id')
        for i in range(1,len(self.models)):
            imp_0 += self.models[i].cbm.get_feature_importance(prettified=True,type=type).set_index('Feature Id')
        return (imp_0 / len(self.models)).sort_values(by='Importances')[::-1]

# %%
train_data = process_data(train_data)
train_data[cat_cols] = train_data[cat_cols].astype('category')
# Out:
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.

# %%
model = CustomBoostKfoldWraper(
    num_folds=n_folds,
    num_repits=n_repits,
    params=params,
    random_state=56,
    score_func=partial(p_auc_tpr,min_tpr=0.80)
)

# %%
model.fit(
    train_data=train_data,
    cat_features=cat_cols,
    drop_cols=drop_cols,
    label_col=label_col,
    verbose=200,
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/catboost/core.py:2311: UserWarning: Failed to import numba for optimizing custom metrics and objectives
#   _check_train_params(params)
# Default metric period is 5 because PythonUserDefinedPerObject is/are not implemented for GPU
# 0:	learn: 0.0265520	test: 0.0392256	best: 0.0392256 (0)	total: 50.1ms	remaining: 50s
# 200:	learn: 0.1761450	test: 0.1759944	best: 0.1765774 (190)	total: 7.06s	remaining: 28.1s
# 400:	learn: 0.1842021	test: 0.1762013	best: 0.1770677 (260)	total: 14s	remaining: 20.9s
# 600:	learn: 0.1892525	test: 0.1758834	best: 0.1770677 (260)	total: 21s	remaining: 13.9s
# 800:	learn: 0.1925490	test: 0.1759283	best: 0.1770677 (260)	total: 28.2s	remaining: 7s
# 999:	learn: 0.1947485	test: 0.1751129	best: 0.1770677 (260)	total: 35.3s	remaining: 0us
# bestTest = 0.1770676772
# bestIteration = 260
# Shrink model to first 261 iterations.
# /usr/local/lib/python3.11/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [0]	validation_0-logloss:0.61237	validation_0-xgb_custom_metric:-0.02782
# [1]	validation_0-logloss:0.54417	validation_0-xgb_custom_metric:-0.02781
# [2]	validation_0-logloss:0.48586	validation_0-xgb_custom_metric:-0.02781
# [3]	validation_0-logloss:0.43544	validation_0-xgb_custom_metric:-0.02780
# [4]	validation_0-logloss:0.39154	validation_0-xgb_custom_metric:-0.02780
# [5]	validation_0-logloss:0.35301	validation_0-xgb_custom_metric:-0.02779
# [6]	validation_0-logloss:0.31904	validation_0-xgb_custom_metric:-0.03133
# [7]	validation_0-logloss:0.28891	validation_0-xgb_custom_metric:-0.03445
# [8]	validation_0-logloss:0.26210	validation_0-xgb_custom_metric:-0.03441
# [9]	validation_0-logloss:0.23818	validation_0-xgb_custom_metric:-0.03999
# [10]	validation_0-logloss:0.21676	validation_0-xgb_custom_metric:-0.04663
# [11]	validation_0-logloss:0.19752	validation_0-xgb_custom_metric:-0.04796
# [12]	validation_0-logloss:0.18019	validation_0-xgb_custom_metric:-0.04794
# [13]	validation_0-logloss:0.16456	validation_0-xgb_custom_metric:-0.05774
# [14]	validation_0-logloss:0.15044	validation_0-xgb_custom_metric:-0.05774
# [15]	validation_0-logloss:0.13764	validation_0-xgb_custom_metric:-0.05970
# [16]	validation_0-logloss:0.12607	validation_0-xgb_custom_metric:-0.05970
# [17]	validation_0-logloss:0.11558	validation_0-xgb_custom_metric:-0.06186
# [18]	validation_0-logloss:0.10605	validation_0-xgb_custom_metric:-0.10619
# [19]	validation_0-logloss:0.09739	validation_0-xgb_custom_metric:-0.10530
# [20]	validation_0-logloss:0.08952	validation_0-xgb_custom_metric:-0.11019
# [21]	validation_0-logloss:0.08234	validation_0-xgb_custom_metric:-0.10937
# [22]	validation_0-logloss:0.07580	validation_0-xgb_custom_metric:-0.11454
# [23]	validation_0-logloss:0.06982	validation_0-xgb_custom_metric:-0.11399
# [24]	validation_0-logloss:0.06439	validation_0-xgb_custom_metric:-0.11307
# [25]	validation_0-logloss:0.05943	validation_0-xgb_custom_metric:-0.11324
# [26]	validation_0-logloss:0.05488	validation_0-xgb_custom_metric:-0.11705
# [27]	validation_0-logloss:0.05076	validation_0-xgb_custom_metric:-0.12843
# [28]	validation_0-logloss:0.04698	validation_0-xgb_custom_metric:-0.12903
# [29]	validation_0-logloss:0.04353	validation_0-xgb_custom_metric:-0.12847
# [30]	validation_0-logloss:0.04034	validation_0-xgb_custom_metric:-0.12823
# [31]	validation_0-logloss:0.03742	validation_0-xgb_custom_metric:-0.12764
# [32]	validation_0-logloss:0.03476	validation_0-xgb_custom_metric:-0.12703
# [33]	validation_0-logloss:0.03232	validation_0-xgb_custom_metric:-0.12728
# [34]	validation_0-logloss:0.03007	validation_0-xgb_custom_metric:-0.12752
# [35]	validation_0-logloss:0.02801	validation_0-xgb_custom_metric:-0.12741
# [36]	validation_0-logloss:0.02614	validation_0-xgb_custom_metric:-0.12734
# [37]	validation_0-logloss:0.02441	validation_0-xgb_custom_metric:-0.12707
# [38]	validation_0-logloss:0.02282	validation_0-xgb_custom_metric:-0.13113
# [39]	validation_0-logloss:0.02137	validation_0-xgb_custom_metric:-0.13142
# [40]	validation_0-logloss:0.02003	validation_0-xgb_custom_metric:-0.13173
# [41]	validation_0-logloss:0.01881	validation_0-xgb_custom_metric:-0.15860
# [42]	validation_0-logloss:0.01770	validation_0-xgb_custom_metric:-0.15777
# [43]	validation_0-logloss:0.01668	validation_0-xgb_custom_metric:-0.15676
# [44]	validation_0-logloss:0.01574	validation_0-xgb_custom_metric:-0.15668
# [45]	validation_0-logloss:0.01488	validation_0-xgb_custom_metric:-0.15698
# [46]	validation_0-logloss:0.01407	validation_0-xgb_custom_metric:-0.15618
# [47]	validation_0-logloss:0.01333	validation_0-xgb_custom_metric:-0.15615
# [48]	validation_0-logloss:0.01269	validation_0-xgb_custom_metric:-0.15622
# [49]	validation_0-logloss:0.01208	validation_0-xgb_custom_metric:-0.16113
# [50]	validation_0-logloss:0.01151	validation_0-xgb_custom_metric:-0.16501
# [51]	validation_0-logloss:0.01099	validation_0-xgb_custom_metric:-0.16492
# [52]	validation_0-logloss:0.01051	validation_0-xgb_custom_metric:-0.16453
# [53]	validation_0-logloss:0.01007	validation_0-xgb_custom_metric:-0.16496
# [54]	validation_0-logloss:0.00967	validation_0-xgb_custom_metric:-0.16457
# [55]	validation_0-logloss:0.00932	validation_0-xgb_custom_metric:-0.16409
# [56]	validation_0-logloss:0.00898	validation_0-xgb_custom_metric:-0.16359
# [57]	validation_0-logloss:0.00869	validation_0-xgb_custom_metric:-0.16326
# [58]	validation_0-logloss:0.00839	validation_0-xgb_custom_metric:-0.16289
# [59]	validation_0-logloss:0.00812	validation_0-xgb_custom_metric:-0.16436
# [60]	validation_0-logloss:0.00789	validation_0-xgb_custom_metric:-0.16389
# [61]	validation_0-logloss:0.00766	validation_0-xgb_custom_metric:-0.16490
# [62]	validation_0-logloss:0.00748	validation_0-xgb_custom_metric:-0.16400
# [63]	validation_0-logloss:0.00730	validation_0-xgb_custom_metric:-0.16396
# [64]	validation_0-logloss:0.00712	validation_0-xgb_custom_metric:-0.16526
# [65]	validation_0-logloss:0.00697	validation_0-xgb_custom_metric:-0.16798
# [66]	validation_0-logloss:0.00682	validation_0-xgb_custom_metric:-0.16834
# [67]	validation_0-logloss:0.00668	validation_0-xgb_custom_metric:-0.16914
# [68]	validation_0-logloss:0.00657	validation_0-xgb_custom_metric:-0.16894
# [69]	validation_0-logloss:0.00646	validation_0-xgb_custom_metric:-0.16823
# [70]	validation_0-logloss:0.00636	validation_0-xgb_custom_metric:-0.16835
# [71]	validation_0-logloss:0.00628	validation_0-xgb_custom_metric:-0.16886
# [72]	validation_0-logloss:0.00618	validation_0-xgb_custom_metric:-0.16997
# [73]	validation_0-logloss:0.00611	validation_0-xgb_custom_metric:-0.16936
# [74]	validation_0-logloss:0.00603	validation_0-xgb_custom_metric:-0.16910
# [75]	validation_0-logloss:0.00598	validation_0-xgb_custom_metric:-0.16855
# [76]	validation_0-logloss:0.00591	validation_0-xgb_custom_metric:-0.16806
# [77]	validation_0-logloss:0.00585	validation_0-xgb_custom_metric:-0.16995
# [78]	validation_0-logloss:0.00579	validation_0-xgb_custom_metric:-0.17041
# [79]	validation_0-logloss:0.00575	validation_0-xgb_custom_metric:-0.16960
# [80]	validation_0-logloss:0.00570	validation_0-xgb_custom_metric:-0.16900
# [81]	validation_0-logloss:0.00564	validation_0-xgb_custom_metric:-0.16924
# [82]	validation_0-logloss:0.00560	validation_0-xgb_custom_metric:-0.16854
# [83]	validation_0-logloss:0.00557	validation_0-xgb_custom_metric:-0.16822
# [84]	validation_0-logloss:0.00553	validation_0-xgb_custom_metric:-0.16806
# [85]	validation_0-logloss:0.00549	validation_0-xgb_custom_metric:-0.16762
# [86]	validation_0-logloss:0.00545	validation_0-xgb_custom_metric:-0.16860
# [87]	validation_0-logloss:0.00541	validation_0-xgb_custom_metric:-0.16893
# [88]	validation_0-logloss:0.00540	validation_0-xgb_custom_metric:-0.16804
# [89]	validation_0-logloss:0.00537	validation_0-xgb_custom_metric:-0.16710
# [90]	validation_0-logloss:0.00536	validation_0-xgb_custom_metric:-0.16600
# [91]	validation_0-logloss:0.00535	validation_0-xgb_custom_metric:-0.16548
# [92]	validation_0-logloss:0.00533	validation_0-xgb_custom_metric:-0.16577
# [93]	validation_0-logloss:0.00531	validation_0-xgb_custom_metric:-0.16499
# [94]	validation_0-logloss:0.00529	validation_0-xgb_custom_metric:-0.16501
# [95]	validation_0-logloss:0.00527	validation_0-xgb_custom_metric:-0.16476
# [96]	validation_0-logloss:0.00525	validation_0-xgb_custom_metric:-0.16646
# [97]	validation_0-logloss:0.00523	validation_0-xgb_custom_metric:-0.16637
# [98]	validation_0-logloss:0.00521	validation_0-xgb_custom_metric:-0.16785
# [99]	validation_0-logloss:0.00519	validation_0-xgb_custom_metric:-0.16925
# [0.17706767718467586, 0.16199886624214677, 0.17040465778414268, 0.17910006904841055]
# /usr/local/lib/python3.11/dist-packages/catboost/core.py:2311: UserWarning: Failed to import numba for optimizing custom metrics and objectives
#   _check_train_params(params)
# Default metric period is 5 because PythonUserDefinedPerObject is/are not implemented for GPU
# 0:	learn: 0.0302481	test: 0.0215900	best: 0.0215900 (0)	total: 36.4ms	remaining: 36.3s
# 200:	learn: 0.1774341	test: 0.1431264	best: 0.1431264 (200)	total: 7.09s	remaining: 28.2s
# 400:	learn: 0.1854246	test: 0.1503266	best: 0.1503266 (400)	total: 14.3s	remaining: 21.3s
# 600:	learn: 0.1898103	test: 0.1563356	best: 0.1563356 (600)	total: 21.4s	remaining: 14.2s
# 800:	learn: 0.1927889	test: 0.1585380	best: 0.1585380 (800)	total: 28.6s	remaining: 7.11s
# 999:	learn: 0.1946810	test: 0.1583486	best: 0.1590224 (915)	total: 35.9s	remaining: 0us
# bestTest = 0.1590223593
# bestIteration = 915
# Shrink model to first 916 iterations.
# /usr/local/lib/python3.11/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [0]	validation_0-logloss:0.61240	validation_0-xgb_custom_metric:-0.02268
# [1]	validation_0-logloss:0.54420	validation_0-xgb_custom_metric:-0.02842
# [2]	validation_0-logloss:0.48585	validation_0-xgb_custom_metric:-0.02961
# [3]	validation_0-logloss:0.43540	validation_0-xgb_custom_metric:-0.02961
# [4]	validation_0-logloss:0.39149	validation_0-xgb_custom_metric:-0.03101
# [5]	validation_0-logloss:0.35293	validation_0-xgb_custom_metric:-0.03099
# [6]	validation_0-logloss:0.31894	validation_0-xgb_custom_metric:-0.03324
# [7]	validation_0-logloss:0.28879	validation_0-xgb_custom_metric:-0.03488
# [8]	validation_0-logloss:0.26198	validation_0-xgb_custom_metric:-0.04133
# [9]	validation_0-logloss:0.23806	validation_0-xgb_custom_metric:-0.04409
# [10]	validation_0-logloss:0.21663	validation_0-xgb_custom_metric:-0.04862
# [11]	validation_0-logloss:0.19738	validation_0-xgb_custom_metric:-0.06724
# [12]	validation_0-logloss:0.18006	validation_0-xgb_custom_metric:-0.06704
# [13]	validation_0-logloss:0.16445	validation_0-xgb_custom_metric:-0.07407
# [14]	validation_0-logloss:0.15033	validation_0-xgb_custom_metric:-0.07407
# [15]	validation_0-logloss:0.13755	validation_0-xgb_custom_metric:-0.07403
# [16]	validation_0-logloss:0.12597	validation_0-xgb_custom_metric:-0.09013
# [17]	validation_0-logloss:0.11549	validation_0-xgb_custom_metric:-0.09000
# [18]	validation_0-logloss:0.10596	validation_0-xgb_custom_metric:-0.08999
# [19]	validation_0-logloss:0.09729	validation_0-xgb_custom_metric:-0.08994
# [20]	validation_0-logloss:0.08940	validation_0-xgb_custom_metric:-0.08983
# [21]	validation_0-logloss:0.08222	validation_0-xgb_custom_metric:-0.08983
# [22]	validation_0-logloss:0.07568	validation_0-xgb_custom_metric:-0.09348
# [23]	validation_0-logloss:0.06971	validation_0-xgb_custom_metric:-0.09348
# [24]	validation_0-logloss:0.06427	validation_0-xgb_custom_metric:-0.09337
# [25]	validation_0-logloss:0.05926	validation_0-xgb_custom_metric:-0.09898
# [26]	validation_0-logloss:0.05473	validation_0-xgb_custom_metric:-0.09878
# [27]	validation_0-logloss:0.05057	validation_0-xgb_custom_metric:-0.09865
# [28]	validation_0-logloss:0.04679	validation_0-xgb_custom_metric:-0.10228
# [29]	validation_0-logloss:0.04331	validation_0-xgb_custom_metric:-0.10642
# [30]	validation_0-logloss:0.04013	validation_0-xgb_custom_metric:-0.10583
# [31]	validation_0-logloss:0.03723	validation_0-xgb_custom_metric:-0.10466
# [32]	validation_0-logloss:0.03458	validation_0-xgb_custom_metric:-0.10553
# [33]	validation_0-logloss:0.03216	validation_0-xgb_custom_metric:-0.10509
# [34]	validation_0-logloss:0.02992	validation_0-xgb_custom_metric:-0.10504
# [35]	validation_0-logloss:0.02787	validation_0-xgb_custom_metric:-0.10422
# [36]	validation_0-logloss:0.02599	validation_0-xgb_custom_metric:-0.10284
# [37]	validation_0-logloss:0.02427	validation_0-xgb_custom_metric:-0.10218
# [38]	validation_0-logloss:0.02269	validation_0-xgb_custom_metric:-0.10180
# [39]	validation_0-logloss:0.02124	validation_0-xgb_custom_metric:-0.11191
# [40]	validation_0-logloss:0.01991	validation_0-xgb_custom_metric:-0.12444
# [41]	validation_0-logloss:0.01869	validation_0-xgb_custom_metric:-0.12396
# [42]	validation_0-logloss:0.01756	validation_0-xgb_custom_metric:-0.12834
# [43]	validation_0-logloss:0.01654	validation_0-xgb_custom_metric:-0.12883
# [44]	validation_0-logloss:0.01559	validation_0-xgb_custom_metric:-0.12924
# [45]	validation_0-logloss:0.01472	validation_0-xgb_custom_metric:-0.12972
# [46]	validation_0-logloss:0.01391	validation_0-xgb_custom_metric:-0.13472
# [47]	validation_0-logloss:0.01319	validation_0-xgb_custom_metric:-0.14025
# [48]	validation_0-logloss:0.01251	validation_0-xgb_custom_metric:-0.14016
# [49]	validation_0-logloss:0.01189	validation_0-xgb_custom_metric:-0.13958
# [50]	validation_0-logloss:0.01133	validation_0-xgb_custom_metric:-0.14026
# [51]	validation_0-logloss:0.01080	validation_0-xgb_custom_metric:-0.14261
# [52]	validation_0-logloss:0.01033	validation_0-xgb_custom_metric:-0.14237
# [53]	validation_0-logloss:0.00993	validation_0-xgb_custom_metric:-0.14098
# [54]	validation_0-logloss:0.00951	validation_0-xgb_custom_metric:-0.14230
# [55]	validation_0-logloss:0.00914	validation_0-xgb_custom_metric:-0.14326
# [56]	validation_0-logloss:0.00883	validation_0-xgb_custom_metric:-0.14058
# [57]	validation_0-logloss:0.00852	validation_0-xgb_custom_metric:-0.14263
# [58]	validation_0-logloss:0.00823	validation_0-xgb_custom_metric:-0.14212
# [59]	validation_0-logloss:0.00797	validation_0-xgb_custom_metric:-0.13990
# [60]	validation_0-logloss:0.00773	validation_0-xgb_custom_metric:-0.13871
# [61]	validation_0-logloss:0.00750	validation_0-xgb_custom_metric:-0.13908
# [62]	validation_0-logloss:0.00728	validation_0-xgb_custom_metric:-0.13851
# [63]	validation_0-logloss:0.00709	validation_0-xgb_custom_metric:-0.13810
# [64]	validation_0-logloss:0.00691	validation_0-xgb_custom_metric:-0.13776
# [65]	validation_0-logloss:0.00676	validation_0-xgb_custom_metric:-0.13717
# [66]	validation_0-logloss:0.00660	validation_0-xgb_custom_metric:-0.13824
# [67]	validation_0-logloss:0.00646	validation_0-xgb_custom_metric:-0.13773
# [68]	validation_0-logloss:0.00635	validation_0-xgb_custom_metric:-0.13616
# [69]	validation_0-logloss:0.00624	validation_0-xgb_custom_metric:-0.13567
# [70]	validation_0-logloss:0.00614	validation_0-xgb_custom_metric:-0.13420
# [71]	validation_0-logloss:0.00605	validation_0-xgb_custom_metric:-0.13327
# [72]	validation_0-logloss:0.00596	validation_0-xgb_custom_metric:-0.13368
# [73]	validation_0-logloss:0.00589	validation_0-xgb_custom_metric:-0.13236
# [74]	validation_0-logloss:0.00583	validation_0-xgb_custom_metric:-0.13132
# [75]	validation_0-logloss:0.00576	validation_0-xgb_custom_metric:-0.13177
# [76]	validation_0-logloss:0.00570	validation_0-xgb_custom_metric:-0.13318
# [77]	validation_0-logloss:0.00564	validation_0-xgb_custom_metric:-0.13570
# [78]	validation_0-logloss:0.00559	validation_0-xgb_custom_metric:-0.14207
# [79]	validation_0-logloss:0.00554	validation_0-xgb_custom_metric:-0.14228
# [80]	validation_0-logloss:0.00552	validation_0-xgb_custom_metric:-0.14433
# [81]	validation_0-logloss:0.00546	validation_0-xgb_custom_metric:-0.14419
# [82]	validation_0-logloss:0.00542	validation_0-xgb_custom_metric:-0.14304
# [83]	validation_0-logloss:0.00538	validation_0-xgb_custom_metric:-0.14537
# [84]	validation_0-logloss:0.00534	validation_0-xgb_custom_metric:-0.14557
# [85]	validation_0-logloss:0.00531	validation_0-xgb_custom_metric:-0.14533
# [86]	validation_0-logloss:0.00529	validation_0-xgb_custom_metric:-0.14600
# [87]	validation_0-logloss:0.00526	validation_0-xgb_custom_metric:-0.14508
# [88]	validation_0-logloss:0.00522	validation_0-xgb_custom_metric:-0.14494
# [89]	validation_0-logloss:0.00520	validation_0-xgb_custom_metric:-0.14491
# [90]	validation_0-logloss:0.00517	validation_0-xgb_custom_metric:-0.14624
# [91]	validation_0-logloss:0.00515	validation_0-xgb_custom_metric:-0.14620
# [92]	validation_0-logloss:0.00512	validation_0-xgb_custom_metric:-0.14814
# [93]	validation_0-logloss:0.00509	validation_0-xgb_custom_metric:-0.14795
# [94]	validation_0-logloss:0.00508	validation_0-xgb_custom_metric:-0.14860
# [95]	validation_0-logloss:0.00505	validation_0-xgb_custom_metric:-0.14810
# [96]	validation_0-logloss:0.00505	validation_0-xgb_custom_metric:-0.14670
# [97]	validation_0-logloss:0.00504	validation_0-xgb_custom_metric:-0.14666
# [98]	validation_0-logloss:0.00501	validation_0-xgb_custom_metric:-0.14905
# [99]	validation_0-logloss:0.00501	validation_0-xgb_custom_metric:-0.14825
# [0.15902215116751073, 0.14493341743324567, 0.14905422987170597, 0.15790745262614467]
# /usr/local/lib/python3.11/dist-packages/catboost/core.py:2311: UserWarning: Failed to import numba for optimizing custom metrics and objectives
#   _check_train_params(params)
# Default metric period is 5 because PythonUserDefinedPerObject is/are not implemented for GPU
# 0:	learn: 0.0278139	test: 0.0308909	best: 0.0308909 (0)	total: 39ms	remaining: 38.9s
# 200:	learn: 0.1765220	test: 0.1754662	best: 0.1754662 (200)	total: 7.13s	remaining: 28.3s
# 400:	learn: 0.1845159	test: 0.1770832	best: 0.1771501 (395)	total: 14.3s	remaining: 21.4s
# 600:	learn: 0.1891888	test: 0.1762037	best: 0.1774785 (440)	total: 21.5s	remaining: 14.3s
# 800:	learn: 0.1923116	test: 0.1770607	best: 0.1774785 (440)	total: 28.8s	remaining: 7.17s
# 999:	learn: 0.1945273	test: 0.1763955	best: 0.1774785 (440)	total: 36s	remaining: 0us
# bestTest = 0.1774785008
# bestIteration = 440
# Shrink model to first 441 iterations.
# /usr/local/lib/python3.11/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [0]	validation_0-logloss:0.61237	validation_0-xgb_custom_metric:-0.03536
# [1]	validation_0-logloss:0.54414	validation_0-xgb_custom_metric:-0.03536
# [2]	validation_0-logloss:0.48579	validation_0-xgb_custom_metric:-0.03536
# [3]	validation_0-logloss:0.43541	validation_0-xgb_custom_metric:-0.04598
# [4]	validation_0-logloss:0.39149	validation_0-xgb_custom_metric:-0.04988
# [5]	validation_0-logloss:0.35296	validation_0-xgb_custom_metric:-0.04988
# [6]	validation_0-logloss:0.31896	validation_0-xgb_custom_metric:-0.04988
# [7]	validation_0-logloss:0.28887	validation_0-xgb_custom_metric:-0.05422
# [8]	validation_0-logloss:0.26209	validation_0-xgb_custom_metric:-0.05756
# [9]	validation_0-logloss:0.23814	validation_0-xgb_custom_metric:-0.05930
# [10]	validation_0-logloss:0.21670	validation_0-xgb_custom_metric:-0.06346
# [11]	validation_0-logloss:0.19746	validation_0-xgb_custom_metric:-0.06822
# [12]	validation_0-logloss:0.18013	validation_0-xgb_custom_metric:-0.07047
# [13]	validation_0-logloss:0.16451	validation_0-xgb_custom_metric:-0.07047
# [14]	validation_0-logloss:0.15037	validation_0-xgb_custom_metric:-0.07236
# [15]	validation_0-logloss:0.13762	validation_0-xgb_custom_metric:-0.09027
# [16]	validation_0-logloss:0.12605	validation_0-xgb_custom_metric:-0.10816
# [17]	validation_0-logloss:0.11554	validation_0-xgb_custom_metric:-0.10816
# [18]	validation_0-logloss:0.10601	validation_0-xgb_custom_metric:-0.10819
# [19]	validation_0-logloss:0.09736	validation_0-xgb_custom_metric:-0.11256
# [20]	validation_0-logloss:0.08948	validation_0-xgb_custom_metric:-0.11235
# [21]	validation_0-logloss:0.08229	validation_0-xgb_custom_metric:-0.11235
# [22]	validation_0-logloss:0.07575	validation_0-xgb_custom_metric:-0.11779
# [23]	validation_0-logloss:0.06978	validation_0-xgb_custom_metric:-0.11782
# [24]	validation_0-logloss:0.06435	validation_0-xgb_custom_metric:-0.12374
# [25]	validation_0-logloss:0.05935	validation_0-xgb_custom_metric:-0.12363
# [26]	validation_0-logloss:0.05482	validation_0-xgb_custom_metric:-0.12319
# [27]	validation_0-logloss:0.05067	validation_0-xgb_custom_metric:-0.12274
# [28]	validation_0-logloss:0.04689	validation_0-xgb_custom_metric:-0.12232
# [29]	validation_0-logloss:0.04342	validation_0-xgb_custom_metric:-0.12189
# [30]	validation_0-logloss:0.04023	validation_0-xgb_custom_metric:-0.12152
# [31]	validation_0-logloss:0.03733	validation_0-xgb_custom_metric:-0.12130
# [32]	validation_0-logloss:0.03469	validation_0-xgb_custom_metric:-0.13374
# [33]	validation_0-logloss:0.03223	validation_0-xgb_custom_metric:-0.13809
# [34]	validation_0-logloss:0.03000	validation_0-xgb_custom_metric:-0.13796
# [35]	validation_0-logloss:0.02796	validation_0-xgb_custom_metric:-0.13829
# [36]	validation_0-logloss:0.02608	validation_0-xgb_custom_metric:-0.14201
# [37]	validation_0-logloss:0.02438	validation_0-xgb_custom_metric:-0.15537
# [38]	validation_0-logloss:0.02280	validation_0-xgb_custom_metric:-0.15518
# [39]	validation_0-logloss:0.02135	validation_0-xgb_custom_metric:-0.15545
# [40]	validation_0-logloss:0.02003	validation_0-xgb_custom_metric:-0.15594
# [41]	validation_0-logloss:0.01883	validation_0-xgb_custom_metric:-0.15559
# [42]	validation_0-logloss:0.01771	validation_0-xgb_custom_metric:-0.15606
# [43]	validation_0-logloss:0.01670	validation_0-xgb_custom_metric:-0.15599
# [44]	validation_0-logloss:0.01576	validation_0-xgb_custom_metric:-0.16066
# [45]	validation_0-logloss:0.01489	validation_0-xgb_custom_metric:-0.16074
# [46]	validation_0-logloss:0.01412	validation_0-xgb_custom_metric:-0.16000
# [47]	validation_0-logloss:0.01340	validation_0-xgb_custom_metric:-0.16385
# [48]	validation_0-logloss:0.01274	validation_0-xgb_custom_metric:-0.16397
# [49]	validation_0-logloss:0.01215	validation_0-xgb_custom_metric:-0.16335
# [50]	validation_0-logloss:0.01159	validation_0-xgb_custom_metric:-0.16340
# [51]	validation_0-logloss:0.01107	validation_0-xgb_custom_metric:-0.16291
# [52]	validation_0-logloss:0.01060	validation_0-xgb_custom_metric:-0.16228
# [53]	validation_0-logloss:0.01016	validation_0-xgb_custom_metric:-0.16174
# [54]	validation_0-logloss:0.00975	validation_0-xgb_custom_metric:-0.16104
# [55]	validation_0-logloss:0.00937	validation_0-xgb_custom_metric:-0.16080
# [56]	validation_0-logloss:0.00903	validation_0-xgb_custom_metric:-0.16111
# [57]	validation_0-logloss:0.00872	validation_0-xgb_custom_metric:-0.16087
# [58]	validation_0-logloss:0.00845	validation_0-xgb_custom_metric:-0.16112
# [59]	validation_0-logloss:0.00819	validation_0-xgb_custom_metric:-0.16159
# [60]	validation_0-logloss:0.00794	validation_0-xgb_custom_metric:-0.16250
# [61]	validation_0-logloss:0.00772	validation_0-xgb_custom_metric:-0.16247
# [62]	validation_0-logloss:0.00751	validation_0-xgb_custom_metric:-0.16548
# [63]	validation_0-logloss:0.00732	validation_0-xgb_custom_metric:-0.16425
# [64]	validation_0-logloss:0.00715	validation_0-xgb_custom_metric:-0.16680
# [65]	validation_0-logloss:0.00697	validation_0-xgb_custom_metric:-0.16626
# [66]	validation_0-logloss:0.00682	validation_0-xgb_custom_metric:-0.16541
# [67]	validation_0-logloss:0.00670	validation_0-xgb_custom_metric:-0.16836
# [68]	validation_0-logloss:0.00657	validation_0-xgb_custom_metric:-0.16830
# [69]	validation_0-logloss:0.00647	validation_0-xgb_custom_metric:-0.16895
# [70]	validation_0-logloss:0.00634	validation_0-xgb_custom_metric:-0.16983
# [71]	validation_0-logloss:0.00625	validation_0-xgb_custom_metric:-0.16930
# [72]	validation_0-logloss:0.00619	validation_0-xgb_custom_metric:-0.16914
# [73]	validation_0-logloss:0.00610	validation_0-xgb_custom_metric:-0.16944
# [74]	validation_0-logloss:0.00602	validation_0-xgb_custom_metric:-0.16970
# [75]	validation_0-logloss:0.00596	validation_0-xgb_custom_metric:-0.17016
# [76]	validation_0-logloss:0.00588	validation_0-xgb_custom_metric:-0.17066
# [77]	validation_0-logloss:0.00581	validation_0-xgb_custom_metric:-0.17167
# [78]	validation_0-logloss:0.00575	validation_0-xgb_custom_metric:-0.17462
# [79]	validation_0-logloss:0.00569	validation_0-xgb_custom_metric:-0.17534
# [80]	validation_0-logloss:0.00563	validation_0-xgb_custom_metric:-0.17535
# [81]	validation_0-logloss:0.00558	validation_0-xgb_custom_metric:-0.17532
# [82]	validation_0-logloss:0.00553	validation_0-xgb_custom_metric:-0.17627
# [83]	validation_0-logloss:0.00550	validation_0-xgb_custom_metric:-0.17585
# [84]	validation_0-logloss:0.00546	validation_0-xgb_custom_metric:-0.17582
# [85]	validation_0-logloss:0.00544	validation_0-xgb_custom_metric:-0.17626
# [86]	validation_0-logloss:0.00541	validation_0-xgb_custom_metric:-0.17678
# [87]	validation_0-logloss:0.00540	validation_0-xgb_custom_metric:-0.17595
# [88]	validation_0-logloss:0.00537	validation_0-xgb_custom_metric:-0.17612
# [89]	validation_0-logloss:0.00536	validation_0-xgb_custom_metric:-0.17702
# [90]	validation_0-logloss:0.00533	validation_0-xgb_custom_metric:-0.17744
# [91]	validation_0-logloss:0.00529	validation_0-xgb_custom_metric:-0.17806
# [92]	validation_0-logloss:0.00528	validation_0-xgb_custom_metric:-0.17754
# [93]	validation_0-logloss:0.00525	validation_0-xgb_custom_metric:-0.17716
# [94]	validation_0-logloss:0.00523	validation_0-xgb_custom_metric:-0.17675
# [95]	validation_0-logloss:0.00520	validation_0-xgb_custom_metric:-0.17700
# [96]	validation_0-logloss:0.00518	validation_0-xgb_custom_metric:-0.17784
# [97]	validation_0-logloss:0.00514	validation_0-xgb_custom_metric:-0.17766
# [98]	validation_0-logloss:0.00515	validation_0-xgb_custom_metric:-0.17817
# [99]	validation_0-logloss:0.00513	validation_0-xgb_custom_metric:-0.17849
# [0.17747850080913474, 0.16469779458386674, 0.17849016938428694, 0.18298378080221284]
# /usr/local/lib/python3.11/dist-packages/catboost/core.py:2311: UserWarning: Failed to import numba for optimizing custom metrics and objectives
#   _check_train_params(params)
# Default metric period is 5 because PythonUserDefinedPerObject is/are not implemented for GPU
# 0:	learn: 0.0286892	test: 0.0276001	best: 0.0276001 (0)	total: 36ms	remaining: 35.9s
# 200:	learn: 0.1757490	test: 0.1633765	best: 0.1633943 (190)	total: 6.98s	remaining: 27.8s
# 400:	learn: 0.1841716	test: 0.1680982	best: 0.1682363 (395)	total: 14.2s	remaining: 21.2s
# 600:	learn: 0.1894727	test: 0.1690273	best: 0.1693923 (575)	total: 21.3s	remaining: 14.1s
# 800:	learn: 0.1925122	test: 0.1697361	best: 0.1700028 (780)	total: 28.4s	remaining: 7.05s
# 999:	learn: 0.1946847	test: 0.1705472	best: 0.1711585 (975)	total: 35.4s	remaining: 0us
# bestTest = 0.1711584834
# bestIteration = 975
# Shrink model to first 976 iterations.
# /usr/local/lib/python3.11/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [0]	validation_0-logloss:0.61232	validation_0-xgb_custom_metric:-0.02984
# [1]	validation_0-logloss:0.54414	validation_0-xgb_custom_metric:-0.02984
# [2]	validation_0-logloss:0.48584	validation_0-xgb_custom_metric:-0.03037
# [3]	validation_0-logloss:0.43546	validation_0-xgb_custom_metric:-0.03604
# [4]	validation_0-logloss:0.39150	validation_0-xgb_custom_metric:-0.03604
# [5]	validation_0-logloss:0.35297	validation_0-xgb_custom_metric:-0.03764
# [6]	validation_0-logloss:0.31898	validation_0-xgb_custom_metric:-0.03764
# [7]	validation_0-logloss:0.28887	validation_0-xgb_custom_metric:-0.04314
# [8]	validation_0-logloss:0.26209	validation_0-xgb_custom_metric:-0.04301
# [9]	validation_0-logloss:0.23816	validation_0-xgb_custom_metric:-0.04280
# [10]	validation_0-logloss:0.21671	validation_0-xgb_custom_metric:-0.04280
# [11]	validation_0-logloss:0.19745	validation_0-xgb_custom_metric:-0.04269
# [12]	validation_0-logloss:0.18010	validation_0-xgb_custom_metric:-0.04246
# [13]	validation_0-logloss:0.16448	validation_0-xgb_custom_metric:-0.05103
# [14]	validation_0-logloss:0.15035	validation_0-xgb_custom_metric:-0.05103
# [15]	validation_0-logloss:0.13759	validation_0-xgb_custom_metric:-0.05103
# [16]	validation_0-logloss:0.12601	validation_0-xgb_custom_metric:-0.05092
# [17]	validation_0-logloss:0.11552	validation_0-xgb_custom_metric:-0.05087
# [18]	validation_0-logloss:0.10600	validation_0-xgb_custom_metric:-0.05237
# [19]	validation_0-logloss:0.09730	validation_0-xgb_custom_metric:-0.05237
# [20]	validation_0-logloss:0.08942	validation_0-xgb_custom_metric:-0.05371
# [21]	validation_0-logloss:0.08225	validation_0-xgb_custom_metric:-0.06627
# [22]	validation_0-logloss:0.07570	validation_0-xgb_custom_metric:-0.06616
# [23]	validation_0-logloss:0.06973	validation_0-xgb_custom_metric:-0.10758
# [24]	validation_0-logloss:0.06427	validation_0-xgb_custom_metric:-0.10758
# [25]	validation_0-logloss:0.05930	validation_0-xgb_custom_metric:-0.11269
# [26]	validation_0-logloss:0.05476	validation_0-xgb_custom_metric:-0.11261
# [27]	validation_0-logloss:0.05064	validation_0-xgb_custom_metric:-0.11579
# [28]	validation_0-logloss:0.04686	validation_0-xgb_custom_metric:-0.11548
# [29]	validation_0-logloss:0.04337	validation_0-xgb_custom_metric:-0.11920
# [30]	validation_0-logloss:0.04017	validation_0-xgb_custom_metric:-0.13521
# [31]	validation_0-logloss:0.03727	validation_0-xgb_custom_metric:-0.14061
# [32]	validation_0-logloss:0.03459	validation_0-xgb_custom_metric:-0.14005
# [33]	validation_0-logloss:0.03213	validation_0-xgb_custom_metric:-0.13987
# [34]	validation_0-logloss:0.02989	validation_0-xgb_custom_metric:-0.13995
# [35]	validation_0-logloss:0.02786	validation_0-xgb_custom_metric:-0.13951
# [36]	validation_0-logloss:0.02598	validation_0-xgb_custom_metric:-0.13916
# [37]	validation_0-logloss:0.02426	validation_0-xgb_custom_metric:-0.14004
# [38]	validation_0-logloss:0.02268	validation_0-xgb_custom_metric:-0.14462
# [39]	validation_0-logloss:0.02125	validation_0-xgb_custom_metric:-0.14481
# [40]	validation_0-logloss:0.01993	validation_0-xgb_custom_metric:-0.14490
# [41]	validation_0-logloss:0.01872	validation_0-xgb_custom_metric:-0.14497
# [42]	validation_0-logloss:0.01760	validation_0-xgb_custom_metric:-0.14467
# [43]	validation_0-logloss:0.01658	validation_0-xgb_custom_metric:-0.14517
# [44]	validation_0-logloss:0.01564	validation_0-xgb_custom_metric:-0.14557
# [45]	validation_0-logloss:0.01477	validation_0-xgb_custom_metric:-0.14907
# [46]	validation_0-logloss:0.01397	validation_0-xgb_custom_metric:-0.14849
# [47]	validation_0-logloss:0.01327	validation_0-xgb_custom_metric:-0.14921
# [48]	validation_0-logloss:0.01258	validation_0-xgb_custom_metric:-0.15312
# [49]	validation_0-logloss:0.01197	validation_0-xgb_custom_metric:-0.15666
# [50]	validation_0-logloss:0.01141	validation_0-xgb_custom_metric:-0.16319
# [51]	validation_0-logloss:0.01090	validation_0-xgb_custom_metric:-0.16241
# [52]	validation_0-logloss:0.01042	validation_0-xgb_custom_metric:-0.16245
# [53]	validation_0-logloss:0.00997	validation_0-xgb_custom_metric:-0.16159
# [54]	validation_0-logloss:0.00957	validation_0-xgb_custom_metric:-0.16181
# [55]	validation_0-logloss:0.00921	validation_0-xgb_custom_metric:-0.16660
# [56]	validation_0-logloss:0.00887	validation_0-xgb_custom_metric:-0.16838
# [57]	validation_0-logloss:0.00857	validation_0-xgb_custom_metric:-0.16740
# [58]	validation_0-logloss:0.00828	validation_0-xgb_custom_metric:-0.16787
# [59]	validation_0-logloss:0.00802	validation_0-xgb_custom_metric:-0.16753
# [60]	validation_0-logloss:0.00778	validation_0-xgb_custom_metric:-0.16686
# [61]	validation_0-logloss:0.00756	validation_0-xgb_custom_metric:-0.16654
# [62]	validation_0-logloss:0.00736	validation_0-xgb_custom_metric:-0.17120
# [63]	validation_0-logloss:0.00718	validation_0-xgb_custom_metric:-0.17089
# [64]	validation_0-logloss:0.00702	validation_0-xgb_custom_metric:-0.17096
# [65]	validation_0-logloss:0.00686	validation_0-xgb_custom_metric:-0.17159
# [66]	validation_0-logloss:0.00670	validation_0-xgb_custom_metric:-0.17207
# [67]	validation_0-logloss:0.00656	validation_0-xgb_custom_metric:-0.17123
# [68]	validation_0-logloss:0.00644	validation_0-xgb_custom_metric:-0.17078
# [69]	validation_0-logloss:0.00632	validation_0-xgb_custom_metric:-0.17037
# [70]	validation_0-logloss:0.00622	validation_0-xgb_custom_metric:-0.16948
# [71]	validation_0-logloss:0.00611	validation_0-xgb_custom_metric:-0.16889
# [72]	validation_0-logloss:0.00600	validation_0-xgb_custom_metric:-0.17177
# [73]	validation_0-logloss:0.00593	validation_0-xgb_custom_metric:-0.17144
# [74]	validation_0-logloss:0.00587	validation_0-xgb_custom_metric:-0.17266
# [75]	validation_0-logloss:0.00579	validation_0-xgb_custom_metric:-0.17177
# [76]	validation_0-logloss:0.00572	validation_0-xgb_custom_metric:-0.17251
# [77]	validation_0-logloss:0.00567	validation_0-xgb_custom_metric:-0.17273
# [78]	validation_0-logloss:0.00562	validation_0-xgb_custom_metric:-0.17319
# [79]	validation_0-logloss:0.00557	validation_0-xgb_custom_metric:-0.17281
# [80]	validation_0-logloss:0.00553	validation_0-xgb_custom_metric:-0.17282
# [81]	validation_0-logloss:0.00549	validation_0-xgb_custom_metric:-0.17318
# [82]	validation_0-logloss:0.00545	validation_0-xgb_custom_metric:-0.17278
# [83]	validation_0-logloss:0.00541	validation_0-xgb_custom_metric:-0.17236
# [84]	validation_0-logloss:0.00538	validation_0-xgb_custom_metric:-0.17177
# [85]	validation_0-logloss:0.00535	validation_0-xgb_custom_metric:-0.17144
# [86]	validation_0-logloss:0.00531	validation_0-xgb_custom_metric:-0.17188
# [87]	validation_0-logloss:0.00526	validation_0-xgb_custom_metric:-0.17194
# [88]	validation_0-logloss:0.00523	validation_0-xgb_custom_metric:-0.17221
# [89]	validation_0-logloss:0.00521	validation_0-xgb_custom_metric:-0.17413
# [90]	validation_0-logloss:0.00519	validation_0-xgb_custom_metric:-0.17440
# [91]	validation_0-logloss:0.00517	validation_0-xgb_custom_metric:-0.17383
# [92]	validation_0-logloss:0.00515	validation_0-xgb_custom_metric:-0.17335
# [93]	validation_0-logloss:0.00514	validation_0-xgb_custom_metric:-0.17253
# [94]	validation_0-logloss:0.00511	validation_0-xgb_custom_metric:-0.17204
# [95]	validation_0-logloss:0.00510	validation_0-xgb_custom_metric:-0.17252
# [96]	validation_0-logloss:0.00508	validation_0-xgb_custom_metric:-0.17227
# [97]	validation_0-logloss:0.00507	validation_0-xgb_custom_metric:-0.17244
# [98]	validation_0-logloss:0.00505	validation_0-xgb_custom_metric:-0.17208
# [99]	validation_0-logloss:0.00503	validation_0-xgb_custom_metric:-0.17219
# [0.17115875859677507, 0.16100714712284955, 0.17439993890407107, 0.17505824753758634]
# /usr/local/lib/python3.11/dist-packages/catboost/core.py:2311: UserWarning: Failed to import numba for optimizing custom metrics and objectives
#   _check_train_params(params)
# Default metric period is 5 because PythonUserDefinedPerObject is/are not implemented for GPU
# 0:	learn: 0.0290801	test: 0.0258610	best: 0.0258610 (0)	total: 36.1ms	remaining: 36.1s
# 200:	learn: 0.1778185	test: 0.1460303	best: 0.1466810 (190)	total: 7s	remaining: 27.8s
# 400:	learn: 0.1864046	test: 0.1511416	best: 0.1512514 (390)	total: 14.4s	remaining: 21.5s
# 600:	learn: 0.1914800	test: 0.1556895	best: 0.1556895 (600)	total: 21.5s	remaining: 14.3s
# 800:	learn: 0.1948858	test: 0.1572787	best: 0.1579061 (700)	total: 28.8s	remaining: 7.15s
