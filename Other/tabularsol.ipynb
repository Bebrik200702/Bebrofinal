# %%
import numpy as np
import pandas as pd
import polars as pl
from catboost import CatBoostClassifier, Pool, cv
import lightgbm as lgb
import xgboost as xgb
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import roc_auc_score, roc_curve, auc
from functools import partial 
from sklearn.base import BaseEstimator
from tqdm.auto import trange
from sklearn.model_selection import train_test_split, StratifiedKFold, StratifiedGroupKFold

# %%
train_data = pl.read_csv('/kaggle/input/isic-2024-challenge/train-metadata.csv')
test_data = pl.read_csv('/kaggle/input/isic-2024-challenge/test-metadata.csv')

# %%
def process_data(data):
    return (
        data
        .with_columns(
                pl.col('age_approx').cast(pl.String).replace('NA', np.nan).cast(pl.Float64),
            )
        .with_columns(
                lesion_size_ratio              = pl.col('tbp_lv_minorAxisMM') / pl.col('clin_size_long_diam_mm'),
                lesion_shape_index             = pl.col('tbp_lv_areaMM2') / (pl.col('tbp_lv_perimeterMM') ** 2),
                hue_contrast                   = (pl.col('tbp_lv_H') - pl.col('tbp_lv_Hext')).abs(),
                luminance_contrast             = (pl.col('tbp_lv_L') - pl.col('tbp_lv_Lext')).abs(),
                lesion_color_difference        = (pl.col('tbp_lv_deltaA') ** 2 + pl.col('tbp_lv_deltaB') ** 2 + pl.col('tbp_lv_deltaL') ** 2).sqrt(),
                border_complexity              = pl.col('tbp_lv_norm_border') + pl.col('tbp_lv_symm_2axis'),
                color_uniformity               = pl.col('tbp_lv_color_std_mean') / (pl.col('tbp_lv_radial_color_std_max') + 1e-6),
            )
        .with_columns(
                position_distance_3d           = (pl.col('tbp_lv_x') ** 2 + pl.col('tbp_lv_y') ** 2 + pl.col('tbp_lv_z') ** 2).sqrt(),
                perimeter_to_area_ratio        = pl.col('tbp_lv_perimeterMM') / pl.col('tbp_lv_areaMM2'),
                area_to_perimeter_ratio        = pl.col('tbp_lv_areaMM2') / pl.col('tbp_lv_perimeterMM'),
                lesion_visibility_score        = pl.col('tbp_lv_deltaLBnorm') + pl.col('tbp_lv_norm_color'),
                combined_anatomical_site       = pl.col('anatom_site_general') + '_' + pl.col('tbp_lv_location'),
                symmetry_border_consistency    = pl.col('tbp_lv_symm_2axis') * pl.col('tbp_lv_norm_border'),
                consistency_symmetry_border    = pl.col('tbp_lv_symm_2axis') * pl.col('tbp_lv_norm_border') / (pl.col('tbp_lv_symm_2axis') + pl.col('tbp_lv_norm_border')),
            )
        .with_columns(
                color_consistency              = pl.col('tbp_lv_stdL') / pl.col('tbp_lv_Lext'),
                consistency_color              = pl.col('tbp_lv_stdL') * pl.col('tbp_lv_Lext') / (pl.col('tbp_lv_stdL') + pl.col('tbp_lv_Lext')),
                size_age_interaction           = pl.col('clin_size_long_diam_mm') * pl.col('age_approx'),
                hue_color_std_interaction      = pl.col('tbp_lv_H') * pl.col('tbp_lv_color_std_mean'),
                lesion_severity_index          = (pl.col('tbp_lv_norm_border') + pl.col('tbp_lv_norm_color') + pl.col('tbp_lv_eccentricity')) / 3,
                shape_complexity_index         = pl.col('border_complexity') + pl.col('lesion_shape_index'),
                color_contrast_index           = pl.col('tbp_lv_deltaA') + pl.col('tbp_lv_deltaB') + pl.col('tbp_lv_deltaL') + pl.col('tbp_lv_deltaLBnorm'),
            )
        .with_columns(
                log_lesion_area                = (pl.col('tbp_lv_areaMM2') + 1).log(),
                normalized_lesion_size         = pl.col('clin_size_long_diam_mm') / pl.col('age_approx'),
                mean_hue_difference            = (pl.col('tbp_lv_H') + pl.col('tbp_lv_Hext')) / 2,
                std_dev_contrast               = ((pl.col('tbp_lv_deltaA') ** 2 + pl.col('tbp_lv_deltaB') ** 2 + pl.col('tbp_lv_deltaL') ** 2) / 3).sqrt(),
                color_shape_composite_index    = (pl.col('tbp_lv_color_std_mean') + pl.col('tbp_lv_area_perim_ratio') + pl.col('tbp_lv_symm_2axis')) / 3,
                lesion_orientation_3d          = pl.arctan2(pl.col('tbp_lv_y'), pl.col('tbp_lv_x')),
                overall_color_difference       = (pl.col('tbp_lv_deltaA') + pl.col('tbp_lv_deltaB') + pl.col('tbp_lv_deltaL')) / 3,
            )
        .with_columns(
                symmetry_perimeter_interaction = pl.col('tbp_lv_symm_2axis') * pl.col('tbp_lv_perimeterMM'),
                comprehensive_lesion_index     = (pl.col('tbp_lv_area_perim_ratio') + pl.col('tbp_lv_eccentricity') + pl.col('tbp_lv_norm_color') + pl.col('tbp_lv_symm_2axis')) / 4,
                color_variance_ratio           = pl.col('tbp_lv_color_std_mean') / pl.col('tbp_lv_stdLExt'),
                border_color_interaction       = pl.col('tbp_lv_norm_border') * pl.col('tbp_lv_norm_color'),
                border_color_interaction_2     = pl.col('tbp_lv_norm_border') * pl.col('tbp_lv_norm_color') / (pl.col('tbp_lv_norm_border') + pl.col('tbp_lv_norm_color')),
                size_color_contrast_ratio      = pl.col('clin_size_long_diam_mm') / pl.col('tbp_lv_deltaLBnorm'),
                age_normalized_nevi_confidence = pl.col('tbp_lv_nevi_confidence') / pl.col('age_approx'),
                age_normalized_nevi_confidence_2 = (pl.col('clin_size_long_diam_mm')**2 + pl.col('age_approx')**2).sqrt(),
                color_asymmetry_index          = pl.col('tbp_lv_radial_color_std_max') * pl.col('tbp_lv_symm_2axis'),
            )
        .with_columns(
                volume_approximation_3d        = pl.col('tbp_lv_areaMM2') * (pl.col('tbp_lv_x')**2 + pl.col('tbp_lv_y')**2 + pl.col('tbp_lv_z')**2).sqrt(),
                color_range                    = (pl.col('tbp_lv_L') - pl.col('tbp_lv_Lext')).abs() + (pl.col('tbp_lv_A') - pl.col('tbp_lv_Aext')).abs() + (pl.col('tbp_lv_B') - pl.col('tbp_lv_Bext')).abs(),
                shape_color_consistency        = pl.col('tbp_lv_eccentricity') * pl.col('tbp_lv_color_std_mean'),
                border_length_ratio            = pl.col('tbp_lv_perimeterMM') / (2 * np.pi * (pl.col('tbp_lv_areaMM2') / np.pi).sqrt()),
                age_size_symmetry_index        = pl.col('age_approx') * pl.col('clin_size_long_diam_mm') * pl.col('tbp_lv_symm_2axis'),
                index_age_size_symmetry        = pl.col('age_approx') * pl.col('tbp_lv_areaMM2') * pl.col('tbp_lv_symm_2axis'),
            )
        .with_columns(
            ((pl.col(col) - pl.col(col).mean().over('patient_id')) / (pl.col(col).std().over('patient_id') + 1e-5)).alias(f'{col}_patient_norm') for col in (num_cols + new_cols)
        )

        .with_columns(
                count_per_patient = pl.col('isic_id').count().over('patient_id'),
                age_difference = (pl.col('age_approx').max().over('patient_id') - pl.col('age_approx').min().over('patient_id')),
                is_tbp_tile_type = pl.col('tbp_tile_type').map_elements(lambda x: 1 if x == '3D: white' else 0)
        )
        .with_columns(
                tbp_tile_type_mean = pl.col('is_tbp_tile_type').mean().over('patient_id'),
                tbp_tile_type_sum = pl.col('is_tbp_tile_type').sum().over('patient_id'),
                tbp_tile_type_inv = pl.col('count_per_patient') - pl.col('is_tbp_tile_type').sum().over('patient_id'),
        )
        .to_pandas()
    )

# %%
def p_auc_tpr(v_gt, v_pred, min_tpr=None, sample_weight=None):
    """Computes the area under the AUC above a minumum TPR.

    Args:
        v_gt: ground truth vector (1s and 0s)
        v_p: predictions vector of scores ranging [0, 1]
        min_tpr: minimum true positive threshold (sensitivity)

    Returns:
        Float value range [0, 1]
    """
    if len(np.unique(v_gt)) != 2:
        raise ValueError(
            "Only one class present in y_true. ROC AUC score "
            "is not defined in that case."
        )
    
    # redefine the target. set 0s to 1s and 1s to 0s
    v_gt = abs(np.asarray(v_gt)-1)
    v_pred = abs(np.asarray(v_pred)-1)
    max_fpr = abs(1-min_tpr)
    
    # using sklearn.metric functions: (1) roc_curve and (2) auc
    fpr, tpr, _ = roc_curve(v_gt, v_pred, sample_weight=sample_weight)
    if max_fpr is None or max_fpr == 1:
        return auc(fpr, tpr)
    if max_fpr <= 0 or max_fpr > 1:
        raise ValueError("Expected min_tpr in range [0, 1), got: %r" % min_tpr)

    # Add a single point at max_fpr by linear interpolation
    stop = np.searchsorted(fpr, max_fpr, "right")
    x_interp = [fpr[stop - 1], fpr[stop]]
    y_interp = [tpr[stop - 1], tpr[stop]]
    tpr = np.append(tpr[:stop], np.interp(max_fpr, x_interp, y_interp))
    fpr = np.append(fpr[:stop], max_fpr)
    partial_auc = auc(fpr, tpr)
    return(partial_auc)

# %%
class PRAUCMetric:
    def is_max_optimal(self):
        return True # greater is better

    def evaluate(self, approxes, target, weight):
        assert len(approxes) == 1
        assert len(target) == len(approxes[0])

        approx = approxes[0]

        y_pred = approx #np.rint(approx)
        y_true = np.array(target).astype(int)

        output_weight = 1 # weight is not used

        score = p_auc_tpr(y_true, y_pred,min_tpr=0.80)
 
        return score, output_weight

    def get_final_error(self, error, weight):
        return error

def lgb_custom_metric(preds, dataset):
    y_true = dataset#.get_label()
    try:
        return 'prauc', -p_auc_tpr(y_true, preds,min_tpr=0.80), True
    except:
        return 'prauc', -100, True

def xgb_custom_metric(y_true, y_pred,*args, **kwargs):
    return -p_auc_tpr(y_true, y_pred, min_tpr=0.80)

# %%
num_cols = [
    'age_approx',                        # Approximate age of patient at time of imaging.
    'clin_size_long_diam_mm',            # Maximum diameter of the lesion (mm).+
    'tbp_lv_A',                          # A inside  lesion.+
    'tbp_lv_Aext',                       # A outside lesion.+
    'tbp_lv_B',                          # B inside  lesion.+
    'tbp_lv_Bext',                       # B outside lesion.+ 
    'tbp_lv_C',                          # Chroma inside  lesion.+
    'tbp_lv_Cext',                       # Chroma outside lesion.+
    'tbp_lv_H',                          # Hue inside the lesion; calculated as the angle of A* and B* in LAB* color space. Typical values range from 25 (red) to 75 (brown).+
    'tbp_lv_Hext',                       # Hue outside lesion.+
    'tbp_lv_L',                          # L inside lesion.+
    'tbp_lv_Lext',                       # L outside lesion.+
    'tbp_lv_areaMM2',                    # Area of lesion (mm^2).+
    'tbp_lv_area_perim_ratio',           # Border jaggedness, the ratio between lesions perimeter and area. Circular lesions will have low values; irregular shaped lesions will have higher values. Values range 0-10.+
    'tbp_lv_color_std_mean',             # Color irregularity, calculated as the variance of colors within the lesion's boundary.
    'tbp_lv_deltaA',                     # Average A contrast (inside vs. outside lesion).+
    'tbp_lv_deltaB',                     # Average B contrast (inside vs. outside lesion).+
    'tbp_lv_deltaL',                     # Average L contrast (inside vs. outside lesion).+
    'tbp_lv_deltaLB',                    #
    'tbp_lv_deltaLBnorm',                # Contrast between the lesion and its immediate surrounding skin. Low contrast lesions tend to be faintly visible such as freckles; high contrast lesions tend to be those with darker pigment. Calculated as the average delta LB of the lesion relative to its immediate background in LAB* color space. Typical values range from 5.5 to 25.+
    'tbp_lv_eccentricity',               # Eccentricity.+
    'tbp_lv_minorAxisMM',                # Smallest lesion diameter (mm).+
    'tbp_lv_nevi_confidence',            # Nevus confidence score (0-100 scale) is a convolutional neural network classifier estimated probability that the lesion is a nevus. The neural network was trained on approximately 57,000 lesions that were classified and labeled by a dermatologist.+,++
    'tbp_lv_norm_border',                # Border irregularity (0-10 scale); the normalized average of border jaggedness and asymmetry.+
    'tbp_lv_norm_color',                 # Color variation (0-10 scale); the normalized average of color asymmetry and color irregularity.+
    'tbp_lv_perimeterMM',                # Perimeter of lesion (mm).+
    'tbp_lv_radial_color_std_max',       # Color asymmetry, a measure of asymmetry of the spatial distribution of color within the lesion. This score is calculated by looking at the average standard deviation in LAB* color space within concentric rings originating from the lesion center. Values range 0-10.+
    'tbp_lv_stdL',                       # Standard deviation of L inside  lesion.+
    'tbp_lv_stdLExt',                    # Standard deviation of L outside lesion.+
    'tbp_lv_symm_2axis',                 # Border asymmetry; a measure of asymmetry of the lesion's contour about an axis perpendicular to the lesion's most symmetric axis. Lesions with two axes of symmetry will therefore have low scores (more symmetric), while lesions with only one or zero axes of symmetry will have higher scores (less symmetric). This score is calculated by comparing opposite halves of the lesion contour over many degrees of rotation. The angle where the halves are most similar identifies the principal axis of symmetry, while the second axis of symmetry is perpendicular to the principal axis. Border asymmetry is reported as the asymmetry value about this second axis. Values range 0-10.+
    'tbp_lv_symm_2axis_angle',           # Lesion border asymmetry angle.+
    'tbp_lv_x',                          # X-coordinate of the lesion on 3D TBP.+
    'tbp_lv_y',                          # Y-coordinate of the lesion on 3D TBP.+
    'tbp_lv_z',                          # Z-coordinate of the lesion on 3D TBP.+
]

new_cols = [
    'lesion_size_ratio',             # tbp_lv_minorAxisMM      / clin_size_long_diam_mm
    'lesion_shape_index',            # tbp_lv_areaMM2          / tbp_lv_perimeterMM **2
    'hue_contrast',                  # tbp_lv_H                - tbp_lv_Hext              abs
    'luminance_contrast',            # tbp_lv_L                - tbp_lv_Lext              abs
    'lesion_color_difference',       # tbp_lv_deltaA **2       + tbp_lv_deltaB **2 + tbp_lv_deltaL **2  sqrt  
    'border_complexity',             # tbp_lv_norm_border      + tbp_lv_symm_2axis
    'color_uniformity',              # tbp_lv_color_std_mean   / tbp_lv_radial_color_std_max

    'position_distance_3d',          # tbp_lv_x **2 + tbp_lv_y **2 + tbp_lv_z **2  sqrt
    'perimeter_to_area_ratio',       # tbp_lv_perimeterMM      / tbp_lv_areaMM2
    'area_to_perimeter_ratio',       # tbp_lv_areaMM2          / tbp_lv_perimeterMM
    'lesion_visibility_score',       # tbp_lv_deltaLBnorm      + tbp_lv_norm_color
    'symmetry_border_consistency',   # tbp_lv_symm_2axis       * tbp_lv_norm_border
    'consistency_symmetry_border',   # tbp_lv_symm_2axis       * tbp_lv_norm_border / (tbp_lv_symm_2axis + tbp_lv_norm_border)

    'color_consistency',             # tbp_lv_stdL             / tbp_lv_Lext
    'consistency_color',             # tbp_lv_stdL*tbp_lv_Lext / tbp_lv_stdL + tbp_lv_Lext
    'size_age_interaction',          # clin_size_long_diam_mm  * age_approx
    'hue_color_std_interaction',     # tbp_lv_H                * tbp_lv_color_std_mean
    'lesion_severity_index',         # tbp_lv_norm_border      + tbp_lv_norm_color + tbp_lv_eccentricity / 3
    'shape_complexity_index',        # border_complexity       + lesion_shape_index
    'color_contrast_index',          # tbp_lv_deltaA + tbp_lv_deltaB + tbp_lv_deltaL + tbp_lv_deltaLBnorm

    'log_lesion_area',               # tbp_lv_areaMM2          + 1  np.log
    'normalized_lesion_size',        # clin_size_long_diam_mm  / age_approx
    'mean_hue_difference',           # tbp_lv_H                + tbp_lv_Hext    / 2
    'std_dev_contrast',              # tbp_lv_deltaA **2 + tbp_lv_deltaB **2 + tbp_lv_deltaL **2   / 3  np.sqrt
    'color_shape_composite_index',   # tbp_lv_color_std_mean   + bp_lv_area_perim_ratio + tbp_lv_symm_2axis   / 3
    'lesion_orientation_3d',         # tbp_lv_y                , tbp_lv_x  np.arctan2
    'overall_color_difference',      # tbp_lv_deltaA           + tbp_lv_deltaB + tbp_lv_deltaL   / 3

    'symmetry_perimeter_interaction',# tbp_lv_symm_2axis       * tbp_lv_perimeterMM
    'comprehensive_lesion_index',    # tbp_lv_area_perim_ratio + tbp_lv_eccentricity + bp_lv_norm_color + tbp_lv_symm_2axis   / 4
    'color_variance_ratio',          # tbp_lv_color_std_mean   / tbp_lv_stdLExt
    'border_color_interaction',      # tbp_lv_norm_border      * tbp_lv_norm_color
    'border_color_interaction_2',
    'size_color_contrast_ratio',     # clin_size_long_diam_mm  / tbp_lv_deltaLBnorm
    'age_normalized_nevi_confidence',# tbp_lv_nevi_confidence  / age_approx
    'age_normalized_nevi_confidence_2',
    'color_asymmetry_index',         # tbp_lv_symm_2axis       * tbp_lv_radial_color_std_max

    'volume_approximation_3d',       # tbp_lv_areaMM2          * sqrt(tbp_lv_x**2 + tbp_lv_y**2 + tbp_lv_z**2)
    'color_range',                   # abs(tbp_lv_L - tbp_lv_Lext) + abs(tbp_lv_A - tbp_lv_Aext) + abs(tbp_lv_B - tbp_lv_Bext)
    'shape_color_consistency',       # tbp_lv_eccentricity     * tbp_lv_color_std_mean
    'border_length_ratio',           # tbp_lv_perimeterMM      / pi * sqrt(tbp_lv_areaMM2 / pi)
    'age_size_symmetry_index',       # age_approx              * clin_size_long_diam_mm * tbp_lv_symm_2axis
    'index_age_size_symmetry',       # age_approx              * tbp_lv_areaMM2 * tbp_lv_symm_2axis
]

aggr_cols = ['combined_anatomical_site'] + [f'{col}_patient_norm' for col in (num_cols + new_cols)]
cat_cols = ['sex', 'anatom_site_general', 'tbp_tile_type', 'tbp_lv_location', 'tbp_lv_location_simple', 'attribution', 'copyright_license','combined_anatomical_site',]
drop_cols = [
    'isic_id',
    'patient_id',
    'image_type',
    'lesion_id',
    'iddx_full',
    'iddx_1',
    'iddx_2',
    'iddx_3',
    'iddx_4',
    'iddx_5',
    'mel_mitotic_index',
    'mel_thick_mm', 
    'tbp_lv_dnn_lesion_confidence',
    'is_tbp_tile_type',
]

cb_params = {
    'iterations': 1000,
    'learning_rate': 0.05,
    'loss_function': 'CrossEntropy',
    'max_depth': 6,
    'eval_metric': PRAUCMetric(),
    'l2_leaf_reg': 6.216113851699493, 
    #'subsample': 0.6249261779711819, 
    'min_data_in_leaf': 24,
    'task_type': 'GPU',
    'random_seed': 56,
}


lgb_params = {
    'objective':        'binary',
    'verbosity':        -1,
    'n_iter':           300,
    'boosting_type':    'gbdt',
    'random_state':     56,
    'lambda_l1':        0.08758718919397321, 
    'lambda_l2':        0.0039689175176025465, 
    'learning_rate':    0.03231007103195577, 
    'max_depth':        5, 
    'num_leaves':       103, 
    'colsample_bytree': 0.8329551585827726, 
    'colsample_bynode': 0.4025961355653304, 
    'bagging_fraction': 0.7738954452473223, 
    'extra_trees':      True,
    'bagging_freq':     4, 
    'min_data_in_leaf': 85, 
    'scale_pos_weight': 2.7984184778875543,
}


xgb_params = {
    'enable_categorical': True,
    #'verbose':50,
    'objective':'binary:logistic',
    'tree_method': 'hist',
    #'num_iterations': 400,
    'random_state': 56,
    'learning_rate': 0.08501257473292347, 
    'lambda': 8.879624125465703, 
    'early_stopping_rounds': 30,
    'alpha': 0.6779926606782505, 
    'eval_metric': xgb_custom_metric,
    'max_depth': 6,
    'subsample': 0.6012681388711075, 
    'colsample_bytree': 0.8437772277074493, 
    'colsample_bylevel': 0.5476090898823716, 
    'colsample_bynode': 0.9928601203635129, 
    'scale_pos_weight': 3.29440313334688,
    'random_state': 56
}

params = {
    'cb_params': cb_params,
    'lgb_params': lgb_params,
    'xgb_params': xgb_params
}

label_col = 'target'
n_folds = 5
n_repits = 1

# %%
class EnsembleClassifier(BaseEstimator):
    def __init__(self,cb_params,lgb_params,xgb_params):
        self.cbm = CatBoostClassifier(**cb_params)
        self.lgbm = lgb.LGBMClassifier(**lgb_params)
        self.xgbm = xgb.XGBClassifier(**xgb_params)
    
    def fit(self,X,y,X_val,y_val,cat_features=None,verbose=False):
        train_pool = Pool(X,label=y,cat_features=cat_features)
        eval_pool = Pool(X_val,label=y_val,cat_features=cat_features)
        self.cbm.fit(train_pool,eval_set=eval_pool,verbose=verbose)
        self.lgbm.fit(X,y,eval_set=[(X_val,y_val)],eval_metric=lgb_custom_metric,categorical_feature=cat_features)
        self.xgbm.fit(X,y,eval_set=[(X_val,y_val)])
    
    def predict_proba(self,X_test,cat_features):
        test_pool = Pool(X_test,cat_features=cat_features)
        cb_preds = self.cbm.predict_proba(test_pool)[:,1]
        lgb_preds = self.lgbm.predict_proba(X_test)[:,1]
        xgb_preds = self.xgbm.predict_proba(X_test)[:,1]
        return cb_preds, lgb_preds, xgb_preds

# %%
class CustomBoostKfoldWraper(BaseEstimator):
    def __init__(self,num_folds,num_repits,params,random_state=56,score_func=p_auc_tpr):
        self.models = []
        self.params = params
        self.random_state = random_state
        self.num_folds = num_folds
        self.num_repits = num_repits
        self.score_func = score_func
        
    def fit(self,train_data,cat_features=None,drop_cols=None,label_col=None,verbose=False):
        self.scores = []
        
        for i in trange(self.num_repits):
            kfold = StratifiedGroupKFold(self.num_folds,random_state=self.random_state+i,shuffle=True)
            for train_index, test_index in (kfold.split(train_data,train_data[label_col],train_data['patient_id'])):
                train_df = train_data.iloc[train_index]
                test_df = train_data.iloc[test_index]
                
                model = EnsembleClassifier(**self.params)
                model.fit(
                    X = train_df.drop([label_col]+drop_cols,axis=1),
                    y = train_df[label_col],
                    X_val = test_df.drop([label_col]+drop_cols,axis=1),
                    y_val = test_df[label_col],
                    cat_features = cat_features,
                    verbose = verbose
                )
                cb_preds, lgb_preds, xgb_preds = model.predict_proba(test_df.drop([label_col]+drop_cols,axis=1),cat_features)
                avg_preds = (cb_preds + lgb_preds + xgb_preds) / 3
                self.scores += [[
                    self.score_func(test_df[label_col],cb_preds),
                    self.score_func(test_df[label_col],lgb_preds),
                    self.score_func(test_df[label_col],xgb_preds),
                    self.score_func(test_df[label_col],avg_preds)
                ]]
                print(self.scores[-1])
                self.models += [model]
                
        print(f"Total Score {np.mean([x[3] for x in self.scores])}")
            
    def predict(self,test_data,drop_cols=None,cat_features=None):
        preds = np.mean([
            np.mean(model.predict_proba(test_data.drop(drop_cols,axis=1),cat_features=cat_features),axis=0)
            for model in self.models
        ],axis=0)
        return preds
    
    def get_feature_importance(self,type='FeatureImportance'):
        imp_0 = self.models[0].cbm.get_feature_importance(prettified=True,type=type).set_index('Feature Id')
        for i in range(1,len(self.models)):
            imp_0 += self.models[i].cbm.get_feature_importance(prettified=True,type=type).set_index('Feature Id')
        return (imp_0 / len(self.models)).sort_values(by='Importances')[::-1]

# %%
train_data = process_data(train_data)
train_data[cat_cols] = train_data[cat_cols].astype('category')

test_data = process_data(test_data)
test_data[cat_cols] = test_data[cat_cols].astype('category')
# Out:
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.

# %%
model = CustomBoostKfoldWraper(
    num_folds=n_folds,
    num_repits=n_repits,
    params=params,
    random_state=56,
    score_func=partial(p_auc_tpr,min_tpr=0.80)
)

# %%
model.fit(
    train_data=train_data,
    cat_features=cat_cols,
    drop_cols=drop_cols,
    label_col=label_col,
    verbose=200,
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Default metric period is 5 because PythonUserDefinedPerObject is/are not implemented for GPU
# /opt/conda/lib/python3.10/site-packages/catboost/core.py:1780: UserWarning: Failed to optimize method "evaluate" in the passed object:
# Failed in nopython mode pipeline (step: nopython frontend)
# Untyped global name 'p_auc_tpr': Cannot determine Numba type of <class 'function'>
#
# File "../../tmp/ipykernel_34/3195744980.py", line 16:
# <source missing, REPL/exec in use?>
#
#   self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
# 0:	learn: 0.0265520	test: 0.0392256	best: 0.0392256 (0)	total: 6.94s	remaining: 1h 55m 30s
# 200:	learn: 0.1761450	test: 0.1759944	best: 0.1765774 (190)	total: 17.6s	remaining: 1m 10s
# 400:	learn: 0.1842021	test: 0.1762013	best: 0.1770677 (260)	total: 28.2s	remaining: 42.1s
# 600:	learn: 0.1892525	test: 0.1758834	best: 0.1770677 (260)	total: 39.2s	remaining: 26s
# 800:	learn: 0.1925491	test: 0.1759285	best: 0.1770677 (260)	total: 51.2s	remaining: 12.7s
# 999:	learn: 0.1947561	test: 0.1746076	best: 0.1770677 (260)	total: 1m 2s	remaining: 0us
# bestTest = 0.1770676772
# bestIteration = 260
# Shrink model to first 261 iterations.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [0]	validation_0-logloss:0.11966	validation_0-xgb_custom_metric:-0.04574
# [1]	validation_0-logloss:0.10975	validation_0-xgb_custom_metric:-0.09227
# [2]	validation_0-logloss:0.10082	validation_0-xgb_custom_metric:-0.09740
# [3]	validation_0-logloss:0.09264	validation_0-xgb_custom_metric:-0.10891
# [4]	validation_0-logloss:0.08518	validation_0-xgb_custom_metric:-0.10869
# [5]	validation_0-logloss:0.07837	validation_0-xgb_custom_metric:-0.11316
# [6]	validation_0-logloss:0.07217	validation_0-xgb_custom_metric:-0.11241
# [7]	validation_0-logloss:0.06652	validation_0-xgb_custom_metric:-0.11665
# [8]	validation_0-logloss:0.06136	validation_0-xgb_custom_metric:-0.11638
# [9]	validation_0-logloss:0.05666	validation_0-xgb_custom_metric:-0.11633
# [10]	validation_0-logloss:0.05238	validation_0-xgb_custom_metric:-0.11582
# [11]	validation_0-logloss:0.04847	validation_0-xgb_custom_metric:-0.13669
# [12]	validation_0-logloss:0.04489	validation_0-xgb_custom_metric:-0.13609
# [13]	validation_0-logloss:0.04160	validation_0-xgb_custom_metric:-0.13786
# [14]	validation_0-logloss:0.03859	validation_0-xgb_custom_metric:-0.14990
# [15]	validation_0-logloss:0.03584	validation_0-xgb_custom_metric:-0.14931
# [16]	validation_0-logloss:0.03331	validation_0-xgb_custom_metric:-0.15544
# [17]	validation_0-logloss:0.03100	validation_0-xgb_custom_metric:-0.15511
# [18]	validation_0-logloss:0.02889	validation_0-xgb_custom_metric:-0.15440
# [19]	validation_0-logloss:0.02694	validation_0-xgb_custom_metric:-0.15398
# [20]	validation_0-logloss:0.02518	validation_0-xgb_custom_metric:-0.15338
# [21]	validation_0-logloss:0.02353	validation_0-xgb_custom_metric:-0.15793
# [22]	validation_0-logloss:0.02206	validation_0-xgb_custom_metric:-0.15653
# [23]	validation_0-logloss:0.02068	validation_0-xgb_custom_metric:-0.15660
# [24]	validation_0-logloss:0.01942	validation_0-xgb_custom_metric:-0.15666
# [25]	validation_0-logloss:0.01827	validation_0-xgb_custom_metric:-0.15737
# [26]	validation_0-logloss:0.01720	validation_0-xgb_custom_metric:-0.15657
# [27]	validation_0-logloss:0.01624	validation_0-xgb_custom_metric:-0.15823
# [28]	validation_0-logloss:0.01536	validation_0-xgb_custom_metric:-0.15834
# [29]	validation_0-logloss:0.01454	validation_0-xgb_custom_metric:-0.16113
# [30]	validation_0-logloss:0.01379	validation_0-xgb_custom_metric:-0.16055
# [31]	validation_0-logloss:0.01310	validation_0-xgb_custom_metric:-0.16540
# [32]	validation_0-logloss:0.01247	validation_0-xgb_custom_metric:-0.16460
# [33]	validation_0-logloss:0.01188	validation_0-xgb_custom_metric:-0.16656
# [34]	validation_0-logloss:0.01136	validation_0-xgb_custom_metric:-0.16639
# [35]	validation_0-logloss:0.01086	validation_0-xgb_custom_metric:-0.16505
# [36]	validation_0-logloss:0.01041	validation_0-xgb_custom_metric:-0.16651
# [37]	validation_0-logloss:0.01001	validation_0-xgb_custom_metric:-0.16602
# [38]	validation_0-logloss:0.00961	validation_0-xgb_custom_metric:-0.16592
# [39]	validation_0-logloss:0.00927	validation_0-xgb_custom_metric:-0.16516
# [40]	validation_0-logloss:0.00894	validation_0-xgb_custom_metric:-0.16593
# [41]	validation_0-logloss:0.00864	validation_0-xgb_custom_metric:-0.16610
# [42]	validation_0-logloss:0.00837	validation_0-xgb_custom_metric:-0.16508
# [43]	validation_0-logloss:0.00811	validation_0-xgb_custom_metric:-0.16736
# [44]	validation_0-logloss:0.00789	validation_0-xgb_custom_metric:-0.16884
# [45]	validation_0-logloss:0.00767	validation_0-xgb_custom_metric:-0.16847
# [46]	validation_0-logloss:0.00747	validation_0-xgb_custom_metric:-0.16850
# [47]	validation_0-logloss:0.00729	validation_0-xgb_custom_metric:-0.16911
# [48]	validation_0-logloss:0.00711	validation_0-xgb_custom_metric:-0.17079
# [49]	validation_0-logloss:0.00696	validation_0-xgb_custom_metric:-0.16956
# [50]	validation_0-logloss:0.00681	validation_0-xgb_custom_metric:-0.17016
# [51]	validation_0-logloss:0.00669	validation_0-xgb_custom_metric:-0.16970
# [52]	validation_0-logloss:0.00656	validation_0-xgb_custom_metric:-0.16974
# [53]	validation_0-logloss:0.00645	validation_0-xgb_custom_metric:-0.16846
# [54]	validation_0-logloss:0.00634	validation_0-xgb_custom_metric:-0.16949
# [55]	validation_0-logloss:0.00626	validation_0-xgb_custom_metric:-0.16856
# [56]	validation_0-logloss:0.00619	validation_0-xgb_custom_metric:-0.16693
# [57]	validation_0-logloss:0.00612	validation_0-xgb_custom_metric:-0.16897
# [58]	validation_0-logloss:0.00604	validation_0-xgb_custom_metric:-0.16926
# [59]	validation_0-logloss:0.00597	validation_0-xgb_custom_metric:-0.16837
# [60]	validation_0-logloss:0.00592	validation_0-xgb_custom_metric:-0.16839
# [61]	validation_0-logloss:0.00587	validation_0-xgb_custom_metric:-0.16724
# [62]	validation_0-logloss:0.00582	validation_0-xgb_custom_metric:-0.16624
# [63]	validation_0-logloss:0.00576	validation_0-xgb_custom_metric:-0.16581
# [64]	validation_0-logloss:0.00572	validation_0-xgb_custom_metric:-0.16697
# [65]	validation_0-logloss:0.00568	validation_0-xgb_custom_metric:-0.16811
# [66]	validation_0-logloss:0.00564	validation_0-xgb_custom_metric:-0.16795
# [67]	validation_0-logloss:0.00560	validation_0-xgb_custom_metric:-0.16809
# [68]	validation_0-logloss:0.00557	validation_0-xgb_custom_metric:-0.16797
# [69]	validation_0-logloss:0.00554	validation_0-xgb_custom_metric:-0.16775
# [70]	validation_0-logloss:0.00550	validation_0-xgb_custom_metric:-0.17219
# [71]	validation_0-logloss:0.00548	validation_0-xgb_custom_metric:-0.17207
# [72]	validation_0-logloss:0.00545	validation_0-xgb_custom_metric:-0.17139
# [73]	validation_0-logloss:0.00543	validation_0-xgb_custom_metric:-0.17112
# [74]	validation_0-logloss:0.00541	validation_0-xgb_custom_metric:-0.17161
# [75]	validation_0-logloss:0.00540	validation_0-xgb_custom_metric:-0.17098
# [76]	validation_0-logloss:0.00537	validation_0-xgb_custom_metric:-0.17085
# [77]	validation_0-logloss:0.00535	validation_0-xgb_custom_metric:-0.17088
# [78]	validation_0-logloss:0.00533	validation_0-xgb_custom_metric:-0.17217
# [79]	validation_0-logloss:0.00531	validation_0-xgb_custom_metric:-0.17145
# [80]	validation_0-logloss:0.00529	validation_0-xgb_custom_metric:-0.17111
# [81]	validation_0-logloss:0.00528	validation_0-xgb_custom_metric:-0.17190
# [82]	validation_0-logloss:0.00527	validation_0-xgb_custom_metric:-0.17178
# [83]	validation_0-logloss:0.00523	validation_0-xgb_custom_metric:-0.17319
# [84]	validation_0-logloss:0.00522	validation_0-xgb_custom_metric:-0.17308
# [85]	validation_0-logloss:0.00521	validation_0-xgb_custom_metric:-0.17352
# [86]	validation_0-logloss:0.00519	validation_0-xgb_custom_metric:-0.17315
# [87]	validation_0-logloss:0.00518	validation_0-xgb_custom_metric:-0.17383
# [88]	validation_0-logloss:0.00517	validation_0-xgb_custom_metric:-0.17437
# [89]	validation_0-logloss:0.00516	validation_0-xgb_custom_metric:-0.17551
# [90]	validation_0-logloss:0.00515	validation_0-xgb_custom_metric:-0.17483
# [91]	validation_0-logloss:0.00515	validation_0-xgb_custom_metric:-0.17423
# [92]	validation_0-logloss:0.00514	validation_0-xgb_custom_metric:-0.17412
# [93]	validation_0-logloss:0.00513	validation_0-xgb_custom_metric:-0.17435
# [94]	validation_0-logloss:0.00512	validation_0-xgb_custom_metric:-0.17469
# [95]	validation_0-logloss:0.00512	validation_0-xgb_custom_metric:-0.17451
# [96]	validation_0-logloss:0.00511	validation_0-xgb_custom_metric:-0.17494
# [97]	validation_0-logloss:0.00511	validation_0-xgb_custom_metric:-0.17453
# [98]	validation_0-logloss:0.00510	validation_0-xgb_custom_metric:-0.17446
# [99]	validation_0-logloss:0.00510	validation_0-xgb_custom_metric:-0.17456
# [0.17706767718467586, 0.16199886624214677, 0.1755078924647116, 0.17963510289674517]
# Default metric period is 5 because PythonUserDefinedPerObject is/are not implemented for GPU
# /opt/conda/lib/python3.10/site-packages/catboost/core.py:1780: UserWarning: Failed to optimize method "evaluate" in the passed object:
# Failed in nopython mode pipeline (step: nopython frontend)
# Untyped global name 'p_auc_tpr': Cannot determine Numba type of <class 'function'>
#
# File "../../tmp/ipykernel_34/3195744980.py", line 16:
# <source missing, REPL/exec in use?>
#
#   self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
# 0:	learn: 0.0302481	test: 0.0215900	best: 0.0215900 (0)	total: 1.11s	remaining: 18m 28s
# 200:	learn: 0.1778651	test: 0.1438417	best: 0.1441456 (195)	total: 11.7s	remaining: 46.3s
# 400:	learn: 0.1861374	test: 0.1550050	best: 0.1550050 (400)	total: 22.5s	remaining: 33.6s
# 600:	learn: 0.1903394	test: 0.1563849	best: 0.1563849 (600)	total: 33.2s	remaining: 22s
# 800:	learn: 0.1932096	test: 0.1584508	best: 0.1585133 (785)	total: 43.8s	remaining: 10.9s
# 999:	learn: 0.1952511	test: 0.1595384	best: 0.1597563 (985)	total: 54.5s	remaining: 0us
# bestTest = 0.1597563184
# bestIteration = 985
# Shrink model to first 986 iterations.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [0]	validation_0-logloss:0.11938	validation_0-xgb_custom_metric:-0.04766
# [1]	validation_0-logloss:0.10951	validation_0-xgb_custom_metric:-0.06353
# [2]	validation_0-logloss:0.10053	validation_0-xgb_custom_metric:-0.06667
# [3]	validation_0-logloss:0.09233	validation_0-xgb_custom_metric:-0.07249
# [4]	validation_0-logloss:0.08490	validation_0-xgb_custom_metric:-0.07228
# [5]	validation_0-logloss:0.07809	validation_0-xgb_custom_metric:-0.07228
# [6]	validation_0-logloss:0.07191	validation_0-xgb_custom_metric:-0.07705
# [7]	validation_0-logloss:0.06626	validation_0-xgb_custom_metric:-0.07646
# [8]	validation_0-logloss:0.06112	validation_0-xgb_custom_metric:-0.07933
# [9]	validation_0-logloss:0.05642	validation_0-xgb_custom_metric:-0.08884
# [10]	validation_0-logloss:0.05211	validation_0-xgb_custom_metric:-0.09439
# [11]	validation_0-logloss:0.04819	validation_0-xgb_custom_metric:-0.09401
# [12]	validation_0-logloss:0.04459	validation_0-xgb_custom_metric:-0.11397
# [13]	validation_0-logloss:0.04131	validation_0-xgb_custom_metric:-0.11383
# [14]	validation_0-logloss:0.03829	validation_0-xgb_custom_metric:-0.11381
# [15]	validation_0-logloss:0.03554	validation_0-xgb_custom_metric:-0.11831
# [16]	validation_0-logloss:0.03303	validation_0-xgb_custom_metric:-0.11793
# [17]	validation_0-logloss:0.03073	validation_0-xgb_custom_metric:-0.11725
# [18]	validation_0-logloss:0.02863	validation_0-xgb_custom_metric:-0.11701
# [19]	validation_0-logloss:0.02670	validation_0-xgb_custom_metric:-0.11695
# [20]	validation_0-logloss:0.02492	validation_0-xgb_custom_metric:-0.11573
# [21]	validation_0-logloss:0.02330	validation_0-xgb_custom_metric:-0.11548
# [22]	validation_0-logloss:0.02181	validation_0-xgb_custom_metric:-0.11387
# [23]	validation_0-logloss:0.02045	validation_0-xgb_custom_metric:-0.11240
# [24]	validation_0-logloss:0.01918	validation_0-xgb_custom_metric:-0.13140
# [25]	validation_0-logloss:0.01801	validation_0-xgb_custom_metric:-0.13054
# [26]	validation_0-logloss:0.01695	validation_0-xgb_custom_metric:-0.13013
# [27]	validation_0-logloss:0.01597	validation_0-xgb_custom_metric:-0.12986
# [28]	validation_0-logloss:0.01507	validation_0-xgb_custom_metric:-0.13062
# [29]	validation_0-logloss:0.01428	validation_0-xgb_custom_metric:-0.12856
# [30]	validation_0-logloss:0.01354	validation_0-xgb_custom_metric:-0.13114
# [31]	validation_0-logloss:0.01286	validation_0-xgb_custom_metric:-0.13068
# [32]	validation_0-logloss:0.01220	validation_0-xgb_custom_metric:-0.13611
# [33]	validation_0-logloss:0.01163	validation_0-xgb_custom_metric:-0.13539
# [34]	validation_0-logloss:0.01110	validation_0-xgb_custom_metric:-0.13442
# [35]	validation_0-logloss:0.01061	validation_0-xgb_custom_metric:-0.13465
# [36]	validation_0-logloss:0.01017	validation_0-xgb_custom_metric:-0.13372
# [37]	validation_0-logloss:0.00975	validation_0-xgb_custom_metric:-0.13659
# [38]	validation_0-logloss:0.00936	validation_0-xgb_custom_metric:-0.14356
# [39]	validation_0-logloss:0.00902	validation_0-xgb_custom_metric:-0.14375
# [40]	validation_0-logloss:0.00870	validation_0-xgb_custom_metric:-0.14360
# [41]	validation_0-logloss:0.00840	validation_0-xgb_custom_metric:-0.14547
# [42]	validation_0-logloss:0.00811	validation_0-xgb_custom_metric:-0.15249
# [43]	validation_0-logloss:0.00786	validation_0-xgb_custom_metric:-0.15153
# [44]	validation_0-logloss:0.00763	validation_0-xgb_custom_metric:-0.14991
# [45]	validation_0-logloss:0.00742	validation_0-xgb_custom_metric:-0.14847
# [46]	validation_0-logloss:0.00721	validation_0-xgb_custom_metric:-0.14994
# [47]	validation_0-logloss:0.00703	validation_0-xgb_custom_metric:-0.14877
# [48]	validation_0-logloss:0.00688	validation_0-xgb_custom_metric:-0.14716
# [49]	validation_0-logloss:0.00673	validation_0-xgb_custom_metric:-0.14743
# [50]	validation_0-logloss:0.00658	validation_0-xgb_custom_metric:-0.14807
# [51]	validation_0-logloss:0.00646	validation_0-xgb_custom_metric:-0.14763
# [52]	validation_0-logloss:0.00635	validation_0-xgb_custom_metric:-0.14620
# [53]	validation_0-logloss:0.00625	validation_0-xgb_custom_metric:-0.14890
# [54]	validation_0-logloss:0.00615	validation_0-xgb_custom_metric:-0.15354
# [55]	validation_0-logloss:0.00606	validation_0-xgb_custom_metric:-0.15291
# [56]	validation_0-logloss:0.00599	validation_0-xgb_custom_metric:-0.15082
# [57]	validation_0-logloss:0.00592	validation_0-xgb_custom_metric:-0.14935
# [58]	validation_0-logloss:0.00584	validation_0-xgb_custom_metric:-0.15011
# [59]	validation_0-logloss:0.00577	validation_0-xgb_custom_metric:-0.14898
# [60]	validation_0-logloss:0.00569	validation_0-xgb_custom_metric:-0.14728
# [61]	validation_0-logloss:0.00562	validation_0-xgb_custom_metric:-0.15102
# [62]	validation_0-logloss:0.00558	validation_0-xgb_custom_metric:-0.15415
# [63]	validation_0-logloss:0.00551	validation_0-xgb_custom_metric:-0.15459
# [64]	validation_0-logloss:0.00545	validation_0-xgb_custom_metric:-0.15658
# [65]	validation_0-logloss:0.00542	validation_0-xgb_custom_metric:-0.15723
# [66]	validation_0-logloss:0.00536	validation_0-xgb_custom_metric:-0.15793
# [67]	validation_0-logloss:0.00531	validation_0-xgb_custom_metric:-0.15729
# [68]	validation_0-logloss:0.00528	validation_0-xgb_custom_metric:-0.15624
# [69]	validation_0-logloss:0.00525	validation_0-xgb_custom_metric:-0.15558
# [70]	validation_0-logloss:0.00525	validation_0-xgb_custom_metric:-0.15462
# [71]	validation_0-logloss:0.00522	validation_0-xgb_custom_metric:-0.15386
# [72]	validation_0-logloss:0.00520	validation_0-xgb_custom_metric:-0.15383
# [73]	validation_0-logloss:0.00517	validation_0-xgb_custom_metric:-0.15527
# [74]	validation_0-logloss:0.00517	validation_0-xgb_custom_metric:-0.15353
# [75]	validation_0-logloss:0.00514	validation_0-xgb_custom_metric:-0.15428
# [76]	validation_0-logloss:0.00511	validation_0-xgb_custom_metric:-0.15419
# [77]	validation_0-logloss:0.00510	validation_0-xgb_custom_metric:-0.15322
# [78]	validation_0-logloss:0.00508	validation_0-xgb_custom_metric:-0.15207
# [79]	validation_0-logloss:0.00508	validation_0-xgb_custom_metric:-0.15243
# [80]	validation_0-logloss:0.00506	validation_0-xgb_custom_metric:-0.15303
# [81]	validation_0-logloss:0.00505	validation_0-xgb_custom_metric:-0.15138
# [82]	validation_0-logloss:0.00503	validation_0-xgb_custom_metric:-0.15060
# [83]	validation_0-logloss:0.00502	validation_0-xgb_custom_metric:-0.15050
# [84]	validation_0-logloss:0.00500	validation_0-xgb_custom_metric:-0.15075
# [85]	validation_0-logloss:0.00499	validation_0-xgb_custom_metric:-0.15000
# [86]	validation_0-logloss:0.00499	validation_0-xgb_custom_metric:-0.15026
# [87]	validation_0-logloss:0.00498	validation_0-xgb_custom_metric:-0.15042
# [88]	validation_0-logloss:0.00497	validation_0-xgb_custom_metric:-0.15003
# [89]	validation_0-logloss:0.00497	validation_0-xgb_custom_metric:-0.14914
# [90]	validation_0-logloss:0.00496	validation_0-xgb_custom_metric:-0.14808
# [91]	validation_0-logloss:0.00496	validation_0-xgb_custom_metric:-0.14855
# [92]	validation_0-logloss:0.00496	validation_0-xgb_custom_metric:-0.15058
# [93]	validation_0-logloss:0.00495	validation_0-xgb_custom_metric:-0.15113
# [94]	validation_0-logloss:0.00495	validation_0-xgb_custom_metric:-0.15134
# [95]	validation_0-logloss:0.00494	validation_0-xgb_custom_metric:-0.15149
# [0.15975631842225227, 0.14482412918079604, 0.15793388997483243, 0.16389174426132588]
# Default metric period is 5 because PythonUserDefinedPerObject is/are not implemented for GPU
# /opt/conda/lib/python3.10/site-packages/catboost/core.py:1780: UserWarning: Failed to optimize method "evaluate" in the passed object:
# Failed in nopython mode pipeline (step: nopython frontend)
# Untyped global name 'p_auc_tpr': Cannot determine Numba type of <class 'function'>
#
# File "../../tmp/ipykernel_34/3195744980.py", line 16:
# <source missing, REPL/exec in use?>
#
#   self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
# 0:	learn: 0.0278139	test: 0.0308909	best: 0.0308909 (0)	total: 122ms	remaining: 2m 2s
# 200:	learn: 0.1765220	test: 0.1754662	best: 0.1754662 (200)	total: 10.4s	remaining: 41.4s
# 400:	learn: 0.1845159	test: 0.1770832	best: 0.1771501 (395)	total: 20.9s	remaining: 31.3s
# 600:	learn: 0.1891892	test: 0.1762033	best: 0.1774785 (440)	total: 31.3s	remaining: 20.8s
# 800:	learn: 0.1923208	test: 0.1770986	best: 0.1774785 (440)	total: 41.7s	remaining: 10.3s
# 999:	learn: 0.1945392	test: 0.1759562	best: 0.1774812 (855)	total: 52.1s	remaining: 0us
# bestTest = 0.1774812317
# bestIteration = 855
# Shrink model to first 856 iterations.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [0]	validation_0-logloss:0.11965	validation_0-xgb_custom_metric:-0.05355
# [1]	validation_0-logloss:0.10974	validation_0-xgb_custom_metric:-0.06526
# [2]	validation_0-logloss:0.10071	validation_0-xgb_custom_metric:-0.07334
# [3]	validation_0-logloss:0.09253	validation_0-xgb_custom_metric:-0.08629
# [4]	validation_0-logloss:0.08507	validation_0-xgb_custom_metric:-0.09020
# [5]	validation_0-logloss:0.07826	validation_0-xgb_custom_metric:-0.11251
# [6]	validation_0-logloss:0.07206	validation_0-xgb_custom_metric:-0.11623
# [7]	validation_0-logloss:0.06645	validation_0-xgb_custom_metric:-0.11627
# [8]	validation_0-logloss:0.06130	validation_0-xgb_custom_metric:-0.12547
# [9]	validation_0-logloss:0.05658	validation_0-xgb_custom_metric:-0.12489
# [10]	validation_0-logloss:0.05227	validation_0-xgb_custom_metric:-0.12413
# [11]	validation_0-logloss:0.04833	validation_0-xgb_custom_metric:-0.12374
# [12]	validation_0-logloss:0.04472	validation_0-xgb_custom_metric:-0.12309
# [13]	validation_0-logloss:0.04143	validation_0-xgb_custom_metric:-0.14011
# [14]	validation_0-logloss:0.03840	validation_0-xgb_custom_metric:-0.14369
# [15]	validation_0-logloss:0.03566	validation_0-xgb_custom_metric:-0.14322
# [16]	validation_0-logloss:0.03313	validation_0-xgb_custom_metric:-0.14403
# [17]	validation_0-logloss:0.03080	validation_0-xgb_custom_metric:-0.15083
# [18]	validation_0-logloss:0.02870	validation_0-xgb_custom_metric:-0.15054
# [19]	validation_0-logloss:0.02677	validation_0-xgb_custom_metric:-0.14904
# [20]	validation_0-logloss:0.02499	validation_0-xgb_custom_metric:-0.14898
# [21]	validation_0-logloss:0.02335	validation_0-xgb_custom_metric:-0.14879
# [22]	validation_0-logloss:0.02186	validation_0-xgb_custom_metric:-0.14852
# [23]	validation_0-logloss:0.02049	validation_0-xgb_custom_metric:-0.14795
# [24]	validation_0-logloss:0.01924	validation_0-xgb_custom_metric:-0.15172
# [25]	validation_0-logloss:0.01806	validation_0-xgb_custom_metric:-0.15145
# [26]	validation_0-logloss:0.01701	validation_0-xgb_custom_metric:-0.15102
# [27]	validation_0-logloss:0.01604	validation_0-xgb_custom_metric:-0.15218
# [28]	validation_0-logloss:0.01516	validation_0-xgb_custom_metric:-0.15192
# [29]	validation_0-logloss:0.01434	validation_0-xgb_custom_metric:-0.15288
# [30]	validation_0-logloss:0.01359	validation_0-xgb_custom_metric:-0.15225
# [31]	validation_0-logloss:0.01290	validation_0-xgb_custom_metric:-0.15277
# [32]	validation_0-logloss:0.01227	validation_0-xgb_custom_metric:-0.15232
# [33]	validation_0-logloss:0.01168	validation_0-xgb_custom_metric:-0.15840
# [34]	validation_0-logloss:0.01114	validation_0-xgb_custom_metric:-0.15826
# [35]	validation_0-logloss:0.01065	validation_0-xgb_custom_metric:-0.16300
# [36]	validation_0-logloss:0.01017	validation_0-xgb_custom_metric:-0.16349
# [37]	validation_0-logloss:0.00978	validation_0-xgb_custom_metric:-0.16581
# [38]	validation_0-logloss:0.00938	validation_0-xgb_custom_metric:-0.16504
# [39]	validation_0-logloss:0.00904	validation_0-xgb_custom_metric:-0.16562
# [40]	validation_0-logloss:0.00872	validation_0-xgb_custom_metric:-0.16548
# [41]	validation_0-logloss:0.00844	validation_0-xgb_custom_metric:-0.16812
# [42]	validation_0-logloss:0.00817	validation_0-xgb_custom_metric:-0.16790
# [43]	validation_0-logloss:0.00792	validation_0-xgb_custom_metric:-0.16754
# [44]	validation_0-logloss:0.00767	validation_0-xgb_custom_metric:-0.17454
# [45]	validation_0-logloss:0.00747	validation_0-xgb_custom_metric:-0.17511
# [46]	validation_0-logloss:0.00729	validation_0-xgb_custom_metric:-0.17420
# [47]	validation_0-logloss:0.00711	validation_0-xgb_custom_metric:-0.17375
# [48]	validation_0-logloss:0.00696	validation_0-xgb_custom_metric:-0.17513
# [49]	validation_0-logloss:0.00683	validation_0-xgb_custom_metric:-0.17573
# [50]	validation_0-logloss:0.00670	validation_0-xgb_custom_metric:-0.17525
# [51]	validation_0-logloss:0.00655	validation_0-xgb_custom_metric:-0.17489
# [52]	validation_0-logloss:0.00643	validation_0-xgb_custom_metric:-0.17423
# [53]	validation_0-logloss:0.00632	validation_0-xgb_custom_metric:-0.17362
# [54]	validation_0-logloss:0.00622	validation_0-xgb_custom_metric:-0.17453
# [55]	validation_0-logloss:0.00611	validation_0-xgb_custom_metric:-0.17548
# [56]	validation_0-logloss:0.00603	validation_0-xgb_custom_metric:-0.17507
# [57]	validation_0-logloss:0.00596	validation_0-xgb_custom_metric:-0.17498
# [58]	validation_0-logloss:0.00590	validation_0-xgb_custom_metric:-0.17497
# [59]	validation_0-logloss:0.00583	validation_0-xgb_custom_metric:-0.17439
# [60]	validation_0-logloss:0.00576	validation_0-xgb_custom_metric:-0.17352
# [61]	validation_0-logloss:0.00570	validation_0-xgb_custom_metric:-0.17400
# [62]	validation_0-logloss:0.00565	validation_0-xgb_custom_metric:-0.17363
# [63]	validation_0-logloss:0.00559	validation_0-xgb_custom_metric:-0.17409
# [64]	validation_0-logloss:0.00556	validation_0-xgb_custom_metric:-0.17366
# [65]	validation_0-logloss:0.00551	validation_0-xgb_custom_metric:-0.17343
# [66]	validation_0-logloss:0.00546	validation_0-xgb_custom_metric:-0.17402
# [67]	validation_0-logloss:0.00543	validation_0-xgb_custom_metric:-0.17474
# [68]	validation_0-logloss:0.00538	validation_0-xgb_custom_metric:-0.17477
# [69]	validation_0-logloss:0.00535	validation_0-xgb_custom_metric:-0.17522
# [70]	validation_0-logloss:0.00531	validation_0-xgb_custom_metric:-0.17608
# [71]	validation_0-logloss:0.00527	validation_0-xgb_custom_metric:-0.17620
# [72]	validation_0-logloss:0.00526	validation_0-xgb_custom_metric:-0.17585
# [73]	validation_0-logloss:0.00524	validation_0-xgb_custom_metric:-0.17570
# [74]	validation_0-logloss:0.00521	validation_0-xgb_custom_metric:-0.17636
# [75]	validation_0-logloss:0.00518	validation_0-xgb_custom_metric:-0.17637
# [76]	validation_0-logloss:0.00515	validation_0-xgb_custom_metric:-0.17634
# [77]	validation_0-logloss:0.00513	validation_0-xgb_custom_metric:-0.17674
# [78]	validation_0-logloss:0.00511	validation_0-xgb_custom_metric:-0.17610
# [79]	validation_0-logloss:0.00508	validation_0-xgb_custom_metric:-0.17656
# [80]	validation_0-logloss:0.00507	validation_0-xgb_custom_metric:-0.17674
# [81]	validation_0-logloss:0.00504	validation_0-xgb_custom_metric:-0.17683
# [82]	validation_0-logloss:0.00502	validation_0-xgb_custom_metric:-0.17696
# [83]	validation_0-logloss:0.00501	validation_0-xgb_custom_metric:-0.17706
# [84]	validation_0-logloss:0.00497	validation_0-xgb_custom_metric:-0.17728
# [85]	validation_0-logloss:0.00497	validation_0-xgb_custom_metric:-0.17703
# [86]	validation_0-logloss:0.00495	validation_0-xgb_custom_metric:-0.17691
# [87]	validation_0-logloss:0.00495	validation_0-xgb_custom_metric:-0.17685
# [88]	validation_0-logloss:0.00494	validation_0-xgb_custom_metric:-0.17708
# [89]	validation_0-logloss:0.00494	validation_0-xgb_custom_metric:-0.17675
# [90]	validation_0-logloss:0.00492	validation_0-xgb_custom_metric:-0.17710
# [91]	validation_0-logloss:0.00492	validation_0-xgb_custom_metric:-0.17660
# [92]	validation_0-logloss:0.00491	validation_0-xgb_custom_metric:-0.17678
# [93]	validation_0-logloss:0.00491	validation_0-xgb_custom_metric:-0.17592
# [94]	validation_0-logloss:0.00490	validation_0-xgb_custom_metric:-0.17627
# [95]	validation_0-logloss:0.00489	validation_0-xgb_custom_metric:-0.17679
# [96]	validation_0-logloss:0.00488	validation_0-xgb_custom_metric:-0.17701
# [97]	validation_0-logloss:0.00488	validation_0-xgb_custom_metric:-0.17732
# [98]	validation_0-logloss:0.00488	validation_0-xgb_custom_metric:-0.17796
# [99]	validation_0-logloss:0.00486	validation_0-xgb_custom_metric:-0.17835
# [0.1774812317234908, 0.16469779458386674, 0.178344727915758, 0.1816329515911632]
# Default metric period is 5 because PythonUserDefinedPerObject is/are not implemented for GPU
# /opt/conda/lib/python3.10/site-packages/catboost/core.py:1780: UserWarning: Failed to optimize method "evaluate" in the passed object:
# Failed in nopython mode pipeline (step: nopython frontend)
# Untyped global name 'p_auc_tpr': Cannot determine Numba type of <class 'function'>
#
# File "../../tmp/ipykernel_34/3195744980.py", line 16:
# <source missing, REPL/exec in use?>
#
#   self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
# 0:	learn: 0.0286892	test: 0.0276001	best: 0.0276001 (0)	total: 129ms	remaining: 2m 9s
# 200:	learn: 0.1757490	test: 0.1633765	best: 0.1633943 (190)	total: 10.3s	remaining: 41.1s
# 400:	learn: 0.1841716	test: 0.1680982	best: 0.1682363 (395)	total: 20.7s	remaining: 30.9s
# 600:	learn: 0.1894483	test: 0.1691603	best: 0.1694090 (575)	total: 31.2s	remaining: 20.7s
# 800:	learn: 0.1925482	test: 0.1697475	best: 0.1698749 (780)	total: 41.6s	remaining: 10.3s
# 999:	learn: 0.1946867	test: 0.1712318	best: 0.1715865 (975)	total: 51.8s	remaining: 0us
# bestTest = 0.1715865402
# bestIteration = 975
# Shrink model to first 976 iterations.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [0]	validation_0-logloss:0.11948	validation_0-xgb_custom_metric:-0.04055
# [1]	validation_0-logloss:0.10958	validation_0-xgb_custom_metric:-0.05558
# [2]	validation_0-logloss:0.10058	validation_0-xgb_custom_metric:-0.05964
# [3]	validation_0-logloss:0.09240	validation_0-xgb_custom_metric:-0.10837
# [4]	validation_0-logloss:0.08493	validation_0-xgb_custom_metric:-0.10815
# [5]	validation_0-logloss:0.07813	validation_0-xgb_custom_metric:-0.10815
# [6]	validation_0-logloss:0.07195	validation_0-xgb_custom_metric:-0.10807
# [7]	validation_0-logloss:0.06630	validation_0-xgb_custom_metric:-0.10773
# [8]	validation_0-logloss:0.06117	validation_0-xgb_custom_metric:-0.10734
# [9]	validation_0-logloss:0.05648	validation_0-xgb_custom_metric:-0.10664
# [10]	validation_0-logloss:0.05217	validation_0-xgb_custom_metric:-0.10664
# [11]	validation_0-logloss:0.04824	validation_0-xgb_custom_metric:-0.10644
# [12]	validation_0-logloss:0.04464	validation_0-xgb_custom_metric:-0.10581
# [13]	validation_0-logloss:0.04134	validation_0-xgb_custom_metric:-0.10565
# [14]	validation_0-logloss:0.03835	validation_0-xgb_custom_metric:-0.11084
# [15]	validation_0-logloss:0.03560	validation_0-xgb_custom_metric:-0.11099
# [16]	validation_0-logloss:0.03307	validation_0-xgb_custom_metric:-0.11049
# [17]	validation_0-logloss:0.03077	validation_0-xgb_custom_metric:-0.11898
# [18]	validation_0-logloss:0.02867	validation_0-xgb_custom_metric:-0.12635
# [19]	validation_0-logloss:0.02673	validation_0-xgb_custom_metric:-0.12631
# [20]	validation_0-logloss:0.02497	validation_0-xgb_custom_metric:-0.13078
# [21]	validation_0-logloss:0.02336	validation_0-xgb_custom_metric:-0.13550
# [22]	validation_0-logloss:0.02188	validation_0-xgb_custom_metric:-0.13555
# [23]	validation_0-logloss:0.02049	validation_0-xgb_custom_metric:-0.13911
# [24]	validation_0-logloss:0.01923	validation_0-xgb_custom_metric:-0.14059
# [25]	validation_0-logloss:0.01809	validation_0-xgb_custom_metric:-0.14067
# [26]	validation_0-logloss:0.01703	validation_0-xgb_custom_metric:-0.13934
# [27]	validation_0-logloss:0.01608	validation_0-xgb_custom_metric:-0.14459
# [28]	validation_0-logloss:0.01520	validation_0-xgb_custom_metric:-0.15187
# [29]	validation_0-logloss:0.01439	validation_0-xgb_custom_metric:-0.15715
# [30]	validation_0-logloss:0.01363	validation_0-xgb_custom_metric:-0.15907
# [31]	validation_0-logloss:0.01294	validation_0-xgb_custom_metric:-0.15989
# [32]	validation_0-logloss:0.01231	validation_0-xgb_custom_metric:-0.15975
# [33]	validation_0-logloss:0.01172	validation_0-xgb_custom_metric:-0.15985
# [34]	validation_0-logloss:0.01118	validation_0-xgb_custom_metric:-0.16053
# [35]	validation_0-logloss:0.01072	validation_0-xgb_custom_metric:-0.15967
# [36]	validation_0-logloss:0.01027	validation_0-xgb_custom_metric:-0.15896
# [37]	validation_0-logloss:0.00986	validation_0-xgb_custom_metric:-0.15823
# [38]	validation_0-logloss:0.00947	validation_0-xgb_custom_metric:-0.15855
# [39]	validation_0-logloss:0.00913	validation_0-xgb_custom_metric:-0.15768
# [40]	validation_0-logloss:0.00881	validation_0-xgb_custom_metric:-0.15786
# [41]	validation_0-logloss:0.00853	validation_0-xgb_custom_metric:-0.16623
# [42]	validation_0-logloss:0.00826	validation_0-xgb_custom_metric:-0.16615
# [43]	validation_0-logloss:0.00800	validation_0-xgb_custom_metric:-0.16678
# [44]	validation_0-logloss:0.00778	validation_0-xgb_custom_metric:-0.16568
# [45]	validation_0-logloss:0.00756	validation_0-xgb_custom_metric:-0.16783
# [46]	validation_0-logloss:0.00737	validation_0-xgb_custom_metric:-0.16967
# [47]	validation_0-logloss:0.00719	validation_0-xgb_custom_metric:-0.16865
# [48]	validation_0-logloss:0.00702	validation_0-xgb_custom_metric:-0.16742
# [49]	validation_0-logloss:0.00686	validation_0-xgb_custom_metric:-0.16691
# [50]	validation_0-logloss:0.00673	validation_0-xgb_custom_metric:-0.16681
# [51]	validation_0-logloss:0.00661	validation_0-xgb_custom_metric:-0.16571
# [52]	validation_0-logloss:0.00649	validation_0-xgb_custom_metric:-0.16493
# [53]	validation_0-logloss:0.00638	validation_0-xgb_custom_metric:-0.16511
# [54]	validation_0-logloss:0.00628	validation_0-xgb_custom_metric:-0.16382
# [55]	validation_0-logloss:0.00621	validation_0-xgb_custom_metric:-0.16579
# [56]	validation_0-logloss:0.00611	validation_0-xgb_custom_metric:-0.16551
# [57]	validation_0-logloss:0.00602	validation_0-xgb_custom_metric:-0.16729
# [58]	validation_0-logloss:0.00596	validation_0-xgb_custom_metric:-0.16626
# [59]	validation_0-logloss:0.00591	validation_0-xgb_custom_metric:-0.16634
# [60]	validation_0-logloss:0.00585	validation_0-xgb_custom_metric:-0.16776
# [61]	validation_0-logloss:0.00578	validation_0-xgb_custom_metric:-0.16836
# [62]	validation_0-logloss:0.00573	validation_0-xgb_custom_metric:-0.16867
# [63]	validation_0-logloss:0.00566	validation_0-xgb_custom_metric:-0.17022
# [64]	validation_0-logloss:0.00562	validation_0-xgb_custom_metric:-0.16947
# [65]	validation_0-logloss:0.00558	validation_0-xgb_custom_metric:-0.16927
# [66]	validation_0-logloss:0.00554	validation_0-xgb_custom_metric:-0.16916
# [67]	validation_0-logloss:0.00549	validation_0-xgb_custom_metric:-0.16787
# [68]	validation_0-logloss:0.00547	validation_0-xgb_custom_metric:-0.16686
# [69]	validation_0-logloss:0.00543	validation_0-xgb_custom_metric:-0.16691
# [70]	validation_0-logloss:0.00540	validation_0-xgb_custom_metric:-0.16629
# [71]	validation_0-logloss:0.00537	validation_0-xgb_custom_metric:-0.16647
# [72]	validation_0-logloss:0.00533	validation_0-xgb_custom_metric:-0.16567
# [73]	validation_0-logloss:0.00531	validation_0-xgb_custom_metric:-0.16602
# [74]	validation_0-logloss:0.00530	validation_0-xgb_custom_metric:-0.16625
# [75]	validation_0-logloss:0.00527	validation_0-xgb_custom_metric:-0.16646
# [76]	validation_0-logloss:0.00524	validation_0-xgb_custom_metric:-0.16645
# [77]	validation_0-logloss:0.00522	validation_0-xgb_custom_metric:-0.16675
# [78]	validation_0-logloss:0.00521	validation_0-xgb_custom_metric:-0.16775
# [79]	validation_0-logloss:0.00519	validation_0-xgb_custom_metric:-0.16712
# [80]	validation_0-logloss:0.00517	validation_0-xgb_custom_metric:-0.16846
# [81]	validation_0-logloss:0.00516	validation_0-xgb_custom_metric:-0.16935
# [82]	validation_0-logloss:0.00515	validation_0-xgb_custom_metric:-0.16916
# [83]	validation_0-logloss:0.00513	validation_0-xgb_custom_metric:-0.16907
# [84]	validation_0-logloss:0.00512	validation_0-xgb_custom_metric:-0.17002
# [85]	validation_0-logloss:0.00510	validation_0-xgb_custom_metric:-0.17116
# [86]	validation_0-logloss:0.00509	validation_0-xgb_custom_metric:-0.17117
# [87]	validation_0-logloss:0.00508	validation_0-xgb_custom_metric:-0.17152
# [88]	validation_0-logloss:0.00507	validation_0-xgb_custom_metric:-0.17124
# [89]	validation_0-logloss:0.00507	validation_0-xgb_custom_metric:-0.17058
# [90]	validation_0-logloss:0.00506	validation_0-xgb_custom_metric:-0.17052
# [91]	validation_0-logloss:0.00506	validation_0-xgb_custom_metric:-0.16984
# [92]	validation_0-logloss:0.00505	validation_0-xgb_custom_metric:-0.16934
# [93]	validation_0-logloss:0.00504	validation_0-xgb_custom_metric:-0.16931
# [94]	validation_0-logloss:0.00504	validation_0-xgb_custom_metric:-0.17009
# [95]	validation_0-logloss:0.00503	validation_0-xgb_custom_metric:-0.16966
# [96]	validation_0-logloss:0.00502	validation_0-xgb_custom_metric:-0.16890
# [97]	validation_0-logloss:0.00500	validation_0-xgb_custom_metric:-0.16935
# [98]	validation_0-logloss:0.00500	validation_0-xgb_custom_metric:-0.16890
# [99]	validation_0-logloss:0.00499	validation_0-xgb_custom_metric:-0.16969
# [0.17158667778502484, 0.16100714712284955, 0.17151736693059005, 0.1742569826867347]
# Default metric period is 5 because PythonUserDefinedPerObject is/are not implemented for GPU
# /opt/conda/lib/python3.10/site-packages/catboost/core.py:1780: UserWarning: Failed to optimize method "evaluate" in the passed object:
# Failed in nopython mode pipeline (step: nopython frontend)
# Untyped global name 'p_auc_tpr': Cannot determine Numba type of <class 'function'>
#
# File "../../tmp/ipykernel_34/3195744980.py", line 16:
# <source missing, REPL/exec in use?>
#
#   self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
# 0:	learn: 0.0290801	test: 0.0258610	best: 0.0258610 (0)	total: 130ms	remaining: 2m 10s
# 200:	learn: 0.1778185	test: 0.1460303	best: 0.1466810 (190)	total: 10.6s	remaining: 42s
# 400:	learn: 0.1864046	test: 0.1511416	best: 0.1512514 (390)	total: 21s	remaining: 31.3s
# 600:	learn: 0.1914800	test: 0.1556895	best: 0.1556895 (600)	total: 31.4s	remaining: 20.8s
# 800:	learn: 0.1948858	test: 0.1572787	best: 0.1579061 (700)	total: 42s	remaining: 10.4s
# 999:	learn: 0.1967777	test: 0.1581927	best: 0.1582771 (985)	total: 52.4s	remaining: 0us
# bestTest = 0.1582771482
# bestIteration = 985
# Shrink model to first 986 iterations.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [0]	validation_0-logloss:0.11934	validation_0-xgb_custom_metric:-0.04119
# [1]	validation_0-logloss:0.10945	validation_0-xgb_custom_metric:-0.04111
# [2]	validation_0-logloss:0.10042	validation_0-xgb_custom_metric:-0.04109
# [3]	validation_0-logloss:0.09223	validation_0-xgb_custom_metric:-0.05169
# [4]	validation_0-logloss:0.08477	validation_0-xgb_custom_metric:-0.06758
# [5]	validation_0-logloss:0.07796	validation_0-xgb_custom_metric:-0.07466
# [6]	validation_0-logloss:0.07177	validation_0-xgb_custom_metric:-0.07690
# [7]	validation_0-logloss:0.06612	validation_0-xgb_custom_metric:-0.07684
# [8]	validation_0-logloss:0.06099	validation_0-xgb_custom_metric:-0.08090
# [9]	validation_0-logloss:0.05628	validation_0-xgb_custom_metric:-0.08072
# [10]	validation_0-logloss:0.05199	validation_0-xgb_custom_metric:-0.08072
# [11]	validation_0-logloss:0.04806	validation_0-xgb_custom_metric:-0.08050
# [12]	validation_0-logloss:0.04447	validation_0-xgb_custom_metric:-0.08050
# [13]	validation_0-logloss:0.04118	validation_0-xgb_custom_metric:-0.08621
# [14]	validation_0-logloss:0.03817	validation_0-xgb_custom_metric:-0.09093
# [15]	validation_0-logloss:0.03544	validation_0-xgb_custom_metric:-0.10585
# [16]	validation_0-logloss:0.03292	validation_0-xgb_custom_metric:-0.10524
# [17]	validation_0-logloss:0.03063	validation_0-xgb_custom_metric:-0.11008
# [18]	validation_0-logloss:0.02853	validation_0-xgb_custom_metric:-0.12079
# [19]	validation_0-logloss:0.02659	validation_0-xgb_custom_metric:-0.11986
# [20]	validation_0-logloss:0.02483	validation_0-xgb_custom_metric:-0.11923
# [21]	validation_0-logloss:0.02320	validation_0-xgb_custom_metric:-0.11832
# [22]	validation_0-logloss:0.02171	validation_0-xgb_custom_metric:-0.12495
# [23]	validation_0-logloss:0.02033	validation_0-xgb_custom_metric:-0.12520
# [24]	validation_0-logloss:0.01909	validation_0-xgb_custom_metric:-0.13045
# [25]	validation_0-logloss:0.01794	validation_0-xgb_custom_metric:-0.13374
# [26]	validation_0-logloss:0.01689	validation_0-xgb_custom_metric:-0.13358
# [27]	validation_0-logloss:0.01593	validation_0-xgb_custom_metric:-0.13174
# [28]	validation_0-logloss:0.01504	validation_0-xgb_custom_metric:-0.13188
# [29]	validation_0-logloss:0.01421	validation_0-xgb_custom_metric:-0.13332
# [30]	validation_0-logloss:0.01350	validation_0-xgb_custom_metric:-0.13260
# [31]	validation_0-logloss:0.01281	validation_0-xgb_custom_metric:-0.13292
# [32]	validation_0-logloss:0.01218	validation_0-xgb_custom_metric:-0.13450
# [33]	validation_0-logloss:0.01160	validation_0-xgb_custom_metric:-0.13436
# [34]	validation_0-logloss:0.01107	validation_0-xgb_custom_metric:-0.13363
# [35]	validation_0-logloss:0.01058	validation_0-xgb_custom_metric:-0.13291
# [36]	validation_0-logloss:0.01014	validation_0-xgb_custom_metric:-0.13248
# [37]	validation_0-logloss:0.00973	validation_0-xgb_custom_metric:-0.13222
# [38]	validation_0-logloss:0.00934	validation_0-xgb_custom_metric:-0.13224
# [39]	validation_0-logloss:0.00900	validation_0-xgb_custom_metric:-0.13195
# [40]	validation_0-logloss:0.00869	validation_0-xgb_custom_metric:-0.13093
# [41]	validation_0-logloss:0.00839	validation_0-xgb_custom_metric:-0.14373
# [42]	validation_0-logloss:0.00813	validation_0-xgb_custom_metric:-0.14445
# [43]	validation_0-logloss:0.00788	validation_0-xgb_custom_metric:-0.14518
# [44]	validation_0-logloss:0.00766	validation_0-xgb_custom_metric:-0.14430
# [45]	validation_0-logloss:0.00746	validation_0-xgb_custom_metric:-0.14565
# [46]	validation_0-logloss:0.00726	validation_0-xgb_custom_metric:-0.15465
# [47]	validation_0-logloss:0.00708	validation_0-xgb_custom_metric:-0.15477
# [48]	validation_0-logloss:0.00691	validation_0-xgb_custom_metric:-0.15304
# [49]	validation_0-logloss:0.00677	validation_0-xgb_custom_metric:-0.15299
# [50]	validation_0-logloss:0.00663	validation_0-xgb_custom_metric:-0.15366
# [51]	validation_0-logloss:0.00650	validation_0-xgb_custom_metric:-0.15344
# [52]	validation_0-logloss:0.00639	validation_0-xgb_custom_metric:-0.15348
# [53]	validation_0-logloss:0.00628	validation_0-xgb_custom_metric:-0.15305
# [54]	validation_0-logloss:0.00618	validation_0-xgb_custom_metric:-0.15944
# [55]	validation_0-logloss:0.00609	validation_0-xgb_custom_metric:-0.15959
# [56]	validation_0-logloss:0.00602	validation_0-xgb_custom_metric:-0.15841
# [57]	validation_0-logloss:0.00594	validation_0-xgb_custom_metric:-0.15731
# [58]	validation_0-logloss:0.00589	validation_0-xgb_custom_metric:-0.15572
# [59]	validation_0-logloss:0.00582	validation_0-xgb_custom_metric:-0.15542
# [60]	validation_0-logloss:0.00576	validation_0-xgb_custom_metric:-0.15534
# [61]	validation_0-logloss:0.00571	validation_0-xgb_custom_metric:-0.15511
# [62]	validation_0-logloss:0.00565	validation_0-xgb_custom_metric:-0.15520
# [63]	validation_0-logloss:0.00561	validation_0-xgb_custom_metric:-0.15315
# [64]	validation_0-logloss:0.00556	validation_0-xgb_custom_metric:-0.15346
# [65]	validation_0-logloss:0.00551	validation_0-xgb_custom_metric:-0.15701
# [66]	validation_0-logloss:0.00546	validation_0-xgb_custom_metric:-0.15666
# [67]	validation_0-logloss:0.00542	validation_0-xgb_custom_metric:-0.15659
# [68]	validation_0-logloss:0.00539	validation_0-xgb_custom_metric:-0.15672
# [69]	validation_0-logloss:0.00538	validation_0-xgb_custom_metric:-0.15512
# [70]	validation_0-logloss:0.00536	validation_0-xgb_custom_metric:-0.15511
# [71]	validation_0-logloss:0.00534	validation_0-xgb_custom_metric:-0.15598
# [72]	validation_0-logloss:0.00533	validation_0-xgb_custom_metric:-0.15633
# [73]	validation_0-logloss:0.00530	validation_0-xgb_custom_metric:-0.15593
# [74]	validation_0-logloss:0.00526	validation_0-xgb_custom_metric:-0.15600
# [75]	validation_0-logloss:0.00524	validation_0-xgb_custom_metric:-0.15588
# [76]	validation_0-logloss:0.00524	validation_0-xgb_custom_metric:-0.15460
# [77]	validation_0-logloss:0.00522	validation_0-xgb_custom_metric:-0.15424
# [78]	validation_0-logloss:0.00521	validation_0-xgb_custom_metric:-0.15467
# [79]	validation_0-logloss:0.00521	validation_0-xgb_custom_metric:-0.15495
# [80]	validation_0-logloss:0.00520	validation_0-xgb_custom_metric:-0.15400
# [81]	validation_0-logloss:0.00517	validation_0-xgb_custom_metric:-0.15638
# [82]	validation_0-logloss:0.00516	validation_0-xgb_custom_metric:-0.15734
# [83]	validation_0-logloss:0.00514	validation_0-xgb_custom_metric:-0.15611
# [84]	validation_0-logloss:0.00512	validation_0-xgb_custom_metric:-0.15585
# [85]	validation_0-logloss:0.00511	validation_0-xgb_custom_metric:-0.15676
# [0.15827714821093955, 0.14789096100651375, 0.159585437672883, 0.15935843669135358]
# Total Score 0.1717550436254645

# %%
submit = pd.read_csv('/kaggle/input/isic-2024-challenge/sample_submission.csv')

# %%
for x in ['lesion_id', 'iddx_full', 'iddx_1', 'iddx_2', 'iddx_3', 'iddx_4', 'iddx_5', 'mel_mitotic_index', 'mel_thick_mm', 'tbp_lv_dnn_lesion_confidence']:
    drop_cols.remove(x)

# %%
preds = np.mean([
    np.mean(estim.predict_proba(test_data.drop(drop_cols,axis=1),cat_features=cat_cols),axis=0)
    for estim in model.models
],axis=0)

# %%
submit['target'] = preds

# %%
submit.to_csv('submission.csv',index=False)
