# %%
import pandas as pd
import numpy as np
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import train_test_split, TimeSeriesSplit, StratifiedKFold, StratifiedGroupKFold, GroupShuffleSplit
from sklearn.metrics import roc_auc_score
import random
from statistics import mean
from tqdm.auto import tqdm, trange
from sklearn.base import BaseEstimator

# %%
train_data = pd.read_csv('dodohack/Data Secrets First Cup/train_target.csv',parse_dates=['LocalBeginDate','LocalEndDate'])
test_data = pd.read_csv('dodohack/Data Secrets First Cup/test.csv',parse_dates=['LocalBeginDate','LocalEndDate'])
sample_submit = pd.read_csv('dodohack/Data Secrets First Cup/submit.csv')
orders_data = pd.read_csv('dodohack/Data Secrets First Cup/orders.csv',parse_dates=['SaleDate','Date'])
mobile_data = pd.read_csv('dodohack/Data Secrets First Cup/mobile_events.csv',parse_dates=['Timestamp'])
clients_data = pd.read_csv('dodohack/Data Secrets First Cup/clients_promo_october.csv',parse_dates=['LocalBeginDate','LocalEndDate'])

# %%
def mounth_count_day(x):
    months = [31,28,31,30,31,30,31,31,30,31,30,31]
    return sum(months[:x])

def create_time_features(df,time_col):
    df['month'] = df[time_col].dt.month
    df['day'] = df[time_col].dt.day
    df['hour'] = df[time_col].dt.hour
    df['year'] = df[time_col].dt.year
    df['weekofyear'] = df[time_col].apply(lambda x: x.weekofyear)
    df['dayofweek'] = df[time_col].dt.dayofweek
    df['dayofyear'] = df[time_col].dt.dayofyear
    df['absolute_time'] = (df[time_col] - df[time_col].min()).dt.days
    
    df['all_day_time'] = df[time_col].apply(lambda x: x.hour * 3600 + x.minute * 60 + x.second)
    df['all_week_time'] = df[time_col].apply(lambda x: x.dayofweek * 24 + x.hour)
    
    df['cl_early_morning'] = ((df['hour'] > 4) & (df['hour'] <= 8)).astype('int16')
    df['cl_is_weekend'] = (df['dayofweek'] > 4).astype('int16')
    return df

# %%
mobile_data = create_time_features(mobile_data,'Timestamp')
orders_data = create_time_features(orders_data,'SaleDate')

# %%
mobile_data
# Out:
#                                ClientUUId  \
# 0        000D3A22FA54A81611EB315CF5443815
# 1        2A4A64AF719E994511EE3F2D8B31E188
# 2        000D3AAC977BBB2F11ECDD081F5481AE
# 3        000D3A21DA51A81411EAE468856F96F1
# 4        000D3A23B0DC80D811E67F4D0A9CA345
# ...                                   ...
# 3916649  000D3A25D54580E011E707D4762E0C84
# 3916650  CEA31E584572ADD411ED0E4D10ED070E
# 3916651  000D3A25D54580E011E707D4762E0C84
# 3916652  CEA31E584572ADD411ED0E4D10ED070E
# 3916653  000D3A25D54580E011E707D4762E0C84
#
#                                    VisitToken       EventName Platform  \
# 0        976627AD-76DC-41D9-981E-F2A6CA14B3A9     screen_menu      ios
# 1        5b22e610-c71e-4b6a-a842-71e8575ece87     screen_menu  android
# 2        BDCEB72F-2B6A-4565-801A-6CB729279C6F        open_app      ios
# 3        A66E2DA6-4E2E-4C37-9FBF-627732623212     add_to_cart      ios
# 4        1BE8139F-A3D3-439F-A51B-5CBD4D3FFF1B     screen_menu      ios
# ...                                       ...             ...      ...
# 3916649  C5EC0144-6C3C-45C2-B0A4-A7A2B6B45444        open_app      ios
# 3916650  5a8b6b6c-e4ad-4fd9-aad9-895fa987ddf1  screen_profile  android
# 3916651  C5EC0144-6C3C-45C2-B0A4-A7A2B6B45444       close_app      ios
# 3916652  5a8b6b6c-e4ad-4fd9-aad9-895fa987ddf1     screen_menu  android
# 3916653  C5EC0144-6C3C-45C2-B0A4-A7A2B6B45444       close_app      ios
#
#                                Timestamp  month  day  hour  year  weekofyear  \
# 0       2023-10-29 16:14:21.343000+00:00     10   29    16  2023          43
# 1       2023-10-29 11:04:36.484000+00:00     10   29    11  2023          43
# 2       2023-10-29 11:14:34.723000+00:00     10   29    11  2023          43
# 3       2023-10-29 14:03:08.363000+00:00     10   29    14  2023          43
# 4       2023-10-29 08:35:40.127000+00:00     10   29     8  2023          43
# ...                                  ...    ...  ...   ...   ...         ...
# 3916649 2023-10-14 06:00:21.558000+00:00     10   14     6  2023          41
# 3916650 2023-10-13 12:55:57.752000+00:00     10   13    12  2023          41
# 3916651 2023-10-14 06:00:21.515000+00:00     10   14     6  2023          41
# 3916652 2023-10-13 12:55:56.303000+00:00     10   13    12  2023          41
# 3916653 2023-10-14 06:00:21.558000+00:00     10   14     6  2023          41
#
#          dayofweek  dayofyear  absolute_time  all_day_time  all_week_time  \
# 0                6        302            387         58461            160
# 1                6        302            386         39876            155
# 2                6        302            386         40474            155
# 3                6        302            387         50588            158
# 4                6        302            386         30940            152
# ...            ...        ...            ...           ...            ...
# 3916649          5        287            371         21621            126
# 3916650          4        286            370         46557            108
# 3916651          5        287            371         21621            126
# 3916652          4        286            370         46556            108
# 3916653          5        287            371         21621            126
#
#          cl_early_morning  cl_is_weekend
# 0                       0              1
# 1                       0              1
# 2                       0              1
# 3                       0              1
# 4                       1              1
# ...                   ...            ...
# 3916649                 1              1
# 3916650                 0              0
# 3916651                 1              1
# 3916652                 0              0
# 3916653                 1              1
#
# [3916654 rows x 17 columns]

# %%
def get_shift_features(data,time_col='absolute_time',user_col='ClientUUId',prefix=''):
    shift_time = data.groupby(user_col)[time_col].agg(lambda x: np.diff(np.sort(x)).tolist())
    shift_features = pd.DataFrame(index=shift_time.index)
    shift_features[f'{prefix}_mean'] = shift_time.apply(np.mean)
    shift_features[f'{prefix}_min'] = shift_time.apply(np.min)
    shift_features[f'{prefix}_max'] = shift_time.apply(np.max)
    shift_features[f'{prefix}_std'] = shift_time.apply(np.std)
    shift_features[f'{prefix}_polyfit'] = shift_time.apply(lambda x:np.polyfit(range(len(x)), x, 1)[1] if len(x) > 10 else -100)
    shift_features[f'{prefix}_polyfit_st'] = shift_time.apply(lambda x:np.polyfit(range(len(x)), x, 1)[0] if len(x) > 10 else -100)
    return shift_features


def get_mobile_data_features(mobile_data):
    time_day_feats = mobile_data.groupby('ClientUUId')['absolute_time'].agg(['min','max','mean','std','nunique','count'])
    time_day_feats['diff'] = time_day_feats['max'] - time_day_feats['min']
    time_day_feats['otn_diff'] = time_day_feats['diff'] / time_day_feats['mean']
    time_day_feats['designity'] = time_day_feats['nunique'] / time_day_feats['count']
    time_day_feats.columns = [f'mobile_time_{x}' for x in time_day_feats.columns]
    
    time_shift_feats = get_shift_features(mobile_data,prefix='mobile_data')
    
    time_hour_features = mobile_data.groupby('ClientUUId')['hour'].agg(['min','max','mean','std','nunique'])
    time_hour_features.columns = [f'mobile_hour_{x}' for x in time_hour_features.columns]
    
    
    platform_featues = pd.pivot_table(
                             mobile_data,
                             index =['ClientUUId'],
                             values=['absolute_time'],
                             columns=['Platform'],
                             aggfunc=['count','nunique','mean','min','max','std']
    ).fillna(-1).sort_index()
    
    event_featues = pd.pivot_table(
                             mobile_data,
                             index =['ClientUUId'],
                             values=['absolute_time'],
                             columns=['EventName'],
                             aggfunc=['count','nunique','mean','min','max','std']
    ).fillna(-1).sort_index()
    
    day_of_week_featues = pd.pivot_table(
                             mobile_data,
                             index =['ClientUUId'],
                             values=['dayofweek'],
                             columns=['EventName'],
                             aggfunc=['count','nunique','mean']
    ).fillna(-1).sort_index()

    
    hour_counters = pd.pivot_table(
                             mobile_data,
                             index =['ClientUUId'],
                             values=['absolute_time'],
                             columns=['hour'],
                             aggfunc=['count','nunique','mean']
    ).fillna(-1).sort_index()
    
    platform_featues.columns = [f'mobile_platform_{x[0]}_{x[2]}' for x in platform_featues.columns]
    event_featues.columns = [f'mobile_event_{x[0]}_{x[2]}' for x in event_featues.columns]
    hour_counters.columns = [f'mobile_hour_{x[0]}_{x[2]}' for x in hour_counters.columns]
    day_of_week_featues.columns = [f'mobile_dayofweek_{x[0]}_{x[2]}' for x in day_of_week_featues.columns]
    
    mobile_data['VisitToken_count'] = mobile_data.groupby('VisitToken')['EventName'].transform('count')
    visitors_features = mobile_data.groupby('ClientUUId')['VisitToken_count'].agg(['min','max','mean','std'])
    visitors_features.columns = [f'mobile_visitors_{x}' for x in visitors_features.columns]
    visitors_features['mobile_visitors_nunique'] = mobile_data.groupby('ClientUUId')['VisitToken'].agg('nunique')
    
    for col in event_featues.columns:
        event_featues[f'{col}_otn'] = event_featues[col] / time_day_feats['mobile_time_count']
    for col in platform_featues.columns:
        platform_featues[f'{col}_otn'] = platform_featues[col] / time_day_feats['mobile_time_count']
    
    return pd.concat([
        time_day_feats,
        time_hour_features,
        platform_featues,
        event_featues,
        hour_counters,
        visitors_features,
        time_shift_feats
    ],axis=1)

# %%
mobile_features = get_mobile_data_features(mobile_data)

# %%
def get_clients_features(clients_data):
    clients_data['vugoda'] = clients_data['Discount'] / clients_data['OrderPrice']
    clients_data['Id+OrderType'] = clients_data['Id'].astype(str) + clients_data['OrderType'].astype(str)
    
    order_price_feats = clients_data.groupby('ClientUUId')['OrderPrice'].agg(['mean','std','sum','mean','max','count'])
    Discount_feats = clients_data.groupby('ClientUUId')['Discount'].agg(['mean','std','sum','mean','max','nunique'])
    vugoda_feats = clients_data.groupby('ClientUUId')['vugoda'].agg(['mean','std','sum','mean','max','nunique'])
    
    order_price_feats.columns = [f'clients_order_price_{x}' for x in order_price_feats.columns]
    Discount_feats.columns = [f'clients_discount_{x}' for x in Discount_feats.columns]
    vugoda_feats.columns = [f'clients_vugoda_{x}' for x in vugoda_feats.columns]
    
    id_features = pd.pivot_table(
                             clients_data,
                             index =['ClientUUId'],
                             values=['OrderPrice',],
                             columns=['Id'],
                             aggfunc=['count','nunique','sum']
    ).fillna(-1).sort_index()
    
    order_features = pd.pivot_table(
                             clients_data,
                             index =['ClientUUId'],
                             values=['OrderPrice',],
                             columns=['OrderType'],
                             aggfunc=['count','nunique','sum']
    ).fillna(-1).sort_index()
    
    orderid_features = pd.pivot_table(
                             clients_data,
                             index =['ClientUUId'],
                             values=['OrderPrice'],
                             columns=['Id+OrderType'],
                             aggfunc=['count']
    ).fillna(-1).sort_index()
    
    id_features.columns = [f'clients_id_{x[0]}_{x[1]}_{x[2]}' for x in id_features.columns]
    order_features.columns = [f'clients_order_{x[0]}_{x[1]}_{x[2]}' for x in order_features.columns]
    orderid_features.columns = [f'clients_orderid_{x[0]}_{x[2]}' for x in orderid_features.columns]

    return pd.concat([
        id_features,
        order_features,
        orderid_features,
        order_price_feats,
        Discount_feats,
        vugoda_feats
    ],axis=1)

# %%
clients_features = get_clients_features(clients_data)

# %%
def get_order_data_feats(orders_data):
    time_day_feats = mobile_data.groupby('ClientUUId')['absolute_time'].agg(['min','max','mean','std','nunique','count'])
    time_day_feats['diff'] = time_day_feats['max'] - time_day_feats['min']
    time_day_feats['otn_diff'] = time_day_feats['diff'] / time_day_feats['mean']
    time_day_feats['designity'] = time_day_feats['nunique'] / time_day_feats['count']
    time_day_feats.columns = [f'order_time_{x}' for x in time_day_feats.columns]
    
    time_shift_feats = get_shift_features(orders_data,prefix='orders_data')
    
    orders_data = orders_data.fillna(0)
    orders_data['OrderUUId_count'] = orders_data.groupby('OrderUUId').transform('count')['NewClient']
    orders_data['addressId_count'] = orders_data.groupby('addressId').transform('count')['NewClient']
    orders_data['deliverySectorId_count'] = orders_data.groupby('deliverySectorId').transform('count')['NewClient']
    orders_data['UnitUUId_count'] = orders_data.groupby('UnitUUId').transform('count')['NewClient']
    orders_data['ProductUUId_count'] = orders_data.groupby('ProductUUId').transform('count')['NewClient']
    
    orders_data['OrderUUId_appl_mean'] = orders_data.groupby('OrderUUId')['apply_promo'].agg('mean').loc[orders_data['OrderUUId']].values
    orders_data['addressId_appl_mean'] = orders_data.groupby('addressId')['apply_promo'].agg('mean').loc[orders_data['addressId']].values
    orders_data['deliverySectorId_appl_mean'] = orders_data.groupby('deliverySectorId')['apply_promo'].agg('mean').loc[orders_data['deliverySectorId']].values
    orders_data['UnitUUId_appl_mean'] = orders_data.groupby('UnitUUId')['apply_promo'].agg('mean').loc[orders_data['UnitUUId']].values
    orders_data['ProductUUId_appl_mean'] = orders_data.groupby('ProductUUId')['apply_promo'].agg('mean').loc[orders_data['ProductUUId']].values
    
    orders_data['OrderUUId_appl_sum'] = orders_data.groupby('OrderUUId')['apply_promo'].agg('sum').loc[orders_data['OrderUUId']].values
    orders_data['addressId_appl_sum'] = orders_data.groupby('addressId')['apply_promo'].agg('sum').loc[orders_data['addressId']].values
    orders_data['deliverySectorId_appl_sum'] = orders_data.groupby('deliverySectorId')['apply_promo'].agg('sum').loc[orders_data['deliverySectorId']].values
    orders_data['UnitUUId_appl_sum'] = orders_data.groupby('UnitUUId')['apply_promo'].agg('sum').loc[orders_data['UnitUUId']].values
    orders_data['ProductUUId_appl_sum'] = orders_data.groupby('ProductUUId')['apply_promo'].agg('sum').loc[orders_data['ProductUUId']].values


    orders_data['Skidka'] = orders_data['MenuPrice'] - orders_data['ProductTotalPrice']
    orders_data['Skidka_otn'] = orders_data['Skidka'] / orders_data['ProductTotalPrice']
    
    appl_features = orders_data.groupby('ClientUUId')['apply_promo'].agg(['mean','count','std','sum'])
    newcl_features = orders_data.groupby('ClientUUId')['NewClient'].agg(['sum'])
    appl_features.columns = [f'order_appl_{x}' for x in appl_features.columns]
    newcl_features.columns = [f'order_newcl_{x}' for x in newcl_features.columns]
    
    category_features = pd.pivot_table(
                             orders_data,
                             index =['ClientUUId'],
                             values=['MenuPrice','absolute_time'],
                             columns=['apply_promo','CategoryId'],
                             aggfunc=['count','sum','mean','std']
    ).fillna(-1).sort_index()
    
    payment_features = pd.pivot_table(
                             orders_data,
                             index =['ClientUUId'],
                             values=['MenuPrice','absolute_time'],
                             columns=['apply_promo','OrderPaymentType'],
                             aggfunc=['count','nunique','sum','mean','std']
    ).fillna(-1).sort_index()

    
    order_features = pd.pivot_table(
                             orders_data,
                             index =['ClientUUId'],
                             values=['MenuPrice','absolute_time'],
                             columns=['apply_promo','OrderType'],
                             aggfunc=['count','nunique','sum','mean','std']
    ).fillna(-1).sort_index()
    
    order_state_features = pd.pivot_table(
                             orders_data,
                             index =['ClientUUId'],
                             values=['MenuPrice'],
                             columns=['apply_promo','OrderState'],
                             aggfunc=['count','nunique','sum','mean']
    ).fillna(-1).sort_index()


    features = pd.pivot_table(
                             orders_data,
                             index =['ClientUUId'],
                             values=['MenuPrice','ClientOrderNumber',
                                     'ProductTotalPrice','OrderTotalPrice',
                                     'OrderUUId_count','Skidka','Skidka_otn',
                                     'addressId_count','deliverySectorId_count',
                                     'UnitUUId_count','ProductUUId_count',
                                     'OrderUUId_appl_mean','addressId_appl_mean',
                                     'deliverySectorId_appl_mean',
                                     'UnitUUId_appl_mean','ProductUUId_appl_mean',
                                     'OrderUUId_appl_sum','addressId_appl_sum',
                                     'deliverySectorId_appl_sum',
                                     'UnitUUId_appl_sum','ProductUUId_appl_sum',
                                     'hour','absolute_time','dayofweek','month','all_day_time'],
                             columns=['apply_promo'],
                             aggfunc=['mean','sum','min','max','std','nunique',lambda x:np.max(x) - np.min(x)]
        
    ).fillna(-1).sort_index()
    
    features.columns = [f'order_feats_{x[0]}_{x[1]}_{x[2]}' for x in features.columns]
    payment_features.columns = [f'order_payment_{x[0]}_{x[1]}_{x[2]}_{x[3]}' for x in payment_features.columns]
    order_features.columns = [f'order_order_{x[0]}_{x[1]}_{x[2]}_{x[3]}' for x in order_features.columns]
    category_features.columns = [f'order_order_{x[0]}_{x[1]}_{x[2]}_{x[3]}' for x in category_features.columns]
    order_state_features.columns = [f'order_order_{x[0]}_{x[1]}_{x[2]}_{x[3]}' for x in order_state_features.columns]
    
    return pd.concat([
        appl_features,
        newcl_features,
        payment_features,
        order_features,
        time_day_feats,
        order_state_features,
        time_shift_feats,
        features,
    ],axis=1)

# %%
order_features = get_order_data_feats(orders_data)
# Out:
# /tmp/ipykernel_168/1861438450.py:88: RuntimeWarning: invalid value encountered in scalar subtract
#   aggfunc=['mean','sum','min','max','std','nunique',lambda x:np.max(x) - np.min(x)]

# %%
mobile_embeds = pd.read_parquet('mobile_embeds.parquet')
order_embeds = pd.read_parquet('order_embeds.parquet')

# %%
mobile_embeds.columns = [f"mobile_{x}" for x in mobile_embeds.columns]
order_embeds.columns = [f"order_{x}" for x in order_embeds.columns]

# %%
all_features = pd.concat([
    order_features,
    clients_features,
    mobile_features,
    mobile_embeds,
    order_embeds
],axis=1).fillna(-100)

# %%
all_features = all_features.T.drop_duplicates().T
all_features['ClientUUId'] = all_features.index
all_features.index = range(len(all_features))

# %%
all_features.shape
# Out:
# (30000, 919)

# %%
train_data = train_data.merge(all_features)

# %%
params = {
    'iterations':1000,
    'learning_rate':0.01,
    'loss_function':'CrossEntropy',
    'max_depth':7,
    'eval_metric':'AUC',
    'task_type':'GPU',
    'random_seed':56
}

drop_cols = [
    'LocalBeginDate',
    'LocalEndDate',
    'ClientUUId',
]

cat_cols = [
    'Id',
    'OrderType',
]

label_col = 'apply_promo'
algorithm = 'RecursiveByShapValues'
num_fold = 5
n_fold_test = 10
test_c_stop = 10
num_repits = 3
num_features_to_select = 128
features_for_select = '0-919'
steps = 10

# %%
def model_builder(train_data):
    splitter = GroupShuffleSplit(test_size=0.2, n_splits=2,random_state=56)
    split = splitter.split(train_data, groups=train_data['ClientUUId'])
    train_inds, test_inds = next(split)

    train_df, eval_df = train_data.iloc[train_inds], train_data.iloc[test_inds]
    
    train_pool = Pool(
        train_df.drop([label_col]+drop_cols,axis=1),
        label = train_df[label_col],
        cat_features = cat_cols
    )

    eval_pool = Pool(
        eval_df.drop([label_col]+drop_cols,axis=1),
        label = eval_df[label_col],
        cat_features = cat_cols
    )
    
    cbm = CatBoostClassifier(**params)
    out = cbm.select_features(
        train_pool,
        eval_set=eval_pool,
        algorithm=algorithm,
        features_for_select=features_for_select,
        num_features_to_select=num_features_to_select,
        steps=steps,
        shap_calc_type=None,
        train_final_model=True,
        verbose=300,
        plot=False
    )
    return cbm, out

# %%
class TestKFoldWrapper():
    def __init__(self,num_folds=10,top_c=1,random_state=56):
        self.top_c = top_c
        self.kfold = StratifiedGroupKFold(num_folds,random_state=random_state,shuffle=True)
    
    def run_experiments(self,model_builder,train_data,label_col=None):
        self.models = []
        self.outs = []
        c = 0
        
        for train_index, test_index in tqdm(self.kfold.split(train_data,train_data[label_col],groups=train_data['ClientUUId'])):
            train_df = train_data.iloc[train_index]
            test_df = train_data.iloc[test_index]
            
            model,outs = model_builder(train_df)
            self.outs.append(outs)
            self.models.append(model)
            c += 1
            if c >= self.top_c:
                break

# %%
evaluator = TestKFoldWrapper(n_fold_test,test_c_stop)

evaluator.run_experiments(
    model_builder=model_builder,
    train_data=train_data,
    label_col=label_col
)
# Out:
# 0it [00:00, ?it/s]
# Default metric period is 5 because AUC is/are not implemented for GPU
# Step #1 out of 10
# 0:	test: 0.7365037	best: 0.7365037 (0)	total: 81.7ms	remaining: 1m 21s
# 300:	test: 0.7682055	best: 0.7752452 (165)	total: 24.4s	remaining: 56.7s
# 600:	test: 0.7637926	best: 0.7752452 (165)	total: 49.4s	remaining: 32.8s
# 900:	test: 0.7583201	best: 0.7752452 (165)	total: 1m 14s	remaining: 8.15s
# 999:	test: 0.7577667	best: 0.7752452 (165)	total: 1m 22s	remaining: 0us
# bestTest = 0.7752452493
# bestIteration = 165
# Shrink model to first 166 iterations.
# Feature #412 eliminated
# Feature #859 eliminated
# Feature #918 eliminated
# Feature #337 eliminated
# Feature #60 eliminated
# Feature #901 eliminated
# Feature #416 eliminated
# Feature #178 eliminated
# Feature #88 eliminated
# Feature #332 eliminated
# Feature #329 eliminated
# Feature #334 eliminated
# Feature #347 eliminated
# Feature #163 eliminated
# Feature #310 eliminated
# Feature #75 eliminated
# Feature #405 eliminated
# Feature #331 eliminated
# Feature #328 eliminated
# Feature #149 eliminated
# Feature #31 eliminated
# Feature #872 eliminated
# Feature #427 eliminated
# Feature #189 eliminated
# Feature #916 eliminated
# Feature #399 eliminated
# Feature #16 eliminated
# Feature #235 eliminated
# Feature #191 eliminated
# Feature #910 eliminated
# Feature #914 eliminated
# Feature #287 eliminated
# Feature #421 eliminated
# Feature #391 eliminated
# Feature #29 eliminated
# Feature #344 eliminated
# Feature #820 eliminated
# Feature #251 eliminated
# Feature #845 eliminated
# Feature #294 eliminated
# Feature #439 eliminated
# Feature #387 eliminated
# Feature #254 eliminated
# Feature #913 eliminated
# Feature #274 eliminated
# Feature #292 eliminated
# Feature #902 eliminated
# Feature #338 eliminated
# Feature #25 eliminated
# Feature #200 eliminated
# Feature #275 eliminated
# Feature #420 eliminated
# Feature #321 eliminated
# Feature #58 eliminated
# Feature #335 eliminated
# Feature #299 eliminated
# Feature #70 eliminated
# Feature #319 eliminated
# Feature #852 eliminated
# Feature #691 eliminated
# Feature #491 eliminated
# Feature #894 eliminated
# Feature #739 eliminated
# Feature #226 eliminated
# Feature #814 eliminated
# Feature #860 eliminated
# Feature #404 eliminated
# Feature #122 eliminated
# Feature #878 eliminated
# Feature #784 eliminated
# Feature #493 eliminated
# Feature #495 eliminated
# Feature #713 eliminated
# Feature #498 eliminated
# Feature #425 eliminated
# Feature #542 eliminated
# Feature #152 eliminated
# Feature #555 eliminated
# Feature #668 eliminated
# Feature #541 eliminated
# Feature #66 eliminated
# Feature #465 eliminated
# Feature #631 eliminated
# Feature #454 eliminated
# Feature #69 eliminated
# Feature #689 eliminated
# Feature #683 eliminated
# Feature #854 eliminated
# Feature #804 eliminated
# Feature #209 eliminated
# Feature #842 eliminated
# Feature #119 eliminated
# Feature #768 eliminated
# Feature #893 eliminated
# Feature #49 eliminated
# Feature #718 eliminated
# Feature #788 eliminated
# Feature #890 eliminated
# Feature #609 eliminated
# Feature #510 eliminated
# Feature #818 eliminated
# Feature #503 eliminated
# Feature #36 eliminated
# Feature #565 eliminated
# Feature #548 eliminated
# Feature #628 eliminated
# Feature #520 eliminated
# Feature #475 eliminated
# Feature #157 eliminated
# Feature #716 eliminated
# Feature #369 eliminated
# Feature #756 eliminated
# Feature #696 eliminated
# Feature #355 eliminated
# Feature #39 eliminated
# Feature #236 eliminated
# Feature #518 eliminated
# Feature #444 eliminated
# Feature #482 eliminated
# Feature #213 eliminated
# Feature #225 eliminated
# Feature #906 eliminated
# Feature #722 eliminated
# Feature #553 eliminated
# Feature #19 eliminated
# Feature #680 eliminated
# Feature #572 eliminated
# Feature #724 eliminated
# Feature #815 eliminated
# Feature #38 eliminated
# Feature #390 eliminated
# Feature #908 eliminated
# Feature #133 eliminated
# Feature #744 eliminated
# Feature #505 eliminated
# Feature #496 eliminated
# Feature #411 eliminated
# Feature #679 eliminated
# Feature #884 eliminated
# Feature #604 eliminated
# Feature #780 eliminated
# Feature #487 eliminated
# Feature #173 eliminated
# Feature #583 eliminated
# Feature #808 eliminated
# Feature #764 eliminated
# Feature #90 eliminated
# Feature #746 eliminated
# Feature #849 eliminated
# Feature #166 eliminated
# Feature #389 eliminated
# Feature #194 eliminated
# Feature #694 eliminated
# Feature #877 eliminated
# Feature #467 eliminated
# Feature #458 eliminated
# Feature #558 eliminated
# Feature #485 eliminated
# Feature #415 eliminated
# Feature #624 eliminated
# Feature #245 eliminated
# Feature #580 eliminated
# Feature #147 eliminated
# Feature #549 eliminated
# Feature #695 eliminated
# Step #2 out of 10
# 0:	test: 0.7060419	best: 0.7060419 (0)	total: 85ms	remaining: 1m 24s
# 300:	test: 0.7699410	best: 0.7778738 (135)	total: 23s	remaining: 53.4s
# 600:	test: 0.7636032	best: 0.7778738 (135)	total: 46.3s	remaining: 30.7s
# 900:	test: 0.7637208	best: 0.7778738 (135)	total: 1m 9s	remaining: 7.68s
# 999:	test: 0.7637175	best: 0.7778738 (135)	total: 1m 17s	remaining: 0us
# bestTest = 0.7778737545
# bestIteration = 135
# Shrink model to first 136 iterations.
# Feature #882 eliminated
# Feature #131 eliminated
# Feature #303 eliminated
# Feature #796 eliminated
# Feature #473 eliminated
# Feature #158 eliminated
# Feature #432 eliminated
# Feature #77 eliminated
# Feature #28 eliminated
# Feature #134 eliminated
# Feature #24 eliminated
# Feature #915 eliminated
# Feature #79 eliminated
# Feature #339 eliminated
# Feature #171 eliminated
# Feature #340 eliminated
# Feature #802 eliminated
# Feature #21 eliminated
# Feature #57 eliminated
# Feature #172 eliminated
# Feature #1 eliminated
# Feature #348 eliminated
# Feature #247 eliminated
# Feature #471 eliminated
# Feature #414 eliminated
# Feature #869 eliminated
# Feature #879 eliminated
# Feature #837 eliminated
# Feature #297 eliminated
# Feature #67 eliminated
# Feature #867 eliminated
# Feature #237 eliminated
# Feature #198 eliminated
# Feature #130 eliminated
# Feature #422 eliminated
# Feature #181 eliminated
# Feature #81 eliminated
# Feature #889 eliminated
# Feature #463 eliminated
# Feature #883 eliminated
# Feature #803 eliminated
# Feature #206 eliminated
# Feature #215 eliminated
# Feature #78 eliminated
# Feature #900 eliminated
# Feature #317 eliminated
# Feature #64 eliminated
# Feature #23 eliminated
# Feature #150 eliminated
# Feature #359 eliminated
# Feature #59 eliminated
# Feature #229 eliminated
# Feature #771 eliminated
# Feature #154 eliminated
# Feature #442 eliminated
# Feature #17 eliminated
# Feature #7 eliminated
# Feature #865 eliminated
# Feature #500 eliminated
# Feature #671 eliminated
# Feature #419 eliminated
# Feature #832 eliminated
# Feature #114 eliminated
# Feature #50 eliminated
# Feature #253 eliminated
# Feature #268 eliminated
# Feature #729 eliminated
# Feature #650 eliminated
# Feature #138 eliminated
# Feature #507 eliminated
# Feature #315 eliminated
# Feature #698 eliminated
# Feature #850 eliminated
# Feature #761 eliminated
# Feature #687 eliminated
# Feature #128 eliminated
# Feature #641 eliminated
# Feature #63 eliminated
# Feature #840 eliminated
# Feature #575 eliminated
# Feature #630 eliminated
# Feature #14 eliminated
# Feature #705 eliminated
# Feature #341 eliminated
# Feature #897 eliminated
# Feature #642 eliminated
# Feature #723 eliminated
# Feature #37 eliminated
# Feature #615 eliminated
# Feature #242 eliminated
# Feature #506 eliminated
# Feature #5 eliminated
# Feature #148 eliminated
# Feature #638 eliminated
# Feature #83 eliminated
# Feature #184 eliminated
# Feature #84 eliminated
# Feature #343 eliminated
# Feature #579 eliminated
# Feature #751 eliminated
# Feature #203 eliminated
# Feature #734 eliminated
# Feature #578 eliminated
# Feature #591 eliminated
# Feature #654 eliminated
# Feature #511 eliminated
# Feature #195 eliminated
# Feature #610 eliminated
# Feature #662 eliminated
# Feature #515 eliminated
# Feature #839 eliminated
# Feature #367 eliminated
# Feature #714 eliminated
# Feature #613 eliminated
# Feature #535 eliminated
# Feature #512 eliminated
# Feature #773 eliminated
# Feature #455 eliminated
# Feature #537 eliminated
# Feature #659 eliminated
# Feature #484 eliminated
# Feature #113 eliminated
# Feature #352 eliminated
# Feature #562 eliminated
# Feature #509 eliminated
# Feature #899 eliminated
# Feature #614 eliminated
# Feature #238 eliminated
# Feature #847 eliminated
# Feature #517 eliminated
# Feature #551 eliminated
# Feature #639 eliminated
# Feature #708 eliminated
# Feature #144 eliminated
# Feature #408 eliminated
# Step #3 out of 10
# 0:	test: 0.6973557	best: 0.6973557 (0)	total: 76.1ms	remaining: 1m 16s
# 300:	test: 0.7835405	best: 0.7890456 (155)	total: 21.5s	remaining: 49.9s
# 600:	test: 0.7778607	best: 0.7890456 (155)	total: 43.4s	remaining: 28.8s
# 900:	test: 0.7748600	best: 0.7890456 (155)	total: 1m 5s	remaining: 7.14s
# 999:	test: 0.7748306	best: 0.7890456 (155)	total: 1m 12s	remaining: 0us
# bestTest = 0.7890455723
# bestIteration = 155
# Shrink model to first 156 iterations.
# Feature #155 eliminated
# Feature #8 eliminated
# Feature #270 eliminated
# Feature #73 eliminated
# Feature #797 eliminated
# Feature #366 eliminated
# Feature #165 eliminated
# Feature #464 eliminated
# Feature #429 eliminated
# Feature #373 eliminated
# Feature #323 eliminated
# Feature #398 eliminated
# Feature #428 eliminated
# Feature #822 eliminated
# Feature #278 eliminated
# Feature #286 eliminated
# Feature #333 eliminated
# Feature #462 eliminated
# Feature #142 eliminated
# Feature #410 eliminated
# Feature #478 eliminated
# Feature #290 eliminated
# Feature #636 eliminated
# Feature #279 eliminated
# Feature #876 eliminated
# Feature #221 eliminated
# Feature #363 eliminated
# Feature #312 eliminated
# Feature #418 eliminated
# Feature #276 eliminated
# Feature #283 eliminated
# Feature #895 eliminated
# Feature #85 eliminated
# Feature #435 eliminated
# Feature #277 eliminated
# Feature #830 eliminated
# Feature #393 eliminated
# Feature #443 eliminated
# Feature #898 eliminated
# Feature #480 eliminated
# Feature #811 eliminated
# Feature #676 eliminated
# Feature #470 eliminated
# Feature #164 eliminated
# Feature #672 eliminated
# Feature #446 eliminated
# Feature #856 eliminated
# Feature #324 eliminated
# Feature #426 eliminated
# Feature #616 eliminated
# Feature #827 eliminated
# Feature #656 eliminated
# Feature #569 eliminated
# Feature #665 eliminated
# Feature #136 eliminated
# Feature #282 eliminated
# Feature #673 eliminated
# Feature #675 eliminated
# Feature #314 eliminated
# Feature #246 eliminated
# Feature #11 eliminated
# Feature #68 eliminated
# Feature #816 eliminated
# Feature #357 eliminated
# Feature #704 eliminated
# Feature #145 eliminated
# Feature #351 eliminated
# Feature #309 eliminated
# Feature #758 eliminated
# Feature #785 eliminated
# Feature #504 eliminated
# Feature #557 eliminated
# Feature #102 eliminated
# Feature #649 eliminated
# Feature #573 eliminated
# Feature #527 eliminated
# Feature #721 eliminated
# Feature #93 eliminated
# Feature #547 eliminated
# Feature #256 eliminated
# Feature #230 eliminated
# Feature #703 eliminated
# Feature #534 eliminated
# Feature #833 eliminated
# Feature #519 eliminated
# Feature #174 eliminated
# Feature #214 eliminated
# Feature #717 eliminated
# Feature #207 eliminated
# Feature #709 eliminated
# Feature #851 eliminated
# Feature #508 eliminated
# Feature #490 eliminated
# Feature #790 eliminated
# Feature #571 eliminated
# Feature #706 eliminated
# Feature #376 eliminated
# Feature #466 eliminated
# Feature #707 eliminated
# Feature #602 eliminated
# Feature #750 eliminated
# Feature #795 eliminated
# Feature #919 eliminated
# Feature #584 eliminated
# Feature #13 eliminated
# Feature #499 eliminated
# Feature #760 eliminated
# Feature #448 eliminated
# Feature #346 eliminated
# Feature #175 eliminated
# Feature #269 eliminated
# Step #4 out of 10
# 0:	test: 0.7035392	best: 0.7035392 (0)	total: 69.6ms	remaining: 1m 9s
# 300:	test: 0.7839127	best: 0.7871436 (100)	total: 20.3s	remaining: 47.2s
# 600:	test: 0.7775129	best: 0.7871436 (100)	total: 41s	remaining: 27.2s
# 900:	test: 0.7737988	best: 0.7871436 (100)	total: 1m 1s	remaining: 6.75s
# 999:	test: 0.7717466	best: 0.7871436 (100)	total: 1m 8s	remaining: 0us
# bestTest = 0.7871436477
# bestIteration = 100
# Shrink model to first 101 iterations.
# Feature #474 eliminated
# Feature #262 eliminated
# Feature #227 eliminated
# Feature #231 eliminated
# Feature #375 eliminated
# Feature #834 eliminated
# Feature #388 eliminated
# Feature #864 eliminated
# Feature #132 eliminated
# Feature #307 eliminated
# Feature #320 eliminated
# Feature #26 eliminated
# Feature #109 eliminated
# Feature #241 eliminated
# Feature #903 eliminated
# Feature #336 eliminated
# Feature #445 eliminated
# Feature #417 eliminated
# Feature #886 eliminated
# Feature #143 eliminated
# Feature #823 eliminated
# Feature #868 eliminated
# Feature #896 eliminated
# Feature #374 eliminated
# Feature #80 eliminated
# Feature #22 eliminated
# Feature #887 eliminated
# Feature #199 eliminated
# Feature #76 eliminated
# Feature #909 eliminated
# Feature #912 eliminated
# Feature #350 eliminated
# Feature #304 eliminated
# Feature #217 eliminated
# Feature #354 eliminated
# Feature #176 eliminated
# Feature #380 eliminated
# Feature #239 eliminated
# Feature #280 eliminated
# Feature #657 eliminated
# Feature #757 eliminated
# Feature #146 eliminated
# Feature #356 eliminated
# Feature #41 eliminated
# Feature #801 eliminated
# Feature #244 eliminated
# Feature #358 eliminated
# Feature #917 eliminated
# Feature #492 eliminated
# Feature #660 eliminated
# Feature #590 eliminated
# Feature #212 eliminated
# Feature #116 eliminated
# Feature #161 eliminated
# Feature #240 eliminated
# Feature #794 eliminated
# Feature #497 eliminated
# Feature #10 eliminated
# Feature #489 eliminated
# Feature #544 eliminated
# Feature #645 eliminated
# Feature #288 eliminated
# Feature #655 eliminated
# Feature #635 eliminated
# Feature #108 eliminated
# Feature #779 eliminated
# Feature #728 eliminated
# Feature #627 eliminated
# Feature #30 eliminated
# Feature #727 eliminated
# Feature #311 eliminated
# Feature #162 eliminated
# Feature #720 eliminated
# Feature #762 eliminated
# Feature #800 eliminated
# Feature #516 eliminated
# Feature #648 eliminated
# Feature #601 eliminated
# Feature #789 eliminated
# Feature #394 eliminated
# Feature #836 eliminated
# Feature #737 eliminated
# Feature #874 eliminated
# Feature #406 eliminated
# Feature #880 eliminated
# Feature #220 eliminated
# Feature #791 eliminated
# Feature #715 eliminated
# Feature #863 eliminated
# Feature #677 eliminated
# Feature #232 eliminated
# Step #5 out of 10
# 0:	test: 0.6297915	best: 0.6297915 (0)	total: 54ms	remaining: 54s
# 300:	test: 0.7835552	best: 0.7898113 (175)	total: 19.7s	remaining: 45.8s
# 600:	test: 0.7794917	best: 0.7898113 (175)	total: 39.6s	remaining: 26.3s
# 900:	test: 0.7779635	best: 0.7898113 (175)	total: 59.1s	remaining: 6.49s
# 999:	test: 0.7779913	best: 0.7898113 (175)	total: 1m 5s	remaining: 0us
# bestTest = 0.7898113132
# bestIteration = 175
# Shrink model to first 176 iterations.
# Feature #431 eliminated
# Feature #325 eliminated
# Feature #477 eliminated
# Feature #326 eliminated
# Feature #112 eliminated
# Feature #285 eliminated
# Feature #257 eliminated
# Feature #866 eliminated
# Feature #452 eliminated
# Feature #197 eliminated
# Feature #33 eliminated
# Feature #222 eliminated
# Feature #381 eliminated
# Feature #318 eliminated
# Feature #828 eliminated
# Feature #233 eliminated
# Feature #127 eliminated
# Feature #457 eliminated
# Feature #34 eliminated
# Feature #397 eliminated
# Feature #322 eliminated
# Feature #52 eliminated
# Feature #459 eliminated
# Feature #838 eliminated
# Feature #813 eliminated
# Feature #835 eliminated
# Feature #447 eliminated
# Feature #87 eliminated
# Feature #293 eliminated
# Feature #56 eliminated
# Feature #905 eliminated
# Feature #806 eliminated
# Feature #486 eliminated
# Feature #589 eliminated
# Feature #667 eliminated
# Feature #769 eliminated
# Feature #35 eliminated
# Feature #582 eliminated
# Feature #646 eliminated
# Feature #488 eliminated
# Feature #772 eliminated
# Feature #674 eliminated
# Feature #763 eliminated
# Feature #843 eliminated
# Feature #468 eliminated
# Feature #697 eliminated
# Feature #846 eliminated
# Feature #664 eliminated
# Feature #605 eliminated
# Feature #792 eliminated
# Feature #117 eliminated
# Feature #871 eliminated
# Feature #663 eliminated
# Feature #526 eliminated
# Feature #594 eliminated
# Feature #115 eliminated
# Feature #61 eliminated
# Feature #643 eliminated
# Feature #875 eliminated
# Feature #652 eliminated
# Feature #556 eliminated
# Feature #587 eliminated
# Feature #666 eliminated
# Feature #125 eliminated
# Feature #765 eliminated
# Feature #313 eliminated
# Feature #754 eliminated
# Feature #379 eliminated
# Feature #621 eliminated
# Feature #752 eliminated
# Feature #129 eliminated
# Feature #608 eliminated
# Feature #281 eliminated
# Feature #775 eliminated
# Feature #640 eliminated
# Step #6 out of 10
# 0:	test: 0.7190521	best: 0.7190521 (0)	total: 49.9ms	remaining: 49.8s
# 300:	test: 0.7881656	best: 0.7890407 (130)	total: 18.3s	remaining: 42.4s
# 600:	test: 0.7785137	best: 0.7890407 (130)	total: 37s	remaining: 24.6s
# 900:	test: 0.7787276	best: 0.7890407 (130)	total: 55.4s	remaining: 6.08s
# 999:	test: 0.7779113	best: 0.7890407 (130)	total: 1m 1s	remaining: 0us
# bestTest = 0.7890406847
# bestIteration = 130
# Shrink model to first 131 iterations.
# Feature #423 eliminated
# Feature #327 eliminated
# Feature #137 eliminated
# Feature #135 eliminated
# Feature #141 eliminated
# Feature #371 eliminated
# Feature #368 eliminated
# Feature #386 eliminated
# Feature #243 eliminated
# Feature #111 eliminated
# Feature #100 eliminated
# Feature #190 eliminated
# Feature #179 eliminated
# Feature #440 eliminated
# Feature #153 eliminated
# Feature #353 eliminated
# Feature #259 eliminated
# Feature #40 eliminated
# Feature #261 eliminated
# Feature #825 eliminated
# Feature #809 eliminated
# Feature #99 eliminated
# Feature #807 eliminated
# Feature #180 eliminated
# Feature #396 eliminated
# Feature #826 eliminated
# Feature #224 eliminated
# Feature #295 eliminated
# Feature #563 eliminated
# Feature #260 eliminated
# Feature #105 eliminated
# Feature #362 eliminated
# Feature #205 eliminated
# Feature #586 eliminated
# Feature #719 eliminated
# Feature #873 eliminated
# Feature #730 eliminated
# Feature #644 eliminated
# Feature #211 eliminated
# Feature #619 eliminated
# Feature #264 eliminated
# Feature #538 eliminated
# Feature #766 eliminated
# Feature #783 eliminated
# Feature #661 eliminated
# Feature #514 eliminated
# Feature #759 eliminated
# Feature #564 eliminated
# Feature #911 eliminated
# Feature #252 eliminated
# Feature #525 eliminated
# Feature #841 eliminated
# Feature #437 eliminated
# Feature #554 eliminated
# Feature #623 eliminated
# Feature #753 eliminated
# Feature #678 eliminated
# Feature #607 eliminated
# Feature #740 eliminated
# Feature #18 eliminated
# Feature #617 eliminated
# Step #7 out of 10
# 0:	test: 0.7190521	best: 0.7190521 (0)	total: 45.5ms	remaining: 45.5s
# 300:	test: 0.7876710	best: 0.7911794 (215)	total: 17.6s	remaining: 40.9s
# 600:	test: 0.7793741	best: 0.7911794 (215)	total: 35s	remaining: 23.3s
# 900:	test: 0.7793088	best: 0.7911794 (215)	total: 52.5s	remaining: 5.77s
# 999:	test: 0.7778835	best: 0.7911794 (215)	total: 58.2s	remaining: 0us
# bestTest = 0.7911794186
# bestIteration = 215
# Shrink model to first 216 iterations.
# Feature #395 eliminated
# Feature #360 eliminated
# Feature #55 eliminated
# Feature #218 eliminated
# Feature #91 eliminated
# Feature #48 eliminated
# Feature #330 eliminated
# Feature #472 eliminated
# Feature #413 eliminated
# Feature #94 eliminated
# Feature #302 eliminated
# Feature #308 eliminated
# Feature #65 eliminated
# Feature #170 eliminated
# Feature #305 eliminated
# Feature #829 eliminated
# Feature #513 eliminated
# Feature #653 eliminated
# Feature #858 eliminated
# Feature #810 eliminated
# Feature #685 eliminated
# Feature #738 eliminated
# Feature #533 eliminated
# Feature #124 eliminated
# Feature #891 eliminated
# Feature #637 eliminated
# Feature #611 eliminated
# Feature #82 eliminated
# Feature #600 eliminated
# Feature #479 eliminated
# Feature #524 eliminated
# Feature #767 eliminated
# Feature #560 eliminated
# Feature #598 eliminated
# Feature #618 eliminated
# Feature #377 eliminated
# Feature #781 eliminated
# Feature #403 eliminated
# Feature #793 eliminated
# Feature #183 eliminated
# Feature #139 eliminated
# Feature #819 eliminated
# Feature #743 eliminated
# Feature #577 eliminated
# Feature #532 eliminated
# Feature #682 eliminated
# Feature #204 eliminated
# Feature #626 eliminated
# Feature #272 eliminated
# Feature #588 eliminated
# Feature #817 eliminated
# Step #8 out of 10
# 0:	test: 0.7190521	best: 0.7190521 (0)	total: 44ms	remaining: 44s
# 300:	test: 0.7894864	best: 0.7916055 (125)	total: 17s	remaining: 39.4s
# 600:	test: 0.7917345	best: 0.7946650 (475)	total: 34.2s	remaining: 22.7s
# 900:	test: 0.7911386	best: 0.7946650 (475)	total: 51.1s	remaining: 5.61s
# 999:	test: 0.7897738	best: 0.7946650 (475)	total: 56.7s	remaining: 0us
# bestTest = 0.794664979
# bestIteration = 475
# Shrink model to first 476 iterations.
# Feature #202 eliminated
# Feature #831 eliminated
# Feature #291 eliminated
# Feature #620 eliminated
# Feature #699 eliminated
# Feature #799 eliminated
# Feature #748 eliminated
# Feature #528 eliminated
# Feature #904 eliminated
# Feature #400 eliminated
# Feature #208 eliminated
# Feature #53 eliminated
# Feature #786 eliminated
# Feature #546 eliminated
# Feature #787 eliminated
# Feature #120 eliminated
# Feature #364 eliminated
# Feature #881 eliminated
# Feature #483 eliminated
# Feature #103 eliminated
# Feature #271 eliminated
# Feature #210 eliminated
# Feature #552 eliminated
# Feature #777 eliminated
# Feature #686 eliminated
# Feature #606 eliminated
# Feature #186 eliminated
# Feature #365 eliminated
# Feature #595 eliminated
# Feature #566 eliminated
# Feature #188 eliminated
# Feature #700 eliminated
# Feature #121 eliminated
# Feature #530 eliminated
# Feature #289 eliminated
# Feature #453 eliminated
# Feature #593 eliminated
# Feature #72 eliminated
# Feature #550 eliminated
# Feature #726 eliminated
# Feature #265 eliminated
# Step #9 out of 10
# 0:	test: 0.7190521	best: 0.7190521 (0)	total: 43.5ms	remaining: 43.5s
# 300:	test: 0.7914717	best: 0.7917737 (255)	total: 16.3s	remaining: 37.8s
# 600:	test: 0.7900137	best: 0.7917737 (255)	total: 32.7s	remaining: 21.7s
# 900:	test: 0.7900056	best: 0.7917737 (255)	total: 49.1s	remaining: 5.4s
# 999:	test: 0.7908300	best: 0.7917737 (255)	total: 54.5s	remaining: 0us
# bestTest = 0.7917736769
# bestIteration = 255
# Shrink model to first 256 iterations.
# Feature #263 eliminated
# Feature #106 eliminated
# Feature #384 eliminated
# Feature #481 eliminated
# Feature #71 eliminated
# Feature #296 eliminated
# Feature #234 eliminated
# Feature #361 eliminated
# Feature #543 eliminated
# Feature #456 eliminated
# Feature #647 eliminated
# Feature #97 eliminated
# Feature #301 eliminated
# Feature #539 eliminated
# Feature #98 eliminated
# Feature #585 eliminated
# Feature #907 eliminated
# Feature #27 eliminated
# Feature #782 eliminated
# Feature #255 eliminated
# Feature #690 eliminated
# Feature #597 eliminated
# Feature #853 eliminated
# Feature #633 eliminated
# Feature #168 eliminated
# Feature #745 eliminated
# Feature #123 eliminated
# Feature #523 eliminated
# Feature #385 eliminated
# Feature #702 eliminated
# Feature #349 eliminated
# Feature #733 eliminated
# Feature #892 eliminated
# Feature #888 eliminated
# Step #10 out of 10
# 0:	test: 0.7190521	best: 0.7190521 (0)	total: 40.5ms	remaining: 40.5s
# 300:	test: 0.7978551	best: 0.7992877 (265)	total: 16s	remaining: 37.2s
# 600:	test: 0.7962951	best: 0.7998551 (405)	total: 32s	remaining: 21.3s
# 900:	test: 0.7923500	best: 0.7998551 (405)	total: 47.5s	remaining: 5.21s
# 999:	test: 0.7910080	best: 0.7998551 (405)	total: 52.7s	remaining: 0us
# bestTest = 0.7998550534
# bestIteration = 405
# Shrink model to first 406 iterations.
# Feature #848 eliminated
# Feature #824 eliminated
# Feature #522 eliminated
# Feature #46 eliminated
# Feature #249 eliminated
# Feature #219 eliminated
# Feature #844 eliminated
# Feature #383 eliminated
# Feature #450 eliminated
# Feature #776 eliminated
# Feature #741 eliminated
# Feature #74 eliminated
# Feature #89 eliminated
# Feature #407 eliminated
# Feature #599 eliminated
# Feature #382 eliminated
# Feature #43 eliminated
# Feature #596 eliminated
# Feature #372 eliminated
# Feature #104 eliminated
# Feature #567 eliminated
# Feature #434 eliminated
# Feature #193 eliminated
# Feature #192 eliminated
# Feature #862 eliminated
# Feature #169 eliminated
# Feature #684 eliminated
# Feature #521 eliminated
# Train final model
# 0:	test: 0.7190521	best: 0.7190521 (0)	total: 43.3ms	remaining: 43.3s
# 300:	test: 0.7959417	best: 0.7969915 (200)	total: 15.7s	remaining: 36.5s
# 600:	test: 0.7934700	best: 0.7969915 (200)	total: 31.4s	remaining: 20.9s
# 900:	test: 0.7925197	best: 0.7969915 (200)	total: 47s	remaining: 5.16s
# 999:	test: 0.7923940	best: 0.7969915 (200)	total: 52.2s	remaining: 0us
# bestTest = 0.7969914675
# bestIteration = 200
# Shrink model to first 201 iterations.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Step #1 out of 10
# 0:	test: 0.6603118	best: 0.6603118 (0)	total: 81.2ms	remaining: 1m 21s
# 300:	test: 0.7431909	best: 0.7456450 (285)	total: 24.7s	remaining: 57.3s
# 600:	test: 0.7474186	best: 0.7485344 (510)	total: 49.9s	remaining: 33.1s
# 900:	test: 0.7491856	best: 0.7495228 (815)	total: 1m 14s	remaining: 8.21s
# 999:	test: 0.7487842	best: 0.7495228 (815)	total: 1m 23s	remaining: 0us
# bestTest = 0.7495228052
# bestIteration = 815
# Shrink model to first 816 iterations.
# Feature #620 eliminated
# Feature #79 eliminated
# Feature #78 eliminated
# Feature #109 eliminated
# Feature #24 eliminated
# Feature #275 eliminated
# Feature #910 eliminated
# Feature #76 eliminated
# Feature #376 eliminated
# Feature #914 eliminated
# Feature #66 eliminated
# Feature #399 eliminated
# Feature #90 eliminated
# Feature #64 eliminated
# Feature #25 eliminated
# Feature #603 eliminated
# Feature #62 eliminated
# Feature #286 eliminated
# Feature #757 eliminated
# Feature #68 eliminated
# Feature #867 eliminated
# Feature #692 eliminated
# Feature #435 eliminated
# Feature #37 eliminated
# Feature #469 eliminated
# Feature #7 eliminated
# Feature #717 eliminated
# Feature #908 eliminated
# Feature #678 eliminated
# Feature #810 eliminated
# Feature #779 eliminated
# Feature #139 eliminated
# Feature #355 eliminated
# Feature #889 eliminated
# Feature #246 eliminated
# Feature #165 eliminated
# Feature #288 eliminated
# Feature #212 eliminated
# Feature #31 eliminated
# Feature #572 eliminated
# Feature #675 eliminated
# Feature #204 eliminated
# Feature #272 eliminated
# Feature #208 eliminated
# Feature #348 eliminated
# Feature #465 eliminated
# Feature #160 eliminated
# Feature #789 eliminated
# Feature #8 eliminated
# Feature #444 eliminated
# Feature #203 eliminated
# Feature #580 eliminated
# Feature #514 eliminated
# Feature #236 eliminated
# Feature #808 eliminated
# Feature #511 eliminated
# Feature #803 eliminated
# Feature #558 eliminated
# Feature #509 eliminated
# Feature #704 eliminated
# Feature #449 eliminated
# Feature #174 eliminated
# Feature #790 eliminated
# Feature #105 eliminated
# Feature #269 eliminated
# Feature #738 eliminated
# Feature #732 eliminated
# Feature #639 eliminated
# Feature #359 eliminated
# Feature #837 eliminated
# Feature #697 eliminated
# Feature #720 eliminated
# Feature #710 eliminated
# Feature #166 eliminated
# Feature #482 eliminated
# Feature #92 eliminated
# Feature #896 eliminated
# Feature #712 eliminated
# Feature #766 eliminated
# Feature #150 eliminated
# Feature #760 eliminated
# Feature #157 eliminated
# Feature #159 eliminated
# Feature #613 eliminated
# Feature #403 eliminated
# Feature #763 eliminated
# Feature #561 eliminated
# Feature #36 eliminated
# Feature #153 eliminated
# Feature #244 eliminated
# Feature #705 eliminated
# Feature #195 eliminated
# Feature #715 eliminated
# Feature #451 eliminated
# Feature #638 eliminated
# Feature #297 eliminated
# Feature #108 eliminated
# Feature #291 eliminated
# Feature #344 eliminated
# Feature #317 eliminated
# Feature #831 eliminated
# Feature #841 eliminated
# Feature #898 eliminated
# Feature #892 eliminated
# Feature #306 eliminated
# Feature #503 eliminated
# Feature #119 eliminated
# Feature #453 eliminated
# Feature #573 eliminated
# Feature #602 eliminated
# Feature #863 eliminated
# Feature #731 eliminated
# Feature #257 eliminated
# Feature #437 eliminated
# Feature #756 eliminated
# Feature #833 eliminated
# Feature #84 eliminated
# Feature #740 eliminated
# Feature #838 eliminated
# Feature #11 eliminated
# Feature #365 eliminated
# Feature #4 eliminated
# Feature #824 eliminated
# Feature #800 eliminated
# Feature #846 eliminated
# Feature #412 eliminated
# Feature #261 eliminated
# Feature #210 eliminated
# Feature #519 eliminated
# Feature #861 eliminated
# Feature #474 eliminated
# Feature #315 eliminated
# Feature #552 eliminated
# Feature #169 eliminated
# Feature #708 eliminated
# Feature #882 eliminated
# Feature #402 eliminated
# Feature #357 eliminated
# Feature #545 eliminated
# Feature #888 eliminated
# Feature #719 eliminated
# Feature #549 eliminated
# Feature #611 eliminated
# Feature #730 eliminated
# Feature #761 eliminated
# Feature #459 eliminated
# Feature #864 eliminated
# Feature #744 eliminated
# Feature #912 eliminated
# Feature #597 eliminated
# Feature #30 eliminated
# Feature #527 eliminated
# Feature #224 eliminated
# Feature #700 eliminated
# Feature #245 eliminated
# Feature #548 eliminated
# Feature #457 eliminated
# Feature #746 eliminated
# Feature #707 eliminated
# Feature #897 eliminated
# Feature #148 eliminated
# Feature #252 eliminated
# Feature #709 eliminated
# Feature #468 eliminated
# Feature #164 eliminated
# Step #2 out of 10
# 0:	test: 0.7046596	best: 0.7046596 (0)	total: 89.4ms	remaining: 1m 29s
# 300:	test: 0.7490583	best: 0.7490583 (300)	total: 22.7s	remaining: 52.7s
# 600:	test: 0.7546831	best: 0.7549559 (590)	total: 46.1s	remaining: 30.6s
# 900:	test: 0.7564889	best: 0.7573548 (860)	total: 1m 9s	remaining: 7.62s
# 999:	test: 0.7572093	best: 0.7577405 (930)	total: 1m 16s	remaining: 0us
# bestTest = 0.7577404976
# bestIteration = 930
# Shrink model to first 931 iterations.
# Feature #397 eliminated
# Feature #335 eliminated
# Feature #843 eliminated
# Feature #440 eliminated
# Feature #88 eliminated
# Feature #894 eliminated
# Feature #373 eliminated
# Feature #300 eliminated
# Feature #241 eliminated
# Feature #154 eliminated
# Feature #147 eliminated
# Feature #806 eliminated
# Feature #310 eliminated
# Feature #285 eliminated
# Feature #72 eliminated
# Feature #919 eliminated
# Feature #289 eliminated
# Feature #420 eliminated
# Feature #314 eliminated
# Feature #423 eliminated
# Feature #172 eliminated
# Feature #75 eliminated
# Feature #226 eliminated
# Feature #162 eliminated
# Feature #764 eliminated
# Feature #506 eliminated
# Feature #682 eliminated
# Feature #16 eliminated
# Feature #750 eliminated
# Feature #466 eliminated
# Feature #298 eliminated
# Feature #586 eliminated
# Feature #713 eliminated
# Feature #305 eliminated
# Feature #654 eliminated
# Feature #881 eliminated
# Feature #791 eliminated
# Feature #578 eliminated
# Feature #346 eliminated
# Feature #772 eliminated
# Feature #856 eliminated
# Feature #242 eliminated
# Feature #462 eliminated
# Feature #865 eliminated
# Feature #238 eliminated
# Feature #189 eliminated
# Feature #566 eliminated
# Feature #916 eliminated
# Feature #312 eliminated
# Feature #680 eliminated
# Feature #205 eliminated
# Feature #67 eliminated
# Feature #886 eliminated
# Feature #427 eliminated
# Feature #267 eliminated
# Feature #311 eliminated
# Feature #362 eliminated
# Feature #249 eliminated
# Feature #32 eliminated
# Feature #842 eliminated
# Feature #832 eliminated
# Feature #890 eliminated
# Feature #13 eliminated
# Feature #690 eliminated
# Feature #227 eliminated
# Feature #617 eliminated
# Feature #220 eliminated
# Feature #915 eliminated
# Feature #583 eliminated
# Feature #19 eliminated
# Feature #706 eliminated
# Feature #534 eliminated
# Feature #515 eliminated
# Feature #873 eliminated
# Feature #883 eliminated
# Feature #201 eliminated
# Feature #849 eliminated
# Feature #73 eliminated
# Feature #904 eliminated
# Feature #513 eliminated
# Feature #737 eliminated
# Feature #703 eliminated
# Feature #438 eliminated
# Feature #343 eliminated
# Feature #531 eliminated
# Feature #565 eliminated
# Feature #681 eliminated
# Feature #537 eliminated
# Feature #361 eliminated
# Feature #765 eliminated
# Feature #676 eliminated
# Feature #571 eliminated
# Feature #826 eliminated
# Feature #146 eliminated
# Feature #734 eliminated
# Feature #631 eliminated
# Feature #499 eliminated
# Feature #141 eliminated
# Feature #546 eliminated
# Feature #716 eliminated
# Feature #260 eliminated
# Feature #759 eliminated
# Feature #847 eliminated
# Feature #609 eliminated
# Feature #604 eliminated
# Feature #404 eliminated
# Feature #858 eliminated
# Feature #379 eliminated
# Feature #230 eliminated
# Feature #683 eliminated
# Feature #43 eliminated
# Feature #787 eliminated
# Feature #132 eliminated
# Feature #377 eliminated
# Feature #679 eliminated
# Feature #475 eliminated
# Feature #42 eliminated
# Feature #445 eliminated
# Feature #783 eliminated
# Feature #584 eliminated
# Feature #370 eliminated
# Feature #439 eliminated
# Feature #689 eliminated
# Feature #590 eliminated
# Feature #594 eliminated
# Feature #758 eliminated
# Feature #486 eliminated
# Feature #446 eliminated
# Feature #358 eliminated
# Feature #507 eliminated
# Feature #671 eliminated
# Feature #309 eliminated
# Feature #240 eliminated
# Feature #811 eliminated
# Feature #606 eliminated
# Step #3 out of 10
# 0:	test: 0.7046596	best: 0.7046596 (0)	total: 74.3ms	remaining: 1m 14s
# 300:	test: 0.7521484	best: 0.7539858 (265)	total: 21.4s	remaining: 49.7s
# 600:	test: 0.7581613	best: 0.7581613 (600)	total: 43.1s	remaining: 28.6s
# 900:	test: 0.7642834	best: 0.7642834 (900)	total: 1m 4s	remaining: 7.11s
# 999:	test: 0.7651844	best: 0.7654731 (995)	total: 1m 11s	remaining: 0us
# bestTest = 0.7654730678
# bestIteration = 995
# Shrink model to first 996 iterations.
# Feature #284 eliminated
# Feature #797 eliminated
# Feature #39 eliminated
# Feature #796 eliminated
# Feature #325 eliminated
# Feature #769 eliminated
# Feature #283 eliminated
# Feature #307 eliminated
# Feature #425 eliminated
# Feature #287 eliminated
# Feature #223 eliminated
# Feature #615 eliminated
# Feature #859 eliminated
# Feature #239 eliminated
# Feature #136 eliminated
# Feature #793 eliminated
# Feature #410 eliminated
# Feature #279 eliminated
# Feature #711 eliminated
# Feature #198 eliminated
# Feature #815 eliminated
# Feature #278 eliminated
# Feature #48 eliminated
# Feature #825 eliminated
# Feature #575 eliminated
# Feature #869 eliminated
# Feature #821 eliminated
# Feature #481 eliminated
# Feature #773 eliminated
# Feature #388 eliminated
# Feature #862 eliminated
# Feature #218 eliminated
# Feature #131 eliminated
# Feature #112 eliminated
# Feature #798 eliminated
# Feature #221 eliminated
# Feature #743 eliminated
# Feature #450 eliminated
# Feature #579 eliminated
# Feature #319 eliminated
# Feature #813 eliminated
# Feature #180 eliminated
# Feature #553 eliminated
# Feature #489 eliminated
# Feature #360 eliminated
# Feature #599 eliminated
# Feature #807 eliminated
# Feature #447 eliminated
# Feature #170 eliminated
# Feature #836 eliminated
# Feature #816 eliminated
# Feature #871 eliminated
# Feature #726 eliminated
# Feature #554 eliminated
# Feature #128 eliminated
# Feature #354 eliminated
# Feature #271 eliminated
# Feature #477 eliminated
# Feature #318 eliminated
# Feature #163 eliminated
# Feature #903 eliminated
# Feature #418 eliminated
# Feature #830 eliminated
# Feature #214 eliminated
# Feature #788 eliminated
# Feature #820 eliminated
# Feature #848 eliminated
# Feature #834 eliminated
# Feature #352 eliminated
# Feature #634 eliminated
# Feature #5 eliminated
# Feature #353 eliminated
# Feature #812 eliminated
# Feature #607 eliminated
# Feature #685 eliminated
# Feature #686 eliminated
# Feature #389 eliminated
# Feature #616 eliminated
# Feature #61 eliminated
# Feature #591 eliminated
# Feature #98 eliminated
# Feature #663 eliminated
# Feature #589 eliminated
# Feature #569 eliminated
# Feature #117 eliminated
# Feature #582 eliminated
# Feature #520 eliminated
# Feature #729 eliminated
# Feature #661 eliminated
# Feature #394 eliminated
# Feature #341 eliminated
# Feature #395 eliminated
# Feature #851 eliminated
# Feature #81 eliminated
# Feature #608 eliminated
# Feature #116 eliminated
# Feature #643 eliminated
# Feature #87 eliminated
# Feature #234 eliminated
# Feature #190 eliminated
# Feature #525 eliminated
# Feature #345 eliminated
# Feature #149 eliminated
# Feature #748 eliminated
# Feature #605 eliminated
# Feature #488 eliminated
# Feature #739 eliminated
# Feature #652 eliminated
# Feature #356 eliminated
# Feature #99 eliminated
# Feature #722 eliminated
# Step #4 out of 10
# 0:	test: 0.6813242	best: 0.6813242 (0)	total: 69.7ms	remaining: 1m 9s
# 300:	test: 0.7567133	best: 0.7567533 (280)	total: 20.1s	remaining: 46.7s
# 600:	test: 0.7625988	best: 0.7627844 (590)	total: 40.4s	remaining: 26.8s
# 900:	test: 0.7674729	best: 0.7674729 (900)	total: 1m	remaining: 6.67s
# 999:	test: 0.7694958	best: 0.7694958 (999)	total: 1m 7s	remaining: 0us
# bestTest = 0.7694957852
# bestIteration = 999
# Feature #336 eliminated
# Feature #276 eliminated
# Feature #422 eliminated
# Feature #29 eliminated
# Feature #327 eliminated
# Feature #77 eliminated
# Feature #334 eliminated
# Feature #340 eliminated
# Feature #371 eliminated
# Feature #59 eliminated
# Feature #347 eliminated
# Feature #326 eliminated
# Feature #378 eliminated
# Feature #74 eliminated
# Feature #49 eliminated
# Feature #258 eliminated
# Feature #510 eliminated
# Feature #718 eliminated
# Feature #130 eliminated
# Feature #53 eliminated
# Feature #232 eliminated
# Feature #518 eliminated
# Feature #129 eliminated
# Feature #259 eliminated
# Feature #637 eliminated
# Feature #822 eliminated
# Feature #23 eliminated
# Feature #887 eliminated
# Feature #895 eliminated
# Feature #454 eliminated
# Feature #188 eliminated
# Feature #677 eliminated
# Feature #829 eliminated
# Feature #588 eliminated
# Feature #421 eliminated
# Feature #835 eliminated
# Feature #299 eliminated
# Feature #414 eliminated
# Feature #577 eliminated
# Feature #70 eliminated
# Feature #752 eliminated
# Feature #562 eliminated
# Feature #416 eliminated
# Feature #529 eliminated
# Feature #96 eliminated
# Feature #138 eliminated
# Feature #199 eliminated
# Feature #133 eliminated
# Feature #496 eliminated
# Feature #237 eliminated
# Feature #364 eliminated
# Feature #767 eliminated
# Feature #387 eliminated
# Feature #667 eliminated
# Feature #498 eliminated
# Feature #2 eliminated
# Feature #266 eliminated
# Feature #192 eliminated
# Feature #666 eliminated
# Feature #483 eliminated
# Feature #840 eliminated
# Feature #383 eliminated
# Feature #101 eliminated
# Feature #455 eliminated
# Feature #799 eliminated
# Feature #35 eliminated
# Feature #492 eliminated
# Feature #727 eliminated
# Feature #567 eliminated
# Feature #695 eliminated
# Feature #21 eliminated
# Feature #612 eliminated
# Feature #476 eliminated
# Feature #264 eliminated
# Feature #526 eliminated
# Feature #123 eliminated
# Feature #872 eliminated
# Feature #385 eliminated
# Feature #814 eliminated
# Feature #80 eliminated
# Feature #785 eliminated
# Feature #655 eliminated
# Feature #728 eliminated
# Feature #598 eliminated
# Feature #657 eliminated
# Feature #698 eliminated
# Feature #508 eliminated
# Feature #530 eliminated
# Feature #338 eliminated
# Feature #473 eliminated
# Feature #544 eliminated
# Step #5 out of 10
# 0:	test: 0.6815412	best: 0.6815412 (0)	total: 70.2ms	remaining: 1m 10s
# 300:	test: 0.7576034	best: 0.7576034 (300)	total: 19.1s	remaining: 44.4s
# 600:	test: 0.7694546	best: 0.7694546 (600)	total: 38.5s	remaining: 25.6s
# 900:	test: 0.7766378	best: 0.7766426 (895)	total: 57.9s	remaining: 6.36s
# 999:	test: 0.7791773	best: 0.7792646 (985)	total: 1m 4s	remaining: 0us
# bestTest = 0.7792646289
# bestIteration = 985
# Shrink model to first 986 iterations.
# Feature #392 eliminated
# Feature #228 eliminated
# Feature #853 eliminated
# Feature #432 eliminated
# Feature #463 eliminated
# Feature #909 eliminated
# Feature #441 eliminated
# Feature #374 eliminated
# Feature #390 eliminated
# Feature #433 eliminated
# Feature #905 eliminated
# Feature #331 eliminated
# Feature #380 eliminated
# Feature #850 eliminated
# Feature #71 eliminated
# Feature #852 eliminated
# Feature #817 eliminated
# Feature #405 eliminated
# Feature #142 eliminated
# Feature #398 eliminated
# Feature #754 eliminated
# Feature #155 eliminated
# Feature #366 eliminated
# Feature #535 eliminated
# Feature #555 eliminated
# Feature #197 eliminated
# Feature #723 eliminated
# Feature #337 eliminated
# Feature #619 eliminated
# Feature #295 eliminated
# Feature #20 eliminated
# Feature #576 eliminated
# Feature #44 eliminated
# Feature #460 eliminated
# Feature #375 eliminated
# Feature #187 eliminated
# Feature #313 eliminated
# Feature #755 eliminated
# Feature #551 eliminated
# Feature #522 eliminated
# Feature #684 eliminated
# Feature #907 eliminated
# Feature #877 eliminated
# Feature #786 eliminated
# Feature #250 eliminated
# Feature #794 eliminated
# Feature #270 eliminated
# Feature #93 eliminated
# Feature #702 eliminated
# Feature #724 eliminated
# Feature #330 eliminated
# Feature #113 eliminated
# Feature #89 eliminated
# Feature #600 eliminated
# Feature #281 eliminated
# Feature #524 eliminated
# Feature #478 eliminated
# Feature #10 eliminated
# Feature #458 eliminated
# Feature #217 eliminated
# Feature #595 eliminated
# Feature #456 eliminated
# Feature #646 eliminated
# Feature #52 eliminated
# Feature #82 eliminated
# Feature #472 eliminated
# Feature #91 eliminated
# Feature #97 eliminated
# Feature #100 eliminated
# Feature #103 eliminated
# Feature #106 eliminated
# Feature #290 eliminated
# Feature #747 eliminated
# Feature #384 eliminated
# Feature #386 eliminated
# Step #6 out of 10
# 0:	test: 0.6815412	best: 0.6815412 (0)	total: 62.2ms	remaining: 1m 2s
# 300:	test: 0.7590296	best: 0.7596506 (290)	total: 17.9s	remaining: 41.5s
# 600:	test: 0.7698269	best: 0.7698269 (600)	total: 36.3s	remaining: 24.1s
# 900:	test: 0.7746343	best: 0.7750551 (855)	total: 54.7s	remaining: 6.01s
# 999:	test: 0.7777705	best: 0.7777705 (999)	total: 1m	remaining: 0us
# bestTest = 0.7777705193
# bestIteration = 999
# Feature #273 eliminated
# Feature #27 eliminated
# Feature #143 eliminated
# Feature #22 eliminated
# Feature #547 eliminated
# Feature #17 eliminated
# Feature #818 eliminated
# Feature #145 eliminated
# Feature #323 eliminated
# Feature #906 eliminated
# Feature #442 eliminated
# Feature #823 eliminated
# Feature #669 eliminated
# Feature #464 eliminated
# Feature #219 eliminated
# Feature #911 eliminated
# Feature #809 eliminated
# Feature #120 eliminated
# Feature #175 eliminated
# Feature #819 eliminated
# Feature #168 eliminated
# Feature #781 eliminated
# Feature #630 eliminated
# Feature #407 eliminated
# Feature #480 eliminated
# Feature #178 eliminated
# Feature #618 eliminated
# Feature #304 eliminated
# Feature #14 eliminated
# Feature #587 eliminated
# Feature #596 eliminated
# Feature #656 eliminated
# Feature #844 eliminated
# Feature #186 eliminated
# Feature #736 eliminated
# Feature #158 eliminated
# Feature #839 eliminated
# Feature #642 eliminated
# Feature #382 eliminated
# Feature #251 eliminated
# Feature #253 eliminated
# Feature #63 eliminated
# Feature #670 eliminated
# Feature #521 eliminated
# Feature #429 eliminated
# Feature #884 eliminated
# Feature #543 eliminated
# Feature #121 eliminated
# Feature #516 eliminated
# Feature #102 eliminated
# Feature #94 eliminated
# Feature #183 eliminated
# Feature #256 eliminated
# Feature #694 eliminated
# Feature #12 eliminated
# Feature #333 eliminated
# Feature #771 eliminated
# Feature #701 eliminated
# Feature #733 eliminated
# Feature #601 eliminated
# Feature #55 eliminated
# Step #7 out of 10
# 0:	test: 0.6815412	best: 0.6815412 (0)	total: 68.8ms	remaining: 1m 8s
# 300:	test: 0.7578860	best: 0.7578860 (300)	total: 17.2s	remaining: 40.1s
# 600:	test: 0.7678089	best: 0.7678089 (600)	total: 34.9s	remaining: 23.2s
# 900:	test: 0.7783344	best: 0.7783344 (900)	total: 52.5s	remaining: 5.77s
# 999:	test: 0.7801597	best: 0.7801597 (999)	total: 58.5s	remaining: 0us
# bestTest = 0.7801596522
# bestIteration = 999
# Feature #901 eliminated
# Feature #83 eliminated
# Feature #115 eliminated
# Feature #277 eliminated
# Feature #827 eliminated
# Feature #854 eliminated
# Feature #231 eliminated
# Feature #415 eliminated
# Feature #110 eliminated
# Feature #292 eliminated
# Feature #868 eliminated
# Feature #777 eliminated
# Feature #674 eliminated
# Feature #502 eliminated
# Feature #268 eliminated
# Feature #585 eliminated
# Feature #436 eliminated
# Feature #369 eliminated
# Feature #200 eliminated
# Feature #660 eliminated
# Feature #753 eliminated
# Feature #45 eliminated
# Feature #778 eliminated
# Feature #542 eliminated
# Feature #18 eliminated
# Feature #211 eliminated
# Feature #262 eliminated
# Feature #860 eliminated
# Feature #302 eliminated
# Feature #876 eliminated
# Feature #320 eliminated
# Feature #659 eliminated
# Feature #650 eliminated
# Feature #368 eliminated
# Feature #126 eliminated
# Feature #801 eliminated
# Feature #528 eliminated
# Feature #653 eliminated
# Feature #428 eliminated
# Feature #593 eliminated
# Feature #301 eliminated
# Feature #452 eliminated
# Feature #15 eliminated
# Feature #85 eliminated
# Feature #648 eliminated
# Feature #649 eliminated
# Feature #699 eliminated
# Feature #28 eliminated
# Feature #207 eliminated
# Feature #118 eliminated
# Feature #644 eliminated
# Step #8 out of 10
# 0:	test: 0.6728202	best: 0.6728202 (0)	total: 76.4ms	remaining: 1m 16s
# 300:	test: 0.7583105	best: 0.7584184 (295)	total: 20.9s	remaining: 48.4s
# 600:	test: 0.7684577	best: 0.7684577 (600)	total: 42s	remaining: 27.9s
# 900:	test: 0.7760265	best: 0.7760314 (890)	total: 1m 3s	remaining: 7s
# 999:	test: 0.7782775	best: 0.7783126 (995)	total: 1m 9s	remaining: 0us
# bestTest = 0.7783126235
# bestIteration = 995
# Shrink model to first 996 iterations.
# Feature #431 eliminated
# Feature #161 eliminated
# Feature #902 eliminated
# Feature #181 eliminated
# Feature #229 eliminated
# Feature #308 eliminated
# Feature #621 eliminated
# Feature #34 eliminated
# Feature #885 eliminated
# Feature #177 eliminated
# Feature #171 eliminated
# Feature #182 eliminated
# Feature #645 eliminated
# Feature #351 eliminated
# Feature #536 eliminated
# Feature #247 eliminated
# Feature #443 eliminated
# Feature #664 eliminated
# Feature #532 eliminated
# Feature #893 eliminated
# Feature #780 eliminated
# Feature #687 eliminated
# Feature #721 eliminated
# Feature #367 eliminated
# Feature #540 eliminated
# Feature #623 eliminated
# Feature #641 eliminated
# Feature #316 eliminated
# Feature #880 eliminated
# Feature #523 eliminated
# Feature #255 eliminated
# Feature #372 eliminated
# Feature #874 eliminated
# Feature #350 eliminated
# Feature #137 eliminated
# Feature #95 eliminated
# Feature #58 eliminated
# Feature #857 eliminated
# Feature #222 eliminated
# Feature #127 eliminated
# Feature #665 eliminated
# Step #9 out of 10
# 0:	test: 0.6675417	best: 0.6675417 (0)	total: 60.3ms	remaining: 1m
# 300:	test: 0.7594735	best: 0.7594735 (300)	total: 16.4s	remaining: 38.2s
# 600:	test: 0.7704611	best: 0.7704611 (600)	total: 33.6s	remaining: 22.3s
# 900:	test: 0.7809746	best: 0.7809746 (900)	total: 50.5s	remaining: 5.55s
# 999:	test: 0.7832643	best: 0.7832643 (999)	total: 56.1s	remaining: 0us
# bestTest = 0.783264339
# bestIteration = 999
# Feature #332 eliminated
# Feature #152 eliminated
# Feature #409 eliminated
# Feature #303 eliminated
# Feature #673 eliminated
# Feature #845 eliminated
# Feature #774 eliminated
# Feature #879 eliminated
# Feature #891 eliminated
# Feature #899 eliminated
# Feature #185 eliminated
# Feature #151 eliminated
# Feature #782 eliminated
# Feature #533 eliminated
# Feature #363 eliminated
# Feature #497 eliminated
# Feature #179 eliminated
# Feature #560 eliminated
# Feature #349 eliminated
# Feature #56 eliminated
# Feature #557 eliminated
# Feature #57 eliminated
# Feature #795 eliminated
# Feature #263 eliminated
# Feature #626 eliminated
# Feature #114 eliminated
# Feature #9 eliminated
# Feature #381 eliminated
# Feature #776 eliminated
# Feature #775 eliminated
# Feature #805 eliminated
# Feature #40 eliminated
# Feature #802 eliminated
# Feature #65 eliminated
# Step #10 out of 10
# 0:	test: 0.6822398	best: 0.6822398 (0)	total: 53.4ms	remaining: 53.3s
# 300:	test: 0.7661656	best: 0.7661656 (300)	total: 15.6s	remaining: 36.3s
# 600:	test: 0.7758628	best: 0.7760811 (595)	total: 32.2s	remaining: 21.4s
# 900:	test: 0.7837155	best: 0.7837155 (900)	total: 48.2s	remaining: 5.29s
# 999:	test: 0.7859130	best: 0.7862028 (980)	total: 53.6s	remaining: 0us
# bestTest = 0.786202848
# bestIteration = 980
# Shrink model to first 981 iterations.
# Feature #413 eliminated
# Feature #243 eliminated
# Feature #328 eliminated
# Feature #324 eliminated
# Feature #479 eliminated
# Feature #417 eliminated
# Feature #714 eliminated
# Feature #900 eliminated
# Feature #209 eliminated
# Feature #191 eliminated
# Feature #122 eliminated
# Feature #628 eliminated
# Feature #254 eliminated
# Feature #633 eliminated
# Feature #60 eliminated
# Feature #461 eliminated
# Feature #156 eliminated
# Feature #470 eliminated
# Feature #550 eliminated
# Feature #672 eliminated
# Feature #135 eliminated
# Feature #784 eliminated
# Feature #741 eliminated
# Feature #46 eliminated
# Feature #322 eliminated
# Feature #86 eliminated
# Feature #487 eliminated
# Feature #635 eliminated
# Train final model
# 0:	test: 0.6822398	best: 0.6822398 (0)	total: 54.2ms	remaining: 54.1s
# 300:	test: 0.7665973	best: 0.7666677 (285)	total: 15.3s	remaining: 35.6s
# 600:	test: 0.7814040	best: 0.7814040 (600)	total: 31.8s	remaining: 21.1s
# 900:	test: 0.7898412	best: 0.7898412 (900)	total: 51.6s	remaining: 5.67s
# 999:	test: 0.7926245	best: 0.7926245 (999)	total: 58.1s	remaining: 0us
# bestTest = 0.7926244736
# bestIteration = 999
# Default metric period is 5 because AUC is/are not implemented for GPU
# Step #1 out of 10
# ...
# Step #10 out of 10
# 0:	test: 0.7181816	best: 0.7181816 (0)	total: 77.2ms	remaining: 1m 17s
# 300:	test: 0.7913375	best: 0.7913375 (300)	total: 19.8s	remaining: 46.1s
# 600:	test: 0.7995467	best: 0.7995467 (600)	total: 40.3s	remaining: 26.7s
# 900:	test: 0.8054938	best: 0.8055281 (895)	total: 1m	remaining: 6.63s
# 999:	test: 0.8070553	best: 0.8071339 (990)	total: 1m 7s	remaining: 0us
# bestTest = 0.807133913
# bestIteration = 990
# Shrink model to first 991 iterations.
# Feature #312 eliminated
# Feature #206 eliminated
# Feature #242 eliminated
# Feature #235 eliminated
# Feature #135 eliminated
# Feature #872 eliminated
# Feature #237 eliminated
# Feature #863 eliminated
# Feature #446 eliminated
# Feature #765 eliminated
# Feature #506 eliminated
# Feature #564 eliminated
# Feature #681 eliminated
# Feature #460 eliminated
# Feature #301 eliminated
# Feature #238 eliminated
# Feature #422 eliminated
# Feature #662 eliminated
# Feature #126 eliminated
# Feature #466 eliminated
# Feature #682 eliminated
# Feature #541 eliminated
# Feature #601 eliminated
# Feature #840 eliminated
# Feature #329 eliminated
# Feature #585 eliminated
# Feature #645 eliminated
# Feature #763 eliminated
# Train final model
# 0:	test: 0.7597189	best: 0.7597189 (0)	total: 52.2ms	remaining: 52.2s
# 300:	test: 0.7882259	best: 0.7882259 (300)	total: 19s	remaining: 44s
# 600:	test: 0.7976592	best: 0.7976592 (600)	total: 38.7s	remaining: 25.7s
# 900:	test: 0.8029614	best: 0.8029943 (895)	total: 58.6s	remaining: 6.44s
# 999:	test: 0.8059528	best: 0.8059528 (999)	total: 1m 5s	remaining: 0us
# bestTest = 0.8059527874
# bestIteration = 999
# Default metric period is 5 because AUC is/are not implemented for GPU
# Step #1 out of 10
# 0:	test: 0.7205787	best: 0.7205787 (0)	total: 80.5ms	remaining: 1m 20s
# 300:	test: 0.7837433	best: 0.7837433 (300)	total: 24.7s	remaining: 57.3s
# 600:	test: 0.7842496	best: 0.7858923 (435)	total: 49.7s	remaining: 33s
# 900:	test: 0.7850044	best: 0.7858923 (435)	total: 1m 14s	remaining: 8.19s
# 999:	test: 0.7857579	best: 0.7861707 (965)	total: 1m 22s	remaining: 0us
# bestTest = 0.7861706614
# bestIteration = 965
# Shrink model to first 966 iterations.
# Feature #212 eliminated
# Feature #306 eliminated
# Feature #723 eliminated
# Feature #203 eliminated
# Feature #411 eliminated
# Feature #25 eliminated
# Feature #865 eliminated
# Feature #755 eliminated
# Feature #79 eliminated
# Feature #283 eliminated
# Feature #868 eliminated
# Feature #109 eliminated
# Feature #31 eliminated
# Feature #548 eliminated
# Feature #95 eliminated
# Feature #910 eliminated
# Feature #884 eliminated
# Feature #303 eliminated
# Feature #812 eliminated
# Feature #832 eliminated
# Feature #246 eliminated
# Feature #341 eliminated
# Feature #442 eliminated
# Feature #36 eliminated
# Feature #417 eliminated
# Feature #710 eliminated
# Feature #220 eliminated
# Feature #156 eliminated
# Feature #604 eliminated
# Feature #919 eliminated
# Feature #24 eliminated
# Feature #107 eliminated
# Feature #620 eliminated
# Feature #249 eliminated
# Feature #66 eliminated
# Feature #451 eliminated
# Feature #119 eliminated
# Feature #905 eliminated
# Feature #90 eliminated
# Feature #896 eliminated
# Feature #527 eliminated
# Feature #580 eliminated
# Feature #436 eliminated
# Feature #103 eliminated
# Feature #788 eliminated
# Feature #169 eliminated
# Feature #691 eliminated
# Feature #453 eliminated
# Feature #810 eliminated
# Feature #776 eliminated
# Feature #354 eliminated
# Feature #210 eliminated
# Feature #362 eliminated
# Feature #886 eliminated
# Feature #769 eliminated
# Feature #141 eliminated
# Feature #849 eliminated
# Feature #881 eliminated
# Feature #195 eliminated
# Feature #514 eliminated
# Feature #716 eliminated
# Feature #513 eliminated
# Feature #6 eliminated
# Feature #309 eliminated
# Feature #848 eliminated
# Feature #359 eliminated
# Feature #738 eliminated
# Feature #96 eliminated
# Feature #803 eliminated
# Feature #189 eliminated
# Feature #837 eliminated
# Feature #511 eliminated
# Feature #785 eliminated
# Feature #731 eliminated
# Feature #130 eliminated
# Feature #558 eliminated
# Feature #255 eliminated
# Feature #72 eliminated
# Feature #619 eliminated
# Feature #677 eliminated
# Feature #737 eliminated
# Feature #504 eliminated
# Feature #456 eliminated
# Feature #405 eliminated
# Feature #172 eliminated
# Feature #681 eliminated
# Feature #380 eliminated
# Feature #734 eliminated
# Feature #174 eliminated
# Feature #724 eliminated
# Feature #165 eliminated
# Feature #700 eliminated
# Feature #678 eliminated
# Feature #168 eliminated
# Feature #139 eliminated
# Feature #379 eliminated
# Feature #52 eliminated
# Feature #695 eliminated
# Feature #834 eliminated
# Feature #577 eliminated
# Feature #374 eliminated
# Feature #800 eliminated
# Feature #12 eliminated
# Feature #53 eliminated
# Feature #752 eliminated
# Feature #448 eliminated
# Feature #686 eliminated
# Feature #194 eliminated
# Feature #213 eliminated
# Feature #555 eliminated
# Feature #128 eliminated
# Feature #150 eliminated
# Feature #441 eliminated
# Feature #831 eliminated
# Feature #240 eliminated
# Feature #318 eliminated
# Feature #774 eliminated
# Feature #915 eliminated
# Feature #170 eliminated
# Feature #891 eliminated
# Feature #331 eliminated
# Feature #813 eliminated
# Feature #717 eliminated
# Feature #39 eliminated
# Feature #830 eliminated
# Feature #525 eliminated
# Feature #314 eliminated
# Feature #497 eliminated
# Feature #247 eliminated
# Feature #751 eliminated
# Feature #818 eliminated
# Feature #204 eliminated
# Feature #256 eliminated
# Feature #726 eliminated
# Feature #575 eliminated
# Feature #488 eliminated
# Feature #347 eliminated
# Feature #816 eliminated
# Feature #534 eliminated
# Feature #414 eliminated
# Feature #30 eliminated
# Feature #554 eliminated
# Feature #108 eliminated
# Feature #798 eliminated
# Feature #894 eliminated
# Feature #610 eliminated
# Feature #815 eliminated
# Feature #178 eliminated
# Feature #641 eliminated
# Feature #297 eliminated
# Feature #756 eliminated
# Feature #403 eliminated
# Feature #516 eliminated
# Feature #565 eliminated
# Feature #668 eliminated
# Feature #720 eliminated
# Feature #742 eliminated
# Feature #307 eliminated
# Feature #214 eliminated
# Feature #121 eliminated
# Feature #519 eliminated
# Feature #248 eliminated
# Feature #761 eliminated
# Feature #389 eliminated
# Feature #350 eliminated
# Step #2 out of 10
# 0:	test: 0.7214367	best: 0.7214367 (0)	total: 94.7ms	remaining: 1m 34s
# 300:	test: 0.7829789	best: 0.7829789 (300)	total: 27.9s	remaining: 1m 4s
# 600:	test: 0.7894940	best: 0.7896475 (595)	total: 54.7s	remaining: 36.3s
# 900:	test: 0.7921414	best: 0.7927496 (760)	total: 1m 17s	remaining: 8.54s
# 999:	test: 0.7929057	best: 0.7934148 (945)	total: 1m 26s	remaining: 0us
# bestTest = 0.7934148312
# bestIteration = 945
# Shrink model to first 946 iterations.
# Feature #481 eliminated
# Feature #286 eliminated
# Feature #883 eliminated
# Feature #145 eliminated
# Feature #218 eliminated
# Feature #537 eliminated
# Feature #289 eliminated
# Feature #19 eliminated
# Feature #78 eliminated
# Feature #864 eliminated
# Feature #854 eliminated
# Feature #908 eliminated
# Feature #899 eliminated
# Feature #317 eliminated
# Feature #186 eliminated
# Feature #811 eliminated
# Feature #277 eliminated
# Feature #683 eliminated
# Feature #435 eliminated
# Feature #308 eliminated
# Feature #349 eliminated
# Feature #466 eliminated
# Feature #234 eliminated
# Feature #99 eliminated
# Feature #572 eliminated
# Feature #467 eliminated
# Feature #808 eliminated
# Feature #167 eliminated
# Feature #439 eliminated
# Feature #515 eliminated
# Feature #264 eliminated
# Feature #916 eliminated
# Feature #300 eliminated
# Feature #160 eliminated
# Feature #184 eliminated
# Feature #784 eliminated
# Feature #261 eliminated
# Feature #158 eliminated
# Feature #733 eliminated
# Feature #829 eliminated
# Feature #603 eliminated
# Feature #267 eliminated
# Feature #208 eliminated
# Feature #41 eliminated
# Feature #748 eliminated
# Feature #62 eliminated
# Feature #708 eliminated
# Feature #807 eliminated
# Feature #712 eliminated
# Feature #786 eliminated
# Feature #238 eliminated
# Feature #443 eliminated
# Feature #228 eliminated
# Feature #606 eliminated
# Feature #465 eliminated
# Feature #685 eliminated
# Feature #147 eliminated
# Feature #413 eliminated
# Feature #215 eliminated
# Feature #675 eliminated
# Feature #821 eliminated
# Feature #222 eliminated
# Feature #315 eliminated
# Feature #911 eliminated
# Feature #153 eliminated
# Feature #236 eliminated
# Feature #123 eliminated
# Feature #5 eliminated
# Feature #591 eliminated
# Feature #547 eliminated
# Feature #112 eliminated
# Feature #521 eliminated
# Feature #459 eliminated
# Feature #138 eliminated
# Feature #617 eliminated
# Feature #355 eliminated
# Feature #269 eliminated
# Feature #278 eliminated
# Feature #571 eliminated
# Feature #904 eliminated
# Feature #251 eliminated
# Feature #422 eliminated
# Feature #736 eliminated
# Feature #866 eliminated
# Feature #759 eliminated
# Feature #719 eliminated
# Feature #71 eliminated
# Feature #551 eliminated
# Feature #573 eliminated
# Feature #86 eliminated
# Feature #594 eliminated
# Feature #457 eliminated
# Feature #820 eliminated
# Feature #324 eliminated
# Feature #162 eliminated
# Feature #166 eliminated
# Feature #242 eliminated
# Feature #524 eliminated
# Feature #599 eliminated
# Feature #706 eliminated
# Feature #232 eliminated
# Feature #455 eliminated
# Feature #722 eliminated
# Feature #259 eliminated
# Feature #795 eliminated
# Feature #478 eliminated
# Feature #475 eliminated
# Feature #366 eliminated
# Feature #295 eliminated
# Feature #653 eliminated
# Feature #381 eliminated
# Feature #29 eliminated
# Feature #569 eliminated
# Feature #17 eliminated
# Feature #536 eliminated
# Feature #684 eliminated
# Feature #699 eliminated
# Feature #608 eliminated
# Feature #773 eliminated
# Feature #16 eliminated
# Feature #578 eliminated
# Feature #895 eliminated
# Feature #626 eliminated
# Feature #640 eliminated
# Feature #593 eliminated
# Feature #861 eliminated
# Feature #538 eliminated
# Feature #656 eliminated
# Feature #288 eliminated
# Feature #452 eliminated
# Feature #586 eliminated
# Feature #839 eliminated
# Feature #545 eliminated
# Feature #630 eliminated
# Feature #368 eliminated
# Step #3 out of 10
# 0:	test: 0.7080005	best: 0.7080005 (0)	total: 86.8ms	remaining: 1m 26s
# 300:	test: 0.7849854	best: 0.7849854 (300)	total: 25.4s	remaining: 59.1s
# 600:	test: 0.7910376	best: 0.7917246 (590)	total: 51.5s	remaining: 34.2s
# 900:	test: 0.7959277	best: 0.7959277 (900)	total: 1m 17s	remaining: 8.53s
# 999:	test: 0.7961354	best: 0.7966065 (925)	total: 1m 25s	remaining: 0us
# bestTest = 0.7966065407
# bestIteration = 925
# Shrink model to first 926 iterations.
# Feature #64 eliminated
# Feature #187 eliminated
# Feature #76 eliminated
# Feature #142 eliminated
# Feature #205 eliminated
# Feature #740 eliminated
# Feature #409 eliminated
# Feature #903 eliminated
# Feature #428 eliminated
# Feature #851 eliminated
# Feature #871 eliminated
# Feature #407 eliminated
# Feature #164 eliminated
# Feature #198 eliminated
# Feature #281 eliminated
# Feature #882 eliminated
# Feature #322 eliminated
# Feature #270 eliminated
# Feature #500 eliminated
# Feature #301 eliminated
# Feature #900 eliminated
# Feature #10 eliminated
# Feature #299 eliminated
# Feature #780 eliminated
# Feature #582 eliminated
# Feature #217 eliminated
# Feature #340 eliminated
# Feature #814 eliminated
# Feature #771 eliminated
# Feature #822 eliminated
# Feature #898 eliminated
# Feature #157 eliminated
# Feature #557 eliminated
# Feature #343 eliminated
# Feature #77 eliminated
# Feature #18 eliminated
# Feature #760 eliminated
# Feature #325 eliminated
# Feature #483 eliminated
# Feature #567 eliminated
# Feature #272 eliminated
# Feature #781 eliminated
# Feature #51 eliminated
# Feature #468 eliminated
# Feature #613 eliminated
# Feature #906 eliminated
# Feature #842 eliminated
# Feature #758 eliminated
# Feature #587 eliminated
# Feature #766 eliminated
# Feature #696 eliminated
# Feature #676 eliminated
# Feature #667 eliminated
# Feature #805 eliminated
# Feature #412 eliminated
# Feature #365 eliminated
# Feature #54 eliminated
# Feature #357 eliminated
# Feature #824 eliminated
# Feature #450 eliminated
# Feature #598 eliminated
# Feature #692 eliminated
# Feature #562 eliminated
# Feature #694 eliminated
# Feature #777 eliminated
# Feature #498 eliminated
# Feature #762 eliminated
# Feature #68 eliminated
# Feature #226 eliminated
# Feature #263 eliminated
# Feature #585 eliminated
# Feature #486 eliminated
# Feature #787 eliminated
# Feature #480 eliminated
# Feature #185 eliminated
# Feature #744 eliminated
# Feature #337 eliminated
# Feature #353 eliminated
# Feature #367 eliminated
# Feature #363 eliminated
# Feature #105 eliminated
# Feature #406 eliminated
# Feature #528 eliminated
# Feature #65 eliminated
# Feature #446 eliminated
# Feature #689 eliminated
# Feature #556 eliminated
# Feature #437 eliminated
# Feature #799 eliminated
# Feature #828 eliminated
# Feature #546 eliminated
# Feature #728 eliminated
# Feature #271 eliminated
# Feature #698 eliminated
# Feature #265 eliminated
# Feature #292 eliminated
# Feature #416 eliminated
# Feature #201 eliminated
# Feature #596 eliminated
# Feature #605 eliminated
# Feature #634 eliminated
# Feature #612 eliminated
# Feature #693 eliminated
# Feature #20 eliminated
# Feature #595 eliminated
# Feature #188 eliminated
# Feature #845 eliminated
# Feature #311 eliminated
# Feature #401 eliminated
# Feature #49 eliminated
# Feature #796 eliminated
# Step #4 out of 10
# 0:	test: 0.7080005	best: 0.7080005 (0)	total: 66.1ms	remaining: 1m 6s
# 300:	test: 0.7909698	best: 0.7909698 (300)	total: 20.7s	remaining: 48s
# 600:	test: 0.7957295	best: 0.7957295 (600)	total: 46.6s	remaining: 30.9s
# 900:	test: 0.8022107	best: 0.8022107 (900)	total: 1m 11s	remaining: 7.88s
# 999:	test: 0.8016297	best: 0.8022107 (900)	total: 1m 19s	remaining: 0us
# bestTest = 0.8022107482
# bestIteration = 900
# Shrink model to first 901 iterations.
# Feature #284 eliminated
# Feature #420 eliminated
# Feature #244 eliminated
# Feature #902 eliminated
# Feature #85 eliminated
# Feature #867 eliminated
# Feature #809 eliminated
# Feature #356 eliminated
# Feature #913 eliminated
# Feature #148 eliminated
# Feature #843 eliminated
# Feature #313 eliminated
# Feature #335 eliminated
# Feature #38 eliminated
# Feature #7 eliminated
# Feature #84 eliminated
# Feature #102 eliminated
# Feature #674 eliminated
# Feature #713 eliminated
# Feature #860 eliminated
# Feature #361 eliminated
# Feature #470 eliminated
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 evaluator = TestKFoldWrapper(n_fold_test,test_c_stop)
# ----> 3 evaluator.run_experiments(
#       4     model_builder=model_builder,
#       5     train_data=train_data,
#       6     label_col=label_col
#       7 )
#
# Cell In[20], line 15, in TestKFoldWrapper.run_experiments(self, model_builder, train_data, label_col)
#      12 train_df = train_data.iloc[train_index]
#      13 test_df = train_data.iloc[test_index]
# ---> 15 model,outs = model_builder(train_df)
#      16 self.outs.append(outs)
#      17 self.models.append(model)
#
# Cell In[19], line 21, in model_builder(train_data)
#      14 eval_pool = Pool(
#      15     eval_df.drop([label_col]+drop_cols,axis=1),
#      16     label = eval_df[label_col],
#      17     cat_features = cat_cols
#      18 )
#      20 cbm = CatBoostClassifier(**params)
# ---> 21 out = cbm.select_features(
#      22     train_pool,
#      23     eval_set=eval_pool,
#      24     algorithm=algorithm,
#      25     features_for_select=features_for_select,
#      26     num_features_to_select=num_features_to_select,
#      27     steps=steps,
#      28     shap_calc_type=None,
#      29     train_final_model=True,
#      30     verbose=300,
#      31     plot=False
#      32 )
#      33 return cbm, out
#
# File /usr/local/lib/python3.11/dist-packages/catboost/core.py:4498, in CatBoost.select_features(self, X, y, eval_set, features_for_select, num_features_to_select, algorithm, steps, shap_calc_type, train_final_model, verbose, logging_level, plot, plot_file, log_cout, log_cerr, grouping, features_tags_for_select, num_features_tags_to_select)
#    4495     create_dir_if_not_exist(plot_dir)
#    4497 with plot_wrapper(plot, plot_file=plot_file, plot_title='Select features plot', train_dirs=plot_dirs):
# -> 4498     summary = self._object._select_features(train_pool, test_pool, params)
#    4500 if train_final_model:
#    4501     self._set_trained_model_attributes()
#
# File _catboost.pyx:5438, in _catboost._CatBoost._select_features()
#
# File _catboost.pyx:5452, in _catboost._CatBoost._select_features()
#
# KeyboardInterrupt:

# %%
top_k_feats = set(evaluator.outs[0]['selected_features_names']) & set(evaluator.outs[1]['selected_features_names']) & set(evaluator.outs[2]['selected_features_names'])

# %%
np.save('best_features6_2.npy',evaluator.outs[2]['selected_features_names'])

# %%
evaluator.models[0].get_feature_importance(prettified=True)[:60]
# Out:
#                                        Feature Id  Importances
# 0       mobile_event_nunique_apply_personal_offer     5.392954
# 1             mobile_event_nunique_screen_profile     4.570807
# 2                    clients_orderid_count_71,2,3     3.418077
# 3       mobile_event_max_apply_personal_offer_otn     3.127639
# 4              order_feats_nunique_all_day_time_1     3.093048
# 5         order_feats_nunique_ClientOrderNumber_1     2.743967
# 6             order_feats_std_ClientOrderNumber_1     2.465097
# 7   mobile_event_nunique_apply_personal_offer_otn     2.048009
# 8          mobile_event_mean_apply_personal_offer     1.980343
# 9       mobile_event_std_apply_personal_offer_otn     1.975341
# 10          mobile_event_min_apply_personal_offer     1.659265
# 11           mobile_event_nunique_screen_cart_otn     1.418332
# 12             mobile_event_mean_remove_from_cart     1.390013
# 13                      order_feats_mean_Skidka_1     1.344298
# 14                                 order_appl_std     1.273971
# 15             mobile_event_count_screen_menu_otn     1.267194
# 16            order_payment_std_absolute_time_1_2     1.189967
# 17          order_feats_mean_OrderUUId_appl_sum_1     1.173442
# 18          mobile_event_max_apply_personal_offer     1.171833
# 19       order_feats_<lambda>_ProductUUId_count_1     1.162323
# 20                   order_feats_min_Skidka_otn_1     1.134737
# 21                   mobile_platform_mean_ios_otn     1.119299
# 22                                mobile_emb_0008     1.108582
# 23                order_order_count_MenuPrice_0_4     1.080877
# 24        order_feats_nunique_ProductTotalPrice_1     1.041713
# 25                    order_feats_min_dayofweek_1     1.038937
# 26        order_feats_min_ProductUUId_appl_mean_1     1.035342
# 27          mobile_event_min_open_bonusaction_otn     1.016543
# 28                order_payment_sum_MenuPrice_1_2     1.011541
# 29                                     OrderPrice     1.003677
# 30                  order_order_sum_MenuPrice_1_3     1.001688
# 31         order_feats_<lambda>_OrderTotalPrice_1     0.992389
# 32                order_feats_min_absolute_time_0     0.984037
# 33                   order_feats_mean_dayofweek_1     0.958759
# 34                 mobile_event_std_close_app_otn     0.957414
# 35                   order_feats_nunique_Skidka_1     0.907950
# 36      mobile_event_nunique_open_bonusaction_otn     0.903653
# 37                order_feats_std_absolute_time_1     0.871822
# 38               order_feats_mean_absolute_time_1     0.867335
# 39                    order_feats_sum_MenuPrice_1     0.826102
# 40                          mobile_hour_nunique_9     0.820799
# 41                           mobile_hour_count_22     0.787671
# 42                 order_order_mean_MenuPrice_1_4     0.779091
# 43                 order_feats_std_all_day_time_1     0.778246
# 44           order_payment_mean_absolute_time_0_2     0.764323
# 45               order_payment_mean_MenuPrice_1_2     0.764039
# 46        order_feats_max_ProductUUId_appl_mean_1     0.750375
# 47                    order_feats_max_MenuPrice_1     0.723036
# 48           order_feats_mean_ProductTotalPrice_1     0.720626
# 49                                order_appl_mean     0.716986
# 50                       order_feats_sum_Skidka_1     0.716362
# 51                       order_feats_mean_month_0     0.707752
# 52           order_feats_<lambda>_absolute_time_0     0.705521
# 53                    order_feats_min_MenuPrice_1     0.700028
# 54            order_feats_<lambda>_all_day_time_1     0.694835
# 55                     order_feats_nunique_hour_1     0.694024
# 56           order_feats_max_UnitUUId_appl_mean_1     0.675692
# 57                             mobile_hour_mean_9     0.660715
# 58                          mobile_hour_nunique_8     0.642114
# 59               order_feats_<lambda>_MenuPrice_1     0.634428

# %%
model = model_builder(train_data)
# Out:
# Default metric period is 5 because AUC is/are not implemented for GPU
# Step #1 out of 10
# 0:	test: 0.6805359	best: 0.6805359 (0)	total: 50.1ms	remaining: 50s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 model = model_builder(train_data)
#
# Cell In[21], line 21, in model_builder(train_data)
#      14 eval_pool = Pool(
#      15     eval_df.drop([label_col]+drop_cols,axis=1),
#      16     label = eval_df[label_col],
#      17     cat_features = cat_cols
#      18 )
#      20 cbm = CatBoostClassifier(**params)
# ---> 21 out = cbm.select_features(
#      22     train_pool,
#      23     eval_set=eval_pool,
#      24     algorithm=algorithm,
#      25     features_for_select=features_for_select,
#      26     num_features_to_select=num_features_to_select,
#      27     steps=steps,
#      28     shap_calc_type=None,
#      29     train_final_model=True,
#      30     verbose=300,
#      31     plot=False
#      32 )
#      33 return cbm, out
#
# File /usr/local/lib/python3.11/dist-packages/catboost/core.py:4498, in CatBoost.select_features(self, X, y, eval_set, features_for_select, num_features_to_select, algorithm, steps, shap_calc_type, train_final_model, verbose, logging_level, plot, plot_file, log_cout, log_cerr, grouping, features_tags_for_select, num_features_tags_to_select)
#    4495     create_dir_if_not_exist(plot_dir)
#    4497 with plot_wrapper(plot, plot_file=plot_file, plot_title='Select features plot', train_dirs=plot_dirs):
# -> 4498     summary = self._object._select_features(train_pool, test_pool, params)
#    4500 if train_final_model:
#    4501     self._set_trained_model_attributes()
#
# File _catboost.pyx:5438, in _catboost._CatBoost._select_features()
#
# File _catboost.pyx:5452, in _catboost._CatBoost._select_features()
#
# KeyboardInterrupt:

# %%
test_data = test_data.merge(all_features)

# %%
preds = evaluator.models[0].predict(test_data[],drop_cols=drop_cols,cat_features=cat_cols)

# %%
sample_submit['apply_promo'] = preds

# %%
sample_submit.to_csv('./submits/sub_dodo8.csv',index=False)

# %%
simple_sub = pd.read_csv('submits/sub_dodo15.csv')
simple_sub['apply_promo'] = pd.read_csv('submits/sub_dodo12.csv')['apply_promo'].values * 0.05 + simple_sub['apply_promo'].values * 0.9

# %%
simple_sub.to_csv('./submits/ens_dodo_3.csv',index=False)

# %%
simple_sub
# Out:
#       apply_promo
# 0        0.030221
# 1        0.096121
# 2        0.024879
# 3        0.030460
# 4        0.039861
# ...           ...
# 6801     0.013490
# 6802     0.017919
# 6803     0.031535
# 6804     0.075184
# 6805     0.032177
#
# [6806 rows x 1 columns]
